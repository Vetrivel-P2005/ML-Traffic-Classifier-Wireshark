# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.9 kB 217.9 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 290.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 294.7 kB/s eta 0:00:00
# Downloading numpy-2.3.3-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB 1.9 MB/s eta 0:00:07
#     --------------------------------------- 0.2/13.1 MB 2.0 MB/s eta 0:00:07
#     --------------------------------------- 0.2/13.1 MB 2.0 MB/s eta 0:00:07
#     --------------------------------------- 0.3/13.1 MB 1.7 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/13.1 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/13.1 MB 2.0 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/13.1 MB 2.0 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/13.1 MB 1.9 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/13.1 MB 2.0 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/13.1 MB 2.2 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/13.1 MB 2.2 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/13.1 MB 2.0 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/13.1 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.2/13.1 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/13.1 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.4/13.1 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.5/13.1 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/13.1 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.7/13.1 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.7/13.1 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.9/13.1 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.9/13.1 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.0/13.1 MB 1.8 MB/s eta 0:00:07
#    ------ --------------------------------- 2.0/13.1 MB 1.9 MB/s eta 0:00:06
#    ------ --------------------------------- 2.0/13.1 MB 1.8 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.1 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.1 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.1 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.1 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 2.2/13.1 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 2.2/13.1 MB 1.6 MB/s eta 0:00:07
#    ------- -------------------------------- 2.3/13.1 MB 1.6 MB/s eta 0:00:07
#    ------- -------------------------------- 2.5/13.1 MB 1.6 MB/s eta 0:00:07
#    ------- -------------------------------- 2.6/13.1 MB 1.6 MB/s eta 0:00:07
#    -------- ------------------------------- 2.7/13.1 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 2.8/13.1 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 2.8/13.1 MB 1.7 MB/s eta 0:00:07
#    -------- ------------------------------- 2.9/13.1 MB 1.6 MB/s eta 0:00:07
#    -------- ------------------------------- 2.9/13.1 MB 1.6 MB/s eta 0:00:07
#    -------- ------------------------------- 2.9/13.1 MB 1.6 MB/s eta 0:00:07
#    --------- ------------------------------ 3.0/13.1 MB 1.6 MB/s eta 0:00:07
#    --------- ------------------------------ 3.0/13.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 3.0/13.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 3.1/13.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 3.1/13.1 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 3.2/13.1 MB 1.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.3/13.1 MB 1.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.4/13.1 MB 1.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.5/13.1 MB 1.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.5/13.1 MB 1.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.7/13.1 MB 1.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.8/13.1 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 4.0/13.1 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 4.2/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------ --------------------------- 4.2/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.3/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.5/13.1 MB 1.7 MB/s eta 0:00:06
#    ------------- -------------------------- 4.5/13.1 MB 1.7 MB/s eta 0:00:06
#    -------------- ------------------------- 4.7/13.1 MB 1.7 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.1 MB 1.7 MB/s eta 0:00:05
#    -------------- ------------------------- 4.9/13.1 MB 1.7 MB/s eta 0:00:05
#    --------------- ------------------------ 5.1/13.1 MB 1.8 MB/s eta 0:00:05
#    --------------- ------------------------ 5.1/13.1 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.3/13.1 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.1 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.6/13.1 MB 1.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.8/13.1 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 5.9/13.1 MB 1.8 MB/s eta 0:00:05
#    ------------------ --------------------- 6.0/13.1 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 6.1/13.1 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 6.1/13.1 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 6.3/13.1 MB 1.8 MB/s eta 0:00:04
#    ------------------- -------------------- 6.5/13.1 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.6/13.1 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 6.8/13.1 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.9/13.1 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 6.9/13.1 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/13.1 MB 1.8 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/13.1 MB 1.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.4/13.1 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.4/13.1 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.7/13.1 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.8/13.1 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 7.9/13.1 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 8.1/13.1 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 8.2/13.1 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 8.4/13.1 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 8.4/13.1 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 8.4/13.1 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 8.6/13.1 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 8.8/13.1 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 8.8/13.1 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 9.2/13.1 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.2/13.1 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.4/13.1 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.6/13.1 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/13.1 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 9.8/13.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.9/13.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 10.0/13.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 10.3/13.1 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 10.4/13.1 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 10.6/13.1 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 10.6/13.1 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 10.7/13.1 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 10.9/13.1 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 11.0/13.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 11.0/13.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 11.0/13.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 11.0/13.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 11.1/13.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/13.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/13.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.1 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/13.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 11.9/13.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 12.4/13.1 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.5/13.1 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.8/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  12.9/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  12.9/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.0-cp311-cp311-win_amd64.whl.metadata (113 kB)
#      ---------------------------------------- 0.0/113.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/113.8 kB ? eta -:--:--
#      --------------------- ----------------- 61.4/113.8 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------  112.6/113.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 113.8/113.8 kB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.1 MB 1.7 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.1 MB 1.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/8.1 MB 1.5 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/8.1 MB 1.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/8.1 MB 1.4 MB/s eta 0:00:06
#    -- ------------------------------------- 0.4/8.1 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.4/8.1 MB 1.3 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/8.1 MB 1.4 MB/s eta 0:00:06
#    --- ------------------------------------ 0.6/8.1 MB 1.4 MB/s eta 0:00:06
#    --- ------------------------------------ 0.7/8.1 MB 1.4 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/8.1 MB 1.4 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/8.1 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.9/8.1 MB 1.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/8.1 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/8.1 MB 1.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.1/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.2/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.4/8.1 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.4/8.1 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 1.7/8.1 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 1.7/8.1 MB 1.6 MB/s eta 0:00:05
#    --------- ------------------------------ 1.9/8.1 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 1.9/8.1 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.0/8.1 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 1.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.2/8.1 MB 1.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.3/8.1 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.5/8.1 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.5/8.1 MB 1.7 MB/s eta 0:00:04
#    ------------- -------------------------- 2.7/8.1 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.8/8.1 MB 1.8 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.6/8.1 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 3.8/8.1 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 4.0/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.0/8.1 MB 2.2 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 2.2 MB/s eta 0:00:02
#    --------------------- ------------------ 4.3/8.1 MB 2.2 MB/s eta 0:00:02
#    --------------------- ------------------ 4.4/8.1 MB 2.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.1 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.8/8.1 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 4.9/8.1 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 5.3/8.1 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 5.3/8.1 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 5.6/8.1 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.7/8.1 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.4/8.1 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.1 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.9/8.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.1 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.1 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.1 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.1 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/225.2 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 225.2/225.2 kB 2.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.0-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.3 MB 4.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.5/2.3 MB 3.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 3.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.3 MB 4.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.3 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.3 MB 3.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.3 MB 3.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.3 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.8/2.3 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.2/2.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.8 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/73.8 kB ? eta -:--:--
#    ---------------------------------------- 73.8/73.8 kB 1.0 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB 15.4 MB/s eta 0:00:01
#    - -------------------------------------- 0.3/7.0 MB 4.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.0 MB 5.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.7/7.0 MB 4.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.0 MB 4.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.0 MB 4.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.0 MB 3.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.0 MB 3.9 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/7.0 MB 3.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/7.0 MB 3.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/7.0 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.0/7.0 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.0 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.3/7.0 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 2.5/7.0 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 2.5/7.0 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.0 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.0 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.0 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 2.7/7.0 MB 2.9 MB/s eta 0:00:02
#    --------------- ------------------------ 2.7/7.0 MB 2.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.8/7.0 MB 2.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/7.0 MB 2.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.0/7.0 MB 2.7 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/7.0 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/7.0 MB 2.8 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.0 MB 2.8 MB/s eta 0:00:02
#    -------------------- ------------------- 3.5/7.0 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 3.7/7.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 3.8/7.0 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 3.8/7.0 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.0/7.0 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 4.3/7.0 MB 2.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.4/7.0 MB 2.8 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/7.0 MB 2.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.8/7.0 MB 2.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.9/7.0 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.1/7.0 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/7.0 MB 2.9 MB/s eta 0:00:01
#    ------------------------------ --------- 5.4/7.0 MB 2.9 MB/s eta 0:00:01
#    -------------------------------- ------- 5.7/7.0 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/7.0 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 5.9/7.0 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.2/7.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.5/7.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.7/7.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 2.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.9 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/113.9 kB ? eta -:--:--
#    ---------------------------------------- 113.9/113.9 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.0 kiwisolver-1.4.9 matplotlib-3.10.6 pillow-11.3.0 pyparsing-3.2.5
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.6.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading scapy-2.6.1-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.4 MB 393.8 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.4 MB 544.7 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/2.4 MB 1.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.4 MB 958.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.4 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.4 MB 1.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.4 MB 1.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.4 MB 1.6 MB/s eta 0:00:02
#    ------------ --------------------------- 0.7/2.4 MB 1.6 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.4 MB 1.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.4 MB 1.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.4 MB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.4 MB 2.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.4/2.4 MB 2.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.4/2.4 MB 2.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.7/2.4 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.9/2.4 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.4 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: scapy
# Successfully installed scapy-2.6.1
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.3 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/11.3 MB 980.4 kB/s eta 0:00:12
#     --------------------------------------- 0.1/11.3 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.3/11.3 MB 1.2 MB/s eta 0:00:10
#     --------------------------------------- 0.3/11.3 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/11.3 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.3 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.3 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/11.3 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/11.3 MB 1.4 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/11.3 MB 1.2 MB/s eta 0:00:10
#    -- ------------------------------------- 0.7/11.3 MB 1.3 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.3 MB 1.3 MB/s eta 0:00:09
#    --- ------------------------------------ 0.9/11.3 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/11.3 MB 1.3 MB/s eta 0:00:09
#    --- ------------------------------------ 0.9/11.3 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.1/11.3 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.2/11.3 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.2/11.3 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.4/11.3 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.5/11.3 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.3 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.3 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.3 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.3 MB 1.6 MB/s eta 0:00:06
#    ------ --------------------------------- 2.0/11.3 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 2.0/11.3 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.3 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 2.2/11.3 MB 1.7 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.3 MB 1.7 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.3 MB 1.7 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.3 MB 1.6 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/11.3 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.7/11.3 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.8/11.3 MB 1.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.3 MB 1.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.3 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.3 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.2/11.3 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.3 MB 1.8 MB/s eta 0:00:05
#    ------------ --------------------------- 3.6/11.3 MB 1.8 MB/s eta 0:00:05
#    ------------ --------------------------- 3.6/11.3 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 3.8/11.3 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.9/11.3 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 4.0/11.3 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 4.1/11.3 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.3 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 4.4/11.3 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.3 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.6/11.3 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.8/11.3 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.9/11.3 MB 2.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.1/11.3 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 5.3/11.3 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 5.4/11.3 MB 2.1 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.3 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.7/11.3 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.3 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.1/11.3 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.3 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.5/11.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.5/11.3 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.7/11.3 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 6.9/11.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.9/11.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.2/11.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.3 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.5/11.3 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.7/11.3 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.7/11.3 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.3 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.3 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.5/11.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 8.6/11.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 9.0/11.3 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.0/11.3 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 9.3/11.3 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.3 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.8/11.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.3 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.3 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.3/11.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.6/11.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.3 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 2.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/509.2 kB ? eta -:--:--
#    ------------------ --------------------- 235.5/509.2 kB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 378.9/509.2 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 440.3/509.2 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 509.2/509.2 kB 2.1 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    ----------- ---------------------------- 102.4/347.8 kB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 317.4/347.8 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 347.8/347.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.3.2 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# [notice] A new release of pip is available: 24.0 -> 25.2
# Requirement already satisfied: numpy>=1.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (2.3.3)
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.8 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 538.0 kB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp311-cp311-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB 2.0 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/8.9 MB 2.0 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/8.9 MB 2.0 MB/s eta 0:00:05
#     --------------------------------------- 0.2/8.9 MB 1.1 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/8.9 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/8.9 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/8.9 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/8.9 MB 1.1 MB/s eta 0:00:08
#    -- ------------------------------------- 0.5/8.9 MB 1.2 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/8.9 MB 1.2 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/8.9 MB 1.2 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/8.9 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.7/8.9 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.7/8.9 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/8.9 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 0.9/8.9 MB 1.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/8.9 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/8.9 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.1/8.9 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.2/8.9 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/8.9 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.4/8.9 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.5/8.9 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.5/8.9 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.7/8.9 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 1.8/8.9 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 1.8/8.9 MB 1.5 MB/s eta 0:00:05
#    -------- ------------------------------- 2.0/8.9 MB 1.6 MB/s eta 0:00:05
#    --------- ------------------------------ 2.0/8.9 MB 1.5 MB/s eta 0:00:05
#    --------- ------------------------------ 2.1/8.9 MB 1.5 MB/s eta 0:00:05
#    --------- ------------------------------ 2.2/8.9 MB 1.5 MB/s eta 0:00:05
#    --------- ------------------------------ 2.2/8.9 MB 1.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/8.9 MB 1.6 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.5/8.9 MB 1.6 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.5/8.9 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 2.7/8.9 MB 1.6 MB/s eta 0:00:04
#    ------------ --------------------------- 2.8/8.9 MB 1.6 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.9 MB 1.7 MB/s eta 0:00:04
#    ------------- -------------------------- 3.1/8.9 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.9 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.3/8.9 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.5/8.9 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.6/8.9 MB 1.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.9 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.8/8.9 MB 1.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.0/8.9 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 4.1/8.9 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/8.9 MB 1.9 MB/s eta 0:00:03
#    ------------------- -------------------- 4.4/8.9 MB 1.9 MB/s eta 0:00:03
#    -------------------- ------------------- 4.6/8.9 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.6/8.9 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.6/8.9 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 4.9/8.9 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 4.9/8.9 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.1/8.9 MB 2.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.1/8.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 5.4/8.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/8.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------ --------------- 5.6/8.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/8.9 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.9 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.0/8.9 MB 2.1 MB/s eta 0:00:02
#    --------------------------- ------------ 6.2/8.9 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.2/8.9 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.4/8.9 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.6/8.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 6.8/8.9 MB 2.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.9/8.9 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/8.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.2/8.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.2/8.9 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.4/8.9 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.5/8.9 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.9 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.2/8.9 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/8.9 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  8.9/8.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 2.3 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ---------------------------------------- 0.0/308.4 kB ? eta -:--:--
#    ----------------------------- ---------- 225.3/308.4 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  307.2/308.4 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 308.4/308.4 kB 3.2 MB/s eta 0:00:00
# Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.7 MB 1.7 MB/s eta 0:00:23
#    ---------------------------------------- 0.3/38.7 MB 4.0 MB/s eta 0:00:10
#    ---------------------------------------- 0.4/38.7 MB 3.3 MB/s eta 0:00:12
#     --------------------------------------- 0.5/38.7 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.8/38.7 MB 3.5 MB/s eta 0:00:11
#     --------------------------------------- 0.9/38.7 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/38.7 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.2/38.7 MB 3.5 MB/s eta 0:00:11
#    - -------------------------------------- 1.3/38.7 MB 3.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.5/38.7 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.7/38.7 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/38.7 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.0/38.7 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/38.7 MB 3.3 MB/s eta 0:00:12
#    -- ------------------------------------- 2.3/38.7 MB 3.4 MB/s eta 0:00:11
#    -- ------------------------------------- 2.5/38.7 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/38.7 MB 3.3 MB/s eta 0:00:12
#    -- ------------------------------------- 2.7/38.7 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.8/38.7 MB 3.2 MB/s eta 0:00:12
#    -- ------------------------------------- 2.9/38.7 MB 3.2 MB/s eta 0:00:12
#    --- ------------------------------------ 3.1/38.7 MB 3.2 MB/s eta 0:00:12
#    --- ------------------------------------ 3.1/38.7 MB 3.1 MB/s eta 0:00:12
#    --- ------------------------------------ 3.3/38.7 MB 3.1 MB/s eta 0:00:12
#    --- ------------------------------------ 3.4/38.7 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 3.4/38.7 MB 2.9 MB/s eta 0:00:13
#    --- ------------------------------------ 3.6/38.7 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 3.6/38.7 MB 3.0 MB/s eta 0:00:12
#    --- ------------------------------------ 3.6/38.7 MB 2.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 3.9/38.7 MB 2.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 3.9/38.7 MB 2.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.1/38.7 MB 2.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.2/38.7 MB 2.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.4/38.7 MB 2.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.6/38.7 MB 2.9 MB/s eta 0:00:12
#    ---- ----------------------------------- 4.6/38.7 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 4.9/38.7 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.0/38.7 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.2/38.7 MB 3.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.4/38.7 MB 3.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.4/38.7 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.6/38.7 MB 3.0 MB/s eta 0:00:12
#    ------ --------------------------------- 5.8/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 5.9/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.2/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.3/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.4/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.7/38.7 MB 3.0 MB/s eta 0:00:11
#    ------ --------------------------------- 6.7/38.7 MB 3.0 MB/s eta 0:00:11
#    ------- -------------------------------- 7.0/38.7 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.1/38.7 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.2/38.7 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.4/38.7 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.6/38.7 MB 3.1 MB/s eta 0:00:11
#    ------- -------------------------------- 7.7/38.7 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 8.0/38.7 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 8.1/38.7 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 8.3/38.7 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 8.5/38.7 MB 3.1 MB/s eta 0:00:10
#    -------- ------------------------------- 8.6/38.7 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 8.8/38.7 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 8.9/38.7 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 9.1/38.7 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 9.3/38.7 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 9.4/38.7 MB 3.2 MB/s eta 0:00:10
#    --------- ------------------------------ 9.6/38.7 MB 3.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 9.8/38.7 MB 3.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 9.9/38.7 MB 3.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.1/38.7 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.3/38.7 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.4/38.7 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 10.6/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.9/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.0/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.2/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.4/38.7 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.5/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 11.7/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 11.9/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 12.0/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 12.1/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 12.3/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 12.4/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------- -------------------------- 12.7/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------- -------------------------- 12.8/38.7 MB 3.2 MB/s eta 0:00:09
#    ------------- -------------------------- 13.0/38.7 MB 3.2 MB/s eta 0:00:08
#    ------------- -------------------------- 13.1/38.7 MB 3.3 MB/s eta 0:00:08
#    ------------- -------------------------- 13.2/38.7 MB 3.2 MB/s eta 0:00:08
#    ------------- -------------------------- 13.4/38.7 MB 3.3 MB/s eta 0:00:08
#    -------------- ------------------------- 13.6/38.7 MB 3.3 MB/s eta 0:00:08
#    -------------- ------------------------- 13.7/38.7 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/38.7 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 14.0/38.7 MB 3.4 MB/s eta 0:00:08
#    -------------- ------------------------- 14.2/38.7 MB 3.5 MB/s eta 0:00:08
#    -------------- ------------------------- 14.4/38.7 MB 3.5 MB/s eta 0:00:08
#    -------------- ------------------------- 14.4/38.7 MB 3.5 MB/s eta 0:00:08
#    --------------- ------------------------ 14.7/38.7 MB 3.5 MB/s eta 0:00:07
#    --------------- ------------------------ 14.7/38.7 MB 3.5 MB/s eta 0:00:07
#    --------------- ------------------------ 14.7/38.7 MB 3.5 MB/s eta 0:00:07
#    --------------- ------------------------ 15.0/38.7 MB 3.4 MB/s eta 0:00:07
#    --------------- ------------------------ 15.0/38.7 MB 3.4 MB/s eta 0:00:07
#    --------------- ------------------------ 15.2/38.7 MB 3.4 MB/s eta 0:00:07
#    --------------- ------------------------ 15.3/38.7 MB 3.3 MB/s eta 0:00:08
#    ---------------- ----------------------- 15.5/38.7 MB 3.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 15.7/38.7 MB 3.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 15.8/38.7 MB 3.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.0/38.7 MB 3.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.1/38.7 MB 3.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.3/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.5/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.6/38.7 MB 3.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.8/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.0/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.1/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.3/38.7 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.4/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------ --------------------- 17.5/38.7 MB 3.4 MB/s eta 0:00:07
#    ------------------ --------------------- 17.7/38.7 MB 3.4 MB/s eta 0:00:07
#    ------------------ --------------------- 17.8/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------ --------------------- 18.0/38.7 MB 3.4 MB/s eta 0:00:07
#    ------------------ --------------------- 18.2/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------ --------------------- 18.2/38.7 MB 3.4 MB/s eta 0:00:07
#    ------------------- -------------------- 18.5/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------- -------------------- 18.6/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------- -------------------- 18.7/38.7 MB 3.3 MB/s eta 0:00:07
#    ------------------- -------------------- 19.0/38.7 MB 3.3 MB/s eta 0:00:06
#    ------------------- -------------------- 19.1/38.7 MB 3.3 MB/s eta 0:00:06
#    ------------------- -------------------- 19.3/38.7 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 19.5/38.7 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 19.5/38.7 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 19.8/38.7 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 20.0/38.7 MB 3.3 MB/s eta 0:00:06
#    -------------------- ------------------- 20.1/38.7 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 20.3/38.7 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 20.4/38.7 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 20.6/38.7 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 20.8/38.7 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 20.9/38.7 MB 3.4 MB/s eta 0:00:06
#    --------------------- ------------------ 21.1/38.7 MB 3.4 MB/s eta 0:00:06
#    --------------------- ------------------ 21.3/38.7 MB 3.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.4/38.7 MB 3.4 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.6/38.7 MB 3.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.7/38.7 MB 3.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.9/38.7 MB 3.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.1/38.7 MB 3.3 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.2/38.7 MB 3.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.5/38.7 MB 3.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.6/38.7 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.7/38.7 MB 3.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.0/38.7 MB 3.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.1/38.7 MB 3.3 MB/s eta 0:00:05
#    ------------------------ --------------- 23.3/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 23.4/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 23.5/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 23.8/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 23.9/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 24.1/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 24.3/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 24.4/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 24.6/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 24.8/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 24.9/38.7 MB 3.4 MB/s eta 0:00:05
#    ------------------------- -------------- 25.1/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.2/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.4/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.7 MB 3.5 MB/s eta 0:00:04
#    -------------------------- ------------- 25.8/38.7 MB 3.4 MB/s eta 0:00:04
#    -------------------------- ------------- 25.9/38.7 MB 3.4 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/38.7 MB 3.3 MB/s eta 0:00:04
#    --------------------------- ------------ 26.1/38.7 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 26.4/38.7 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 26.5/38.7 MB 3.3 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/38.7 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 26.9/38.7 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 26.9/38.7 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.2/38.7 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.7 MB 3.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.5/38.7 MB 3.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.7/38.7 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.0/38.7 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.0/38.7 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.2/38.7 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.4/38.7 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.5/38.7 MB 3.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.8/38.7 MB 3.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.9/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.1/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.3/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.5/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.8/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.1/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.3/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.4/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.6/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.8/38.7 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.2/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.2/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.4/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.6/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/38.7 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 31.8/38.7 MB 3.4 MB/s eta 0:00:03
#    --------------------------------- ------ 32.0/38.7 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.1/38.7 MB 3.3 MB/s eta 0:00:02
#    --------------------------------- ------ 32.4/38.7 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.5/38.7 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.5/38.7 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/38.7 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 32.9/38.7 MB 3.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.0/38.7 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.7 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.7 MB 3.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/38.7 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.7/38.7 MB 3.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.9/38.7 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.7 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.2/38.7 MB 3.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.4/38.7 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/38.7 MB 3.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/38.7 MB 3.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.8/38.7 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 35.0/38.7 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.7 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/38.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.5/38.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 35.8/38.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.7 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.7 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.7 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.5/38.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.5/38.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.7 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 36.8/38.7 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.7 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/38.7 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.7 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.7 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  37.7/38.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  38.4/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 3.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.2 threadpoolctl-3.6.0

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
# [notice] A new release of pip is available: 24.0 -> 25.2
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 487.6 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 469.7 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.9 kB 819.2 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 708.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 708.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 708.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 708.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 708.1 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/294.9 kB 561.1 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/294.9 kB 561.1 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 535.8 kB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 520.4 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import numpy as np
from scapy.all import rdpcap, IP, TCP, UDP, ICMP
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import os
import glob
import warnings
warnings.filterwarnings('ignore')

class PacketClassifier:
    def __init__(self):
        self.scaler = StandardScaler()
        self.label_encoder = LabelEncoder()
        self.model = RandomForestClassifier(n_estimators=100, random_state=42)
        self.feature_columns = []
        
    def extract_packet_features(self, packet):
        """Extract features from a single packet"""
        features = {}
        
        try:
            # Basic packet features
            features['packet_length'] = len(packet)
            features['has_ip'] = 1 if packet.haslayer(IP) else 0
            
            if packet.haslayer(IP):
                ip_layer = packet[IP]
                features['ip_length'] = self._safe_int(ip_layer.len)
                features['ip_ttl'] = self._safe_int(ip_layer.ttl)
                features['ip_flags'] = self._safe_int(ip_layer.flags)
                features['ip_frag'] = self._safe_int(ip_layer.frag)
                features['ip_proto'] = self._safe_int(ip_layer.proto)
                
                # Protocol-specific features
                features['is_tcp'] = 1 if packet.haslayer(TCP) else 0
                features['is_udp'] = 1 if packet.haslayer(UDP) else 0
                features['is_icmp'] = 1 if packet.haslayer(ICMP) else 0
                
                if packet.haslayer(TCP):
                    tcp_layer = packet[TCP]
                    features['src_port'] = self._safe_int(tcp_layer.sport)
                    features['dst_port'] = self._safe_int(tcp_layer.dport)
                    features['tcp_flags'] = self._safe_int(tcp_layer.flags)
                    features['tcp_window'] = self._safe_int(tcp_layer.window)
                    features['tcp_seq'] = self._safe_int(tcp_layer.seq)
                    features['tcp_ack'] = self._safe_int(tcp_layer.ack)
                    features['tcp_dataofs'] = self._safe_int(tcp_layer.dataofs)
                else:
                    features['src_port'] = 0
                    features['dst_port'] = 0
                    features['tcp_flags'] = 0
                    features['tcp_window'] = 0
                    features['tcp_seq'] = 0
                    features['tcp_ack'] = 0
                    features['tcp_dataofs'] = 0
                    
                if packet.haslayer(UDP):
                    udp_layer = packet[UDP]
                    features['src_port'] = self._safe_int(udp_layer.sport)
                    features['dst_port'] = self._safe_int(udp_layer.dport)
                    features['udp_length'] = self._safe_int(udp_layer.len)
                else:
                    features['udp_length'] = 0
                    
            else:
                # Default values for non-IP packets
                for key in ['ip_length', 'ip_ttl', 'ip_flags', 'ip_frag', 'ip_proto',
                           'is_tcp', 'is_udp', 'is_icmp', 'src_port', 'dst_port',
                           'tcp_flags', 'tcp_window', 'tcp_seq', 'tcp_ack', 
                           'tcp_dataofs', 'udp_length']:
                    features[key] = 0
                    
        except Exception as e:
            print(f"Warning: Error extracting features from packet: {e}")
            # Return default features in case of error
            for key in ['packet_length', 'has_ip', 'ip_length', 'ip_ttl', 'ip_flags', 
                       'ip_frag', 'ip_proto', 'is_tcp', 'is_udp', 'is_icmp', 
                       'src_port', 'dst_port', 'tcp_flags', 'tcp_window', 
                       'tcp_seq', 'tcp_ack', 'tcp_dataofs', 'udp_length']:
                features[key] = 0
                
        return features
    
    def _safe_int(self, value):
        """Safely convert value to integer, handling FlagValue and other objects"""
        try:
            # Handle Scapy FlagValue objects
            if hasattr(value, 'value'):
                return int(value.value)
            # Handle None values
            elif value is None:
                return 0
            # Handle regular numeric values
            else:
                return int(value)
        except (ValueError, TypeError, AttributeError):
            # Return 0 for any conversion errors
            return 0
    
    def classify_packet(self, packet):
        """Classify packet based on common patterns"""
        try:
            if not packet.haslayer(IP):
                return 'non_ip'
                
            ip_layer = packet[IP]
            
            if packet.haslayer(TCP):
                tcp_layer = packet[TCP]
                src_port = self._safe_int(tcp_layer.sport)
                dst_port = self._safe_int(tcp_layer.dport)
                
                # Web traffic
                if dst_port in [80, 443, 8080, 8443] or src_port in [80, 443, 8080, 8443]:
                    return 'web_traffic'
                # Email
                elif dst_port in [25, 587, 465, 993, 995, 143, 110] or src_port in [25, 587, 465, 993, 995, 143, 110]:
                    return 'email'
                # SSH/Telnet
                elif dst_port in [22, 23] or src_port in [22, 23]:
                    return 'remote_access'
                # FTP
                elif dst_port in [21, 20] or src_port in [21, 20]:
                    return 'file_transfer'
                # Database
                elif dst_port in [1433, 3306, 5432, 1521] or src_port in [1433, 3306, 5432, 1521]:
                    return 'database'
                else:
                    return 'other_tcp'
                    
            elif packet.haslayer(UDP):
                udp_layer = packet[UDP]
                src_port = self._safe_int(udp_layer.sport)
                dst_port = self._safe_int(udp_layer.dport)
                
                # DNS
                if dst_port == 53 or src_port == 53:
                    return 'dns'
                # DHCP
                elif dst_port in [67, 68] or src_port in [67, 68]:
                    return 'dhcp'
                # NTP
                elif dst_port == 123 or src_port == 123:
                    return 'ntp'
                # SNMP
                elif dst_port in [161, 162] or src_port in [161, 162]:
                    return 'snmp'
                else:
                    return 'other_udp'
                    
            elif packet.haslayer(ICMP):
                return 'icmp'
            else:
                return 'other_ip'
                
        except Exception as e:
            print(f"Warning: Error classifying packet: {e}")
            return 'unknown'
    
    def load_and_process_pcap(self, pcap_file_path):
        """Load single pcap file and extract features"""
        print(f"Loading packets from {pcap_file_path}...")
        
        try:
            packets = rdpcap(pcap_file_path)
            print(f"Loaded {len(packets)} packets from {os.path.basename(pcap_file_path)}")
        except Exception as e:
            print(f"Error loading pcap file {pcap_file_path}: {e}")
            return None, None
        
        features_list = []
        labels_list = []
        
        print("Extracting features...")
        for i, packet in enumerate(packets):
            if i % 1000 == 0:
                print(f"  Processed {i} packets...")
                
            try:
                # Extract features
                features = self.extract_packet_features(packet)
                features_list.append(features)
                
                # Generate label
                label = self.classify_packet(packet)
                labels_list.append(label)
                
            except Exception as e:
                print(f"Error processing packet {i}: {e}")
                continue
        
        # Convert to DataFrame
        df_features = pd.DataFrame(features_list)
        df_labels = pd.Series(labels_list, name='label')
        
        print(f"Extracted features for {len(df_features)} packets from {os.path.basename(pcap_file_path)}")
        
        return df_features, df_labels
    
    def load_and_process_folder(self, folder_path, file_limit=None):
        """Load and process multiple pcap files from a folder"""
        print(f"Scanning folder: {folder_path}")
        
        # Find all pcap/pcapng files
        pcap_patterns = ['*.pcap', '*.pcapng', '*.cap']
        pcap_files = []
        
        for pattern in pcap_patterns:
            pcap_files.extend(glob.glob(os.path.join(folder_path, pattern)))
        
        if not pcap_files:
            print(f"No pcap/pcapng files found in {folder_path}")
            print("Supported file extensions: .pcap, .pcapng, .cap")
            return None, None
        
        print(f"Found {len(pcap_files)} pcap files:")
        for file in pcap_files:
            print(f"  - {os.path.basename(file)}")
        
        # Limit files if specified
        if file_limit:
            pcap_files = pcap_files[:file_limit]
            print(f"Processing first {len(pcap_files)} files due to limit")
        
        all_features = []
        all_labels = []
        
        for i, pcap_file in enumerate(pcap_files, 1):
            print(f"\n[{i}/{len(pcap_files)}] Processing {os.path.basename(pcap_file)}")
            
            features, labels = self.load_and_process_pcap(pcap_file)
            
            if features is not None and not features.empty:
                all_features.append(features)
                all_labels.append(labels)
            else:
                print(f"Skipping {os.path.basename(pcap_file)} due to processing errors")
        
        if not all_features:
            print("No valid features extracted from any files")
            return None, None
        
        # Combine all data
        print(f"\nCombining data from {len(all_features)} files...")
        combined_features = pd.concat(all_features, ignore_index=True)
        combined_labels = pd.concat(all_labels, ignore_index=True)
        
        print(f"Total packets processed: {len(combined_features)}")
        print("\nOverall label distribution:")
        print(combined_labels.value_counts())
        
        return combined_features, combined_labels
    
    def train_model(self, features, labels):
        """Train the classification model"""
        print("\nTraining model...")
        
        # Store feature columns
        self.feature_columns = features.columns.tolist()
        
        # Clean the data: remove any rows with non-numeric values
        print("Cleaning data...")
        original_size = len(features)
        
        # Replace any remaining non-numeric values with 0
        features_cleaned = features.copy()
        for col in features_cleaned.columns:
            features_cleaned[col] = pd.to_numeric(features_cleaned[col], errors='coerce').fillna(0)
        
        # Remove rows where all features are 0 (likely corrupted packets)
        valid_rows = (features_cleaned != 0).any(axis=1)
        features_cleaned = features_cleaned[valid_rows]
        labels_cleaned = labels[valid_rows]
        
        print(f"Cleaned dataset: {len(features_cleaned)}/{original_size} packets retained")
        
        if len(features_cleaned) == 0:
            print("Error: No valid data remaining after cleaning")
            return None, None, None
        
        # Encode labels
        labels_encoded = self.label_encoder.fit_transform(labels_cleaned)
        
        # Scale features
        features_scaled = self.scaler.fit_transform(features_cleaned)
        
        # Check if we have enough samples for each class
        unique_labels, label_counts = np.unique(labels_encoded, return_counts=True)
        min_samples = min(label_counts)
        
        if min_samples < 2:
            print("Warning: Some classes have very few samples. Results may not be reliable.")
        
        # Split data with stratification if possible
        try:
            X_train, X_test, y_train, y_test = train_test_split(
                features_scaled, labels_encoded, test_size=0.2, random_state=42, 
                stratify=labels_encoded if min_samples >= 2 else None
            )
        except ValueError:
            # Fall back to random split if stratification fails
            X_train, X_test, y_train, y_test = train_test_split(
                features_scaled, labels_encoded, test_size=0.2, random_state=42
            )
        
        # Train model
        self.model.fit(X_train, y_train)
        
        # Evaluate
        y_pred = self.model.predict(X_test)
        
        accuracy = accuracy_score(y_test, y_pred)
        print(f"\nModel Accuracy: {accuracy:.3f}")
        
        # Classification report
        print("\nClassification Report:")
        class_names = self.label_encoder.classes_
        print(classification_report(y_test, y_pred, target_names=class_names, zero_division=0))
        
        # Feature importance
        feature_importance = pd.DataFrame({
            'feature': self.feature_columns,
            'importance': self.model.feature_importances_
        }).sort_values('importance', ascending=False)
        
        print("\nTop 10 Most Important Features:")
        print(feature_importance.head(10))
        
        return X_test, y_test, y_pred
    
    def plot_results(self, y_test, y_pred):
        """Plot confusion matrix and feature importance"""
        plt.figure(figsize=(15, 5))
        
        # Confusion Matrix
        plt.subplot(1, 3, 1)
        cm = confusion_matrix(y_test, y_pred)
        class_names = self.label_encoder.classes_
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                   xticklabels=class_names, yticklabels=class_names)
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.xticks(rotation=45)
        plt.yticks(rotation=0)
        
        # Feature Importance
        plt.subplot(1, 3, 2)
        feature_importance = pd.DataFrame({
            'feature': self.feature_columns,
            'importance': self.model.feature_importances_
        }).sort_values('importance', ascending=True).tail(10)
        
        plt.barh(feature_importance['feature'], feature_importance['importance'])
        plt.title('Top 10 Feature Importance')
        plt.xlabel('Importance')
        
        # Label Distribution
        plt.subplot(1, 3, 3)
        label_counts = pd.Series(self.label_encoder.inverse_transform(y_test)).value_counts()
        plt.pie(label_counts.values, labels=label_counts.index, autopct='%1.1f%%')
        plt.title('Test Set Label Distribution')
        
        plt.tight_layout()
        plt.show()
    
    def predict_packet_class(self, packet):
        """Predict the class of a single packet"""
        features = self.extract_packet_features(packet)
        features_df = pd.DataFrame([features])
        
        # Ensure all columns are present
        for col in self.feature_columns:
            if col not in features_df.columns:
                features_df[col] = 0
        
        features_df = features_df[self.feature_columns]
        features_scaled = self.scaler.transform(features_df)
        
        prediction = self.model.predict(features_scaled)[0]
        probability = self.model.predict_proba(features_scaled)[0]
        
        predicted_class = self.label_encoder.inverse_transform([prediction])[0]
        confidence = max(probability)
        
        return predicted_class, confidence

# Global classifier variable for Jupyter notebook usage
classifier = None

# Example usage
def main():
    """
    Main function to demonstrate the packet classifier
    
    To use this:
    1. Install required packages: pip install scapy scikit-learn pandas matplotlib seaborn
    2. Update the folder_path below to point to your pcap files folder
    3. Run the script
    """
    
    global classifier
    classifier = PacketClassifier()
    
    # Update this path to your pcap files folder
    pcap_folder = r"E:\pcap"  # Replace with your folder path
    # Alternative examples:
    # pcap_folder = "/path/to/your/pcap/files"  # Linux/Mac
    # pcap_folder = r"C:\path\to\your\pcap\files"  # Windows
    
    print("Network Packet Classification ML Model")
    print("=" * 50)
    
    # Check if folder exists
    if not os.path.exists(pcap_folder):
        print(f"Error: Folder '{pcap_folder}' does not exist")
        print("\nPlease:")
        print("1. Create the folder or update the path")
        print("2. Place your .pcap/.pcapng files in the folder")
        print("3. Update the 'pcap_folder' variable in the code")
        return None
    
    try:
        # Option 1: Process all files in folder
        features, labels = classifier.load_and_process_folder(pcap_folder)
        
        # Option 2: Process with file limit (uncomment to use)
        # features, labels = classifier.load_and_process_folder(pcap_folder, file_limit=5)
        
        # Option 3: Process single file (uncomment to use)
        # single_file = os.path.join(pcap_folder, "your_file.pcap")
        # features, labels = classifier.load_and_process_pcap(single_file)
        
        if features is not None and not features.empty:
            print(f"\nDataset shape: {features.shape}")
            print(f"Number of classes: {labels.nunique()}")
            
            # Check if we have enough data for training
            if len(features) < 100:
                print("Warning: Very small dataset. Consider adding more pcap files.")
            
            # Train the model
            X_test, y_test, y_pred = classifier.train_model(features, labels)
            
            # Plot results
            if X_test is not None:
                classifier.plot_results(y_test, y_pred)
            
            # Save model info
            print("\nModel trained successfully!")
            print("You can now use the classifier for predictions:")
            print("predicted_class, confidence = classifier.predict_packet_class(packet)")
            
            return classifier
            
        else:
            print("No valid data extracted from pcap files.")
            return None
            
    except Exception as e:
        print(f"Error during processing: {e}")
        return None

# Test functions for Jupyter notebook usage
def classify_packet_examples(trained_classifier):
    """Examples of classifying different types of packets"""
    if trained_classifier is None:
        print("Error: Classifier not trained. Please run main() first.")
        return
    
    from scapy.all import IP, TCP, UDP, ICMP
    
    print("\n" + "="*50)
    print("TESTING PACKET CLASSIFICATION")
    print("="*50)
    
    # Example 1: HTTP packet
    http_packet = IP(dst="192.168.1.1")/TCP(dport=80)
    pred_class, confidence = trained_classifier.predict_packet_class(http_packet)
    print(f"HTTP packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 2: DNS packet  
    dns_packet = IP(dst="8.8.8.8")/UDP(dport=53)
    pred_class, confidence = trained_classifier.predict_packet_class(dns_packet)
    print(f"DNS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 3: HTTPS packet
    https_packet = IP(dst="www.google.com")/TCP(dport=443)
    pred_class, confidence = trained_classifier.predict_packet_class(https_packet)
    print(f"HTTPS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 4: ICMP packet
    icmp_packet = IP(dst="192.168.1.1")/ICMP()
    pred_class, confidence = trained_classifier.predict_packet_class(icmp_packet)
    print(f"ICMP packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 5: SSH packet
    ssh_packet = IP(dst="192.168.1.100")/TCP(dport=22)
    pred_class, confidence = trained_classifier.predict_packet_class(ssh_packet)
    print(f"SSH packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 6: FTP packet
    ftp_packet = IP(dst="ftp.example.com")/TCP(dport=21)
    pred_class, confidence = trained_classifier.predict_packet_class(ftp_packet)
    print(f"FTP packet: {pred_class} (confidence: {confidence:.3f})")

def classify_new_pcap_file(trained_classifier, pcap_file_path):
    """Classify all packets in a new pcap file"""
    if trained_classifier is None:
        print("Error: Classifier not trained. Please run main() first.")
        return None
        
    print(f"Classifying packets in: {pcap_file_path}")
    
    try:
        from scapy.all import rdpcap
        packets = rdpcap(pcap_file_path)
        
        results = []
        for i, packet in enumerate(packets):
            predicted_class, confidence = trained_classifier.predict_packet_class(packet)
            results.append({
                'packet_id': i,
                'predicted_class': predicted_class,
                'confidence': confidence
            })
            
            # Print first 10 predictions as examples
            if i < 10:
                print(f"Packet {i}: {predicted_class} (confidence: {confidence:.3f})")
        
        return results
        
    except Exception as e:
        print(f"Error: {e}")
        return None

# Additional utility functions
def list_pcap_files(folder_path):
    """List all pcap files in a folder"""
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist")
        return []
    
    pcap_patterns = ['*.pcap', '*.pcapng', '*.cap']
    pcap_files = []
    
    for pattern in pcap_patterns:
        pcap_files.extend(glob.glob(os.path.join(folder_path, pattern)))
    
    return pcap_files

def get_file_info(folder_path):
    """Get information about pcap files in folder"""
    files = list_pcap_files(folder_path)
    
    print(f"PCAP Files in '{folder_path}':")
    print("-" * 60)
    
    if not files:
        print("No pcap files found")
        return
    
    total_size = 0
    for file in files:
        size = os.path.getsize(file)
        total_size += size
        print(f"{os.path.basename(file):30} {size/1024/1024:.2f} MB")
    
    print("-" * 60)
    print(f"Total files: {len(files)}")
    print(f"Total size: {total_size/1024/1024:.2f} MB")

if __name__ == "__main__":
    # Uncomment to see file info first
    # get_file_info("./pcap_files")
    
    main()
# Out:
# Network Packet Classification ML Model
# ==================================================
# Scanning folder: E:\pcap
# Found 231 pcap files:
#   - 6to4.pcap
#   - aaa.pcap
#   - abis-accept-network.pcap
#   - abis-reject-network.pcap
#   - airtunes-1.pcap
#   - alp-sample1.pcap
#   - alp-sample2.pcap
#   - anony-tcp-std.pcap
#   - ansi_map_ota.pcap
#   - ansi_map_win.pcap
#   - ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#   - Apple_IP-over-IEEE_1394_Packet.pcap
#   - arp-storm.pcap
#   - Asterisk_ZFONE_XLITE.pcap
#   - bfd-raw-auth-md5.pcap
#   - bfd-raw-auth-sha1.pcap
#   - bgpsec.pcap
#   - bgp_shutdown_communication.pcap
#   - bicc.pcap
#   - BITTORRENT.pcap
#   - bmp.pcap
#   - c1222_over_ipv6.pcap
#   - c1222_std_example8.pcap
#   - camel.pcap
#   - camel2.pcap
#   - can-2003-0003.pcap
#   - cdp.pcap
#   - cdp_v2.pcap
#   - ch11-25-slt.pcap
#   - chargen-tcp.pcap
#   - chargen-udp.pcap
#   - cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#   - cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#   - coap-cbor.pcap
#   - couchbase-lww.pcap
#   - couchbase_subdoc_multi.pcap
#   - dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#   - dhcp-nanosecond.pcap
#   - dhcp.pcap
#   - dhcpv6_1.pcap
#   - DICOM_C-ECHO-echoscu.pcap
#   - dlep.pcap
#   - dnp3_read.pcap
#   - dnp3_select_operate.pcap
#   - dnp3_write.pcap
#   - dns-remoteshell.pcap
#   - dns_port.pcap
#   - DTMFsipinfo.pcap
#   - dvb-ci_1.pcap
#   - dvb-ci_2.pcap
#   - dvb-ci_UV1_0000.pcap
#   - eapol-mka.pcap
#   - ecpri.pcap
#   - eia709.1-over-eia852.pcap
#   - eigrp-for-ipv6-auth.pcap
#   - eigrp-for-ipv6-stub.pcap
#   - eigrp-for-ipv6-updates.pcap
#   - eigrp-ipx.pcap
#   - epmd.pcap
#   - exablaze_trailer.pcap
#   - exec-sample.pcap
#   - FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#   - fix-ssl.pcap
#   - fix.pcap
#   - fuzz-2008-09-30-17714.pcap
#   - gopher.pcap
#   - greb_filterlist.pcap
#   - gsm-r.uus1.pcap
#   - gsm_map_with_ussd_string.pcap
#   - h263-over-rtp.pcap
#   - hart_ip.pcap
#   - hcrt.pcap
#   - hdcp_authentication_sample.pcap
#   - homeplug_network_statistics_basic.pcap
#   - homeplug_request_channel_estimation.pcap
#   - homeplug_request_parameters_and_statistics.pcap
#   - hsrp.pcap
#   - http-chunked-gzip.pcap
#   - iec104.pcap
#   - IGMP-dataset.pcap
#   - infiniband.pcap
#   - iperf-mptcp-0-0.pcap
#   - ipmb.multi.packets.pcap
#   - ipmi.SDR.FRU.SEL.pcap
#   - ipmi.sensor.event.RR.pcap
#   - ipp.pcap
#   - ipv4frags.pcap
#   - ipv4_cipso_option.pcap
#   - isup_load_generator.pcap
#   - jaeger-compact.pcap
#   - japan_tcap_over_m2pa.pcap
#   - jxta-mcast-sample.pcap
#   - jxta-sample.pcap
#   - kismet-client-server-dump-1.pcap
#   - ldap-and-search.pcap
#   - ldap-attribute-value-list.pcap
#   - ldap-extensible-match-with-dn.pcap
#   - ldap-extensible-match.pcap
#   - ldap-substring.pcap
#   - lldp.detailed.pcap
#   - lldp.minimal.pcap
#   - lldpmed_civicloc.pcap
#   - llt-sample.pcap
#   - macsec_cisco_trunk.pcap
#   - mdb_bill_validator.pcap
#   - mdb_cashless_1.pcap
#   - mesh.pcap
#   - metamako_trailer.pcap
#   - metasploit-sip-invite-spoof.pcap
#   - MGCP.pcap
#   - mndp.pcap
#   - Mobile-Originating-Call(AMR).pcap
#   - Mobile-Terminating-Call(AMR).pcap
#   - mouse_replug2.pcap
#   - mp4-ftyp-styp-sidx.pcap
#   - mpeg2_mp2t_with_cc_drop01.pcap
#   - msgpack-generated.pcap
#   - msnms.pcap
#   - mysql_complete.pcap
#   - nano.pcap
#   - nano_tcp.pcap
#   - nb6-hotspot.pcap
#   - nb6-http.pcap
#   - nb6-startup.pcap
#   - nb6-telephone.pcap
#   - netlink-conntrack.pcap
#   - netlink-ipset.pcap
#   - netlink-nflog.pcap
#   - netlink.pcap
#   - Network_Join_Nokia_Mobile.pcap
#   - new_rfp.pcap
#   - new_rfp_on_wire.pcap
#   - nflog.pcap
#   - nlmon-big.pcap
#   - nntp.pcap
#   - notifyLTE.pcap
#   - nspi.pcap
#   - NTLM-wenchao.pcap
#   - NTP_sync.pcap
#   - opensafety_epl_trace.pcap
#   - opensafety_sercosiii_trace.pcap
#   - opensafety_udp_trace.pcap
#   - OptoMMP.pcap
#   - p772-transfer-success.pcap
#   - policy-authorizeNV.pcap
#   - ppp_lcp_ipcp.pcap
#   - ptpv2.pcap
#   - pvfs2-sample.pcap
#   - rsasnakeoil2.pcap
#   - rtp-norm-transfer.pcap
#   - rtp-opus-only.pcap
#   - s101glow.pcap
#   - S5066-Expedited.pcap
#   - S5066-HFChat-1.pcap
#   - S5066-HFChat-Rejected.pcap
#   - s7comm_downloading_block_db1.pcap
#   - s7comm_program_blocklist_onlineview.pcap
#   - s7comm_reading_plc_status.pcap
#   - s7comm_reading_setting_plc_time.pcap
#   - s7comm_varservice_libnodavedemo.pcap
#   - s7comm_varservice_libnodavedemo_bench.pcap
#   - sbus.pcap
#   - scsi-osd-example-001.pcap
#   - segmented_fpm.pcap
#   - SIMULCRYPT.pcap
#   - sip-rtp-dvi4.pcap
#   - sip-rtp-g711.pcap
#   - sip-rtp-g722.pcap
#   - sip-rtp-g726.pcap
#   - sip-rtp-g729a.pcap
#   - sip-rtp-gsm.pcap
#   - sip-rtp-ilbc.pcap
#   - sip-rtp-l16.pcap
#   - sip-rtp-lpc.pcap
#   - sip-rtp-opus-hybrid.pcap
#   - sip-rtp-opus.pcap
#   - sip-rtp-speex.pcap
#   - siso_std_002_annex_b_example.pcap
#   - siso_std_002_transmitter.pcap
#   - smb3-aes-128-ccm.pcap
#   - smb311-aes-128-ccm-filt.pcap
#   - smtp.pcap
#   - snakeoil-dtls.pcap
#   - snmp_usm.pcap
#   - sr-header.pcap
#   - stanag-5602-simple-example.pcap
#   - Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#   - steam-ihs-discovery.pcap
#   - stp.pcap
#   - tcp-ecn-sample.pcap
#   - TeamSpeak2.pcap
#   - telecomitalia-pppoe.pcap
#   - telnet-cooked.pcap
#   - telnet-raw.pcap
#   - Teredo.pcap
#   - tftp_rrq.pcap
#   - tftp_wrq.pcap
#   - tipc-publication-payload-withdrawal.pcap
#   - TNS_Oracle1.pcap
#   - TNS_Oracle2.pcap
#   - TNS_Oracle3.pcap
#   - TNS_Oracle4.pcap
#   - TNS_Oracle5.pcap
#   - tpncp_tcp.pcap
#   - tpncp_udp.pcap
#   - TTE_mix_small.pcap
#   - tunnel.pcap
#   - ua3g_freeseating_ipv4.pcap
#   - ua3g_freeseating_ipv6.pcap
#   - uaudp_ipv6.pcap
#   - udp-nm_anon.pcap
#   - udp_lite_checksum_0.pcap
#   - udp_lite_full_coverage_0.pcap
#   - udp_lite_illegal_1-7.pcap
#   - udp_lite_illegal_large-coverage.pcap
#   - udp_lite_normal_coverage_8-20.pcap
#   - UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#   - unistim-call.pcap
#   - usb_memory_stick.pcap
#   - usb_memory_stick_create_file.pcap
#   - usb_memory_stick_delete_file.pcap
#   - UserLog.pcap
#   - v6.pcap
#   - VariousUSBDevices.pcap
#   - vnc-sample.pcap
#   - wap_google.pcap
#   - win_s4u2self.pcap
#   - wpa-Induction.pcap
#   - x400-ping-refuse.pcap
#   - x400-ping-success.pcap
#   - yami.pcap
#
# [1/231] Processing 6to4.pcap
# Loading packets from E:\pcap\6to4.pcap...
# Loaded 5 packets from 6to4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from 6to4.pcap
#
# [2/231] Processing aaa.pcap
# Loading packets from E:\pcap\aaa.pcap...
# Loaded 691 packets from aaa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 691 packets from aaa.pcap
#
# [3/231] Processing abis-accept-network.pcap
# Loading packets from E:\pcap\abis-accept-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 85 packets from abis-accept-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from abis-accept-network.pcap
#
# [4/231] Processing abis-reject-network.pcap
# Loading packets from E:\pcap\abis-reject-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 78 packets from abis-reject-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from abis-reject-network.pcap
#
# [5/231] Processing airtunes-1.pcap
# Loading packets from E:\pcap\airtunes-1.pcap...
# Loaded 1748 packets from airtunes-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1748 packets from airtunes-1.pcap
#
# [6/231] Processing alp-sample1.pcap
# Loading packets from E:\pcap\alp-sample1.pcap...
# WARNING: more PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 17 packets from alp-sample1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from alp-sample1.pcap
#
# [7/231] Processing alp-sample2.pcap
# Loading packets from E:\pcap\alp-sample2.pcap...
# Loaded 85 packets from alp-sample2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from alp-sample2.pcap
#
# [8/231] Processing anony-tcp-std.pcap
# Loading packets from E:\pcap\anony-tcp-std.pcap...
# Loaded 170 packets from anony-tcp-std.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 170 packets from anony-tcp-std.pcap
#
# [9/231] Processing ansi_map_ota.pcap
# Loading packets from E:\pcap\ansi_map_ota.pcap...
# Loaded 24 packets from ansi_map_ota.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from ansi_map_ota.pcap
#
# [10/231] Processing ansi_map_win.pcap
# Loading packets from E:\pcap\ansi_map_win.pcap...
# Loaded 9 packets from ansi_map_win.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from ansi_map_win.pcap
#
# [11/231] Processing ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Loading packets from E:\pcap\ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap...
# Loaded 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#
# [12/231] Processing Apple_IP-over-IEEE_1394_Packet.pcap
# Loading packets from E:\pcap\Apple_IP-over-IEEE_1394_Packet.pcap...
# Loaded 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
#
# [13/231] Processing arp-storm.pcap
# Loading packets from E:\pcap\arp-storm.pcap...
# Loaded 622 packets from arp-storm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 622 packets from arp-storm.pcap
#
# [14/231] Processing Asterisk_ZFONE_XLITE.pcap
# Loading packets from E:\pcap\Asterisk_ZFONE_XLITE.pcap...
# Loaded 1042 packets from Asterisk_ZFONE_XLITE.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1042 packets from Asterisk_ZFONE_XLITE.pcap
#
# [15/231] Processing bfd-raw-auth-md5.pcap
# Loading packets from E:\pcap\bfd-raw-auth-md5.pcap...
# Loaded 31 packets from bfd-raw-auth-md5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 31 packets from bfd-raw-auth-md5.pcap
#
# [16/231] Processing bfd-raw-auth-sha1.pcap
# Loading packets from E:\pcap\bfd-raw-auth-sha1.pcap...
# Loaded 25 packets from bfd-raw-auth-sha1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from bfd-raw-auth-sha1.pcap
#
# [17/231] Processing bgpsec.pcap
# Loading packets from E:\pcap\bgpsec.pcap...
# Loaded 1127 packets from bgpsec.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1127 packets from bgpsec.pcap
#
# [18/231] Processing bgp_shutdown_communication.pcap
# Loading packets from E:\pcap\bgp_shutdown_communication.pcap...
# Loaded 9 packets from bgp_shutdown_communication.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from bgp_shutdown_communication.pcap
#
# [19/231] Processing bicc.pcap
# Loading packets from E:\pcap\bicc.pcap...
# Loaded 1 packets from bicc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from bicc.pcap
#
# [20/231] Processing BITTORRENT.pcap
# Loading packets from E:\pcap\BITTORRENT.pcap...
# Loaded 53 packets from BITTORRENT.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 53 packets from BITTORRENT.pcap
#
# [21/231] Processing bmp.pcap
# Loading packets from E:\pcap\bmp.pcap...
# Loaded 39 packets from bmp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from bmp.pcap
#
# [22/231] Processing c1222_over_ipv6.pcap
# Loading packets from E:\pcap\c1222_over_ipv6.pcap...
# Loaded 11 packets from c1222_over_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 11 packets from c1222_over_ipv6.pcap
#
# [23/231] Processing c1222_std_example8.pcap
# Loading packets from E:\pcap\c1222_std_example8.pcap...
# Loaded 2 packets from c1222_std_example8.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from c1222_std_example8.pcap
#
# [24/231] Processing camel.pcap
# Loading packets from E:\pcap\camel.pcap...
# Loaded 5 packets from camel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from camel.pcap
#
# [25/231] Processing camel2.pcap
# Loading packets from E:\pcap\camel2.pcap...
# Loaded 4 packets from camel2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from camel2.pcap
#
# [26/231] Processing can-2003-0003.pcap
# Loading packets from E:\pcap\can-2003-0003.pcap...
# Loaded 27 packets from can-2003-0003.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 27 packets from can-2003-0003.pcap
#
# [27/231] Processing cdp.pcap
# Loading packets from E:\pcap\cdp.pcap...
# Loaded 1 packets from cdp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from cdp.pcap
#
# [28/231] Processing cdp_v2.pcap
# Loading packets from E:\pcap\cdp_v2.pcap...
# Loaded 4 packets from cdp_v2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from cdp_v2.pcap
#
# [29/231] Processing ch11-25-slt.pcap
# Loading packets from E:\pcap\ch11-25-slt.pcap...
# Loaded 68 packets from ch11-25-slt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from ch11-25-slt.pcap
#
# [30/231] Processing chargen-tcp.pcap
# Loading packets from E:\pcap\chargen-tcp.pcap...
# Loaded 22 packets from chargen-tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from chargen-tcp.pcap
#
# [31/231] Processing chargen-udp.pcap
# Loading packets from E:\pcap\chargen-udp.pcap...
# Loaded 2 packets from chargen-udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from chargen-udp.pcap
#
# [32/231] Processing cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_-OpenSSL-EJBCA.pcap...
# Loaded 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#
# [33/231] Processing cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_OpenSSL-Cryptlib.pcap...
# Loaded 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#
# [34/231] Processing coap-cbor.pcap
# Loading packets from E:\pcap\coap-cbor.pcap...
# Loaded 164 packets from coap-cbor.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 164 packets from coap-cbor.pcap
#
# [35/231] Processing couchbase-lww.pcap
# Loading packets from E:\pcap\couchbase-lww.pcap...
# Loaded 240 packets from couchbase-lww.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 240 packets from couchbase-lww.pcap
#
# [36/231] Processing couchbase_subdoc_multi.pcap
# Loading packets from E:\pcap\couchbase_subdoc_multi.pcap...
# Loaded 477 packets from couchbase_subdoc_multi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 477 packets from couchbase_subdoc_multi.pcap
#
# [37/231] Processing dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Loading packets from E:\pcap\dcerpc-winreg-with-rpc-sec-verification-trailer.pcap...
# Loaded 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#
# [38/231] Processing dhcp-nanosecond.pcap
# Loading packets from E:\pcap\dhcp-nanosecond.pcap...
# Loaded 4 packets from dhcp-nanosecond.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp-nanosecond.pcap
#
# [39/231] Processing dhcp.pcap
# Loading packets from E:\pcap\dhcp.pcap...
# Loaded 4 packets from dhcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp.pcap
#
# [40/231] Processing dhcpv6_1.pcap
# Loading packets from E:\pcap\dhcpv6_1.pcap...
# Loaded 10 packets from dhcpv6_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from dhcpv6_1.pcap
#
# [41/231] Processing DICOM_C-ECHO-echoscu.pcap
# Loading packets from E:\pcap\DICOM_C-ECHO-echoscu.pcap...
# Loaded 25 packets from DICOM_C-ECHO-echoscu.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from DICOM_C-ECHO-echoscu.pcap
#
# [42/231] Processing dlep.pcap
# Loading packets from E:\pcap\dlep.pcap...
# Loaded 23 packets from dlep.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from dlep.pcap
#
# [43/231] Processing dnp3_read.pcap
# Loading packets from E:\pcap\dnp3_read.pcap...
# Loaded 8 packets from dnp3_read.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_read.pcap
#
# [44/231] Processing dnp3_select_operate.pcap
# Loading packets from E:\pcap\dnp3_select_operate.pcap...
# Loaded 12 packets from dnp3_select_operate.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from dnp3_select_operate.pcap
#
# [45/231] Processing dnp3_write.pcap
# Loading packets from E:\pcap\dnp3_write.pcap...
# Loaded 8 packets from dnp3_write.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_write.pcap
#
# [46/231] Processing dns-remoteshell.pcap
# Loading packets from E:\pcap\dns-remoteshell.pcap...
# Loaded 131 packets from dns-remoteshell.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 131 packets from dns-remoteshell.pcap
#
# [47/231] Processing dns_port.pcap
# Loading packets from E:\pcap\dns_port.pcap...
# Loaded 2 packets from dns_port.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from dns_port.pcap
#
# [48/231] Processing DTMFsipinfo.pcap
# Loading packets from E:\pcap\DTMFsipinfo.pcap...
# Loaded 32 packets from DTMFsipinfo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from DTMFsipinfo.pcap
#
# [49/231] Processing dvb-ci_1.pcap
# Loading packets from E:\pcap\dvb-ci_1.pcap...
# Loaded 396 packets from dvb-ci_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 396 packets from dvb-ci_1.pcap
#
# [50/231] Processing dvb-ci_2.pcap
# Loading packets from E:\pcap\dvb-ci_2.pcap...
# Loaded 273 packets from dvb-ci_2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from dvb-ci_2.pcap
#
# [51/231] Processing dvb-ci_UV1_0000.pcap
# Loading packets from E:\pcap\dvb-ci_UV1_0000.pcap...
# Loaded 1 packets from dvb-ci_UV1_0000.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from dvb-ci_UV1_0000.pcap
#
# [52/231] Processing eapol-mka.pcap
# Loading packets from E:\pcap\eapol-mka.pcap...
# Loaded 68 packets from eapol-mka.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from eapol-mka.pcap
#
# [53/231] Processing ecpri.pcap
# Loading packets from E:\pcap\ecpri.pcap...
# Loaded 18 packets from ecpri.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 18 packets from ecpri.pcap
#
# [54/231] Processing eia709.1-over-eia852.pcap
# Loading packets from E:\pcap\eia709.1-over-eia852.pcap...
# Loaded 12028 packets from eia709.1-over-eia852.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
# Extracted features for 12028 packets from eia709.1-over-eia852.pcap
#
# [55/231] Processing eigrp-for-ipv6-auth.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-auth.pcap...
# Loaded 570 packets from eigrp-for-ipv6-auth.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 570 packets from eigrp-for-ipv6-auth.pcap
#
# [56/231] Processing eigrp-for-ipv6-stub.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-stub.pcap...
# Loaded 273 packets from eigrp-for-ipv6-stub.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from eigrp-for-ipv6-stub.pcap
#
# [57/231] Processing eigrp-for-ipv6-updates.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-updates.pcap...
# Loaded 421 packets from eigrp-for-ipv6-updates.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 421 packets from eigrp-for-ipv6-updates.pcap
#
# [58/231] Processing eigrp-ipx.pcap
# Loading packets from E:\pcap\eigrp-ipx.pcap...
# WARNING: PcapReader: unknown LL type [104]/[0x68]. Using Raw packets
# Loaded 74 packets from eigrp-ipx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 74 packets from eigrp-ipx.pcap
#
# [59/231] Processing epmd.pcap
# Loading packets from E:\pcap\epmd.pcap...
# Loaded 10 packets from epmd.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from epmd.pcap
#
# [60/231] Processing exablaze_trailer.pcap
# Loading packets from E:\pcap\exablaze_trailer.pcap...
# Loaded 24 packets from exablaze_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from exablaze_trailer.pcap
#
# [61/231] Processing exec-sample.pcap
# Loading packets from E:\pcap\exec-sample.pcap...
# Loaded 14 packets from exec-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from exec-sample.pcap
#
# [62/231] Processing FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Loading packets from E:\pcap\FAX-Call-t38-CA-TDM-SIP-FB-1.pcap...
# Loaded 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
# Extracted features for 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#
# [63/231] Processing fix-ssl.pcap
# Loading packets from E:\pcap\fix-ssl.pcap...
# Loaded 1237 packets from fix-ssl.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1237 packets from fix-ssl.pcap
#
# [64/231] Processing fix.pcap
# Loading packets from E:\pcap\fix.pcap...
# Loaded 485 packets from fix.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 485 packets from fix.pcap
#
# [65/231] Processing fuzz-2008-09-30-17714.pcap
# Loading packets from E:\pcap\fuzz-2008-09-30-17714.pcap...
# Loaded 68294 packets from fuzz-2008-09-30-17714.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
#   Processed 32000 packets...
#   Processed 33000 packets...
#   Processed 34000 packets...
#   Processed 35000 packets...
#   Processed 36000 packets...
#   Processed 37000 packets...
#   Processed 38000 packets...
#   Processed 39000 packets...
#   Processed 40000 packets...
#   Processed 41000 packets...
#   Processed 42000 packets...
#   Processed 43000 packets...
#   Processed 44000 packets...
#   Processed 45000 packets...
#   Processed 46000 packets...
#   Processed 47000 packets...
#   Processed 48000 packets...
#   Processed 49000 packets...
#   Processed 50000 packets...
#   Processed 51000 packets...
#   Processed 52000 packets...
#   Processed 53000 packets...
#   Processed 54000 packets...
#   Processed 55000 packets...
#   Processed 56000 packets...
#   Processed 57000 packets...
#   Processed 58000 packets...
#   Processed 59000 packets...
#   Processed 60000 packets...
#   Processed 61000 packets...
#   Processed 62000 packets...
#   Processed 63000 packets...
#   Processed 64000 packets...
#   Processed 65000 packets...
#   Processed 66000 packets...
#   Processed 67000 packets...
#   Processed 68000 packets...
# Extracted features for 68294 packets from fuzz-2008-09-30-17714.pcap
#
# [66/231] Processing gopher.pcap
# Loading packets from E:\pcap\gopher.pcap...
# Loaded 92 packets from gopher.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from gopher.pcap
#
# [67/231] Processing greb_filterlist.pcap
# Loading packets from E:\pcap\greb_filterlist.pcap...
# Loaded 1 packets from greb_filterlist.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from greb_filterlist.pcap
#
# [68/231] Processing gsm-r.uus1.pcap
# Loading packets from E:\pcap\gsm-r.uus1.pcap...
# WARNING: PcapReader: unknown LL type [141]/[0x8d]. Using Raw packets
# Loaded 9 packets from gsm-r.uus1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from gsm-r.uus1.pcap
#
# [69/231] Processing gsm_map_with_ussd_string.pcap
# Loading packets from E:\pcap\gsm_map_with_ussd_string.pcap...
# Loaded 1 packets from gsm_map_with_ussd_string.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from gsm_map_with_ussd_string.pcap
#
# [70/231] Processing h263-over-rtp.pcap
# Loading packets from E:\pcap\h263-over-rtp.pcap...
# Loaded 49 packets from h263-over-rtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 49 packets from h263-over-rtp.pcap
#
# [71/231] Processing hart_ip.pcap
# Loading packets from E:\pcap\hart_ip.pcap...
# Loaded 116 packets from hart_ip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from hart_ip.pcap
#
# [72/231] Processing hcrt.pcap
# Loading packets from E:\pcap\hcrt.pcap...
# Loaded 10 packets from hcrt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from hcrt.pcap
#
# [73/231] Processing hdcp_authentication_sample.pcap
# Loading packets from E:\pcap\hdcp_authentication_sample.pcap...
# Loaded 8 packets from hdcp_authentication_sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from hdcp_authentication_sample.pcap
#
# [74/231] Processing homeplug_network_statistics_basic.pcap
# Loading packets from E:\pcap\homeplug_network_statistics_basic.pcap...
# Loaded 1 packets from homeplug_network_statistics_basic.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_network_statistics_basic.pcap
#
# [75/231] Processing homeplug_request_channel_estimation.pcap
# Loading packets from E:\pcap\homeplug_request_channel_estimation.pcap...
# Loaded 1 packets from homeplug_request_channel_estimation.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_channel_estimation.pcap
#
# [76/231] Processing homeplug_request_parameters_and_statistics.pcap
# Loading packets from E:\pcap\homeplug_request_parameters_and_statistics.pcap...
# Loaded 1 packets from homeplug_request_parameters_and_statistics.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_parameters_and_statistics.pcap
#
# [77/231] Processing hsrp.pcap
# Loading packets from E:\pcap\hsrp.pcap...
# Loaded 100 packets from hsrp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from hsrp.pcap
#
# [78/231] Processing http-chunked-gzip.pcap
# Loading packets from E:\pcap\http-chunked-gzip.pcap...
# Loaded 28 packets from http-chunked-gzip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from http-chunked-gzip.pcap
#
# [79/231] Processing iec104.pcap
# Loading packets from E:\pcap\iec104.pcap...
# Loaded 105 packets from iec104.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from iec104.pcap
#
# [80/231] Processing IGMP-dataset.pcap
# Loading packets from E:\pcap\IGMP-dataset.pcap...
# Loaded 147 packets from IGMP-dataset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 147 packets from IGMP-dataset.pcap
#
# [81/231] Processing infiniband.pcap
# Loading packets from E:\pcap\infiniband.pcap...
# WARNING: PcapReader: unknown LL type [197]/[0xc5]. Using Raw packets
# Loaded 43 packets from infiniband.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 43 packets from infiniband.pcap
#
# [82/231] Processing iperf-mptcp-0-0.pcap
# Loading packets from E:\pcap\iperf-mptcp-0-0.pcap...
# Loaded 2560 packets from iperf-mptcp-0-0.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2560 packets from iperf-mptcp-0-0.pcap
#
# [83/231] Processing ipmb.multi.packets.pcap
# Loading packets from E:\pcap\ipmb.multi.packets.pcap...
# WARNING: more PcapReader: unknown LL type [199]/[0xc7]. Using Raw packets
# Loaded 357 packets from ipmb.multi.packets.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 357 packets from ipmb.multi.packets.pcap
#
# [84/231] Processing ipmi.SDR.FRU.SEL.pcap
# Loading packets from E:\pcap\ipmi.SDR.FRU.SEL.pcap...
# Loaded 1138 packets from ipmi.SDR.FRU.SEL.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1138 packets from ipmi.SDR.FRU.SEL.pcap
#
# [85/231] Processing ipmi.sensor.event.RR.pcap
# Loading packets from E:\pcap\ipmi.sensor.event.RR.pcap...
# Loaded 726 packets from ipmi.sensor.event.RR.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 726 packets from ipmi.sensor.event.RR.pcap
#
# [86/231] Processing ipp.pcap
# Loading packets from E:\pcap\ipp.pcap...
# Loaded 279 packets from ipp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 279 packets from ipp.pcap
#
# [87/231] Processing ipv4frags.pcap
# Loading packets from E:\pcap\ipv4frags.pcap...
# Loaded 3 packets from ipv4frags.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from ipv4frags.pcap
#
# [88/231] Processing ipv4_cipso_option.pcap
# Loading packets from E:\pcap\ipv4_cipso_option.pcap...
# Loaded 6 packets from ipv4_cipso_option.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from ipv4_cipso_option.pcap
#
# [89/231] Processing isup_load_generator.pcap
# Loading packets from E:\pcap\isup_load_generator.pcap...
# Loaded 5265 packets from isup_load_generator.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
# Extracted features for 5265 packets from isup_load_generator.pcap
#
# [90/231] Processing jaeger-compact.pcap
# Loading packets from E:\pcap\jaeger-compact.pcap...
# Loaded 2 packets from jaeger-compact.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from jaeger-compact.pcap
#
# [91/231] Processing japan_tcap_over_m2pa.pcap
# Loading packets from E:\pcap\japan_tcap_over_m2pa.pcap...
# Loaded 6 packets from japan_tcap_over_m2pa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from japan_tcap_over_m2pa.pcap
#
# [92/231] Processing jxta-mcast-sample.pcap
# Loading packets from E:\pcap\jxta-mcast-sample.pcap...
# Loaded 401 packets from jxta-mcast-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 401 packets from jxta-mcast-sample.pcap
#
# [93/231] Processing jxta-sample.pcap
# Loading packets from E:\pcap\jxta-sample.pcap...
# Loaded 255 packets from jxta-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 255 packets from jxta-sample.pcap
#
# [94/231] Processing kismet-client-server-dump-1.pcap
# Loading packets from E:\pcap\kismet-client-server-dump-1.pcap...
# Loaded 35 packets from kismet-client-server-dump-1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 35 packets from kismet-client-server-dump-1.pcap
#
# [95/231] Processing ldap-and-search.pcap
# Loading packets from E:\pcap\ldap-and-search.pcap...
# Loaded 13 packets from ldap-and-search.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-and-search.pcap
#
# [96/231] Processing ldap-attribute-value-list.pcap
# Loading packets from E:\pcap\ldap-attribute-value-list.pcap...
# Loaded 13 packets from ldap-attribute-value-list.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-attribute-value-list.pcap
#
# [97/231] Processing ldap-extensible-match-with-dn.pcap
# Loading packets from E:\pcap\ldap-extensible-match-with-dn.pcap...
# Loaded 13 packets from ldap-extensible-match-with-dn.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match-with-dn.pcap
#
# [98/231] Processing ldap-extensible-match.pcap
# Loading packets from E:\pcap\ldap-extensible-match.pcap...
# Loaded 13 packets from ldap-extensible-match.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match.pcap
#
# [99/231] Processing ldap-substring.pcap
# Loading packets from E:\pcap\ldap-substring.pcap...
# Loaded 26 packets from ldap-substring.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 26 packets from ldap-substring.pcap
#
# [100/231] Processing lldp.detailed.pcap
# Loading packets from E:\pcap\lldp.detailed.pcap...
# Loaded 1 packets from lldp.detailed.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.detailed.pcap
#
# [101/231] Processing lldp.minimal.pcap
# Loading packets from E:\pcap\lldp.minimal.pcap...
# Loaded 1 packets from lldp.minimal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.minimal.pcap
#
# [102/231] Processing lldpmed_civicloc.pcap
# Loading packets from E:\pcap\lldpmed_civicloc.pcap...
# Loaded 1 packets from lldpmed_civicloc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldpmed_civicloc.pcap
#
# [103/231] Processing llt-sample.pcap
# Loading packets from E:\pcap\llt-sample.pcap...
# Loaded 10 packets from llt-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from llt-sample.pcap
#
# [104/231] Processing macsec_cisco_trunk.pcap
# Loading packets from E:\pcap\macsec_cisco_trunk.pcap...
# Loaded 1614 packets from macsec_cisco_trunk.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1614 packets from macsec_cisco_trunk.pcap
#
# [105/231] Processing mdb_bill_validator.pcap
# Loading packets from E:\pcap\mdb_bill_validator.pcap...
# Loaded 10 packets from mdb_bill_validator.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mdb_bill_validator.pcap
#
# [106/231] Processing mdb_cashless_1.pcap
# Loading packets from E:\pcap\mdb_cashless_1.pcap...
# Loaded 278 packets from mdb_cashless_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 278 packets from mdb_cashless_1.pcap
#
# [107/231] Processing mesh.pcap
# Loading packets from E:\pcap\mesh.pcap...
# Loaded 780 packets from mesh.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 780 packets from mesh.pcap
#
# [108/231] Processing metamako_trailer.pcap
# Loading packets from E:\pcap\metamako_trailer.pcap...
# Loaded 111 packets from metamako_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 111 packets from metamako_trailer.pcap
#
# [109/231] Processing metasploit-sip-invite-spoof.pcap
# Loading packets from E:\pcap\metasploit-sip-invite-spoof.pcap...
# Loaded 3 packets from metasploit-sip-invite-spoof.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from metasploit-sip-invite-spoof.pcap
#
# [110/231] Processing MGCP.pcap
# Loading packets from E:\pcap\MGCP.pcap...
# Loaded 14 packets from MGCP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from MGCP.pcap
#
# [111/231] Processing mndp.pcap
# Loading packets from E:\pcap\mndp.pcap...
# Loaded 10 packets from mndp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mndp.pcap
#
# [112/231] Processing Mobile-Originating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Originating-Call(AMR).pcap...
# Loaded 299 packets from Mobile-Originating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 299 packets from Mobile-Originating-Call(AMR).pcap
#
# [113/231] Processing Mobile-Terminating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Terminating-Call(AMR).pcap...
# Loaded 308 packets from Mobile-Terminating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 308 packets from Mobile-Terminating-Call(AMR).pcap
#
# [114/231] Processing mouse_replug2.pcap
# Loading packets from E:\pcap\mouse_replug2.pcap...
# WARNING: PcapReader: unknown LL type [186]/[0xba]. Using Raw packets
# Loaded 17 packets from mouse_replug2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from mouse_replug2.pcap
#
# [115/231] Processing mp4-ftyp-styp-sidx.pcap
# Loading packets from E:\pcap\mp4-ftyp-styp-sidx.pcap...
# WARNING: PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 5 packets from mp4-ftyp-styp-sidx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from mp4-ftyp-styp-sidx.pcap
#
# [116/231] Processing mpeg2_mp2t_with_cc_drop01.pcap
# Loading packets from E:\pcap\mpeg2_mp2t_with_cc_drop01.pcap...
# Loaded 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
#
# [117/231] Processing msgpack-generated.pcap
# Loading packets from E:\pcap\msgpack-generated.pcap...
# WARNING: more PcapReader: unknown LL type [252]/[0xfc]. Using Raw packets
# Loaded 23 packets from msgpack-generated.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from msgpack-generated.pcap
#
# [118/231] Processing msnms.pcap
# Loading packets from E:\pcap\msnms.pcap...
# Loaded 364 packets from msnms.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 364 packets from msnms.pcap
#
# [119/231] Processing mysql_complete.pcap
# Loading packets from E:\pcap\mysql_complete.pcap...
# Loaded 57 packets from mysql_complete.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 57 packets from mysql_complete.pcap
#
# [120/231] Processing nano.pcap
# Loading packets from E:\pcap\nano.pcap...
# Loaded 2500 packets from nano.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2500 packets from nano.pcap
#
# [121/231] Processing nano_tcp.pcap
# Loading packets from E:\pcap\nano_tcp.pcap...
# Loaded 117 packets from nano_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from nano_tcp.pcap
#
# [122/231] Processing nb6-hotspot.pcap
# Loading packets from E:\pcap\nb6-hotspot.pcap...
# Loaded 347 packets from nb6-hotspot.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 347 packets from nb6-hotspot.pcap
#
# [123/231] Processing nb6-http.pcap
# Loading packets from E:\pcap\nb6-http.pcap...
# Loaded 62 packets from nb6-http.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 62 packets from nb6-http.pcap
#
# [124/231] Processing nb6-startup.pcap
# Loading packets from E:\pcap\nb6-startup.pcap...
# Loaded 531 packets from nb6-startup.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 531 packets from nb6-startup.pcap
#
# [125/231] Processing nb6-telephone.pcap
# Loading packets from E:\pcap\nb6-telephone.pcap...
# Loaded 527 packets from nb6-telephone.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 527 packets from nb6-telephone.pcap
#
# [126/231] Processing netlink-conntrack.pcap
# Loading packets from E:\pcap\netlink-conntrack.pcap...
# Loaded 107 packets from netlink-conntrack.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 107 packets from netlink-conntrack.pcap
#
# [127/231] Processing netlink-ipset.pcap
# Loading packets from E:\pcap\netlink-ipset.pcap...
# Loaded 300 packets from netlink-ipset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 300 packets from netlink-ipset.pcap
#
# [128/231] Processing netlink-nflog.pcap
# Loading packets from E:\pcap\netlink-nflog.pcap...
# Loaded 22 packets from netlink-nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from netlink-nflog.pcap
#
# [129/231] Processing netlink.pcap
# Loading packets from E:\pcap\netlink.pcap...
# Loaded 673 packets from netlink.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 673 packets from netlink.pcap
#
# [130/231] Processing Network_Join_Nokia_Mobile.pcap
# Loading packets from E:\pcap\Network_Join_Nokia_Mobile.pcap...
# Loaded 1180 packets from Network_Join_Nokia_Mobile.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1180 packets from Network_Join_Nokia_Mobile.pcap
#
# [131/231] Processing new_rfp.pcap
# Loading packets from E:\pcap\new_rfp.pcap...
# Loaded 66 packets from new_rfp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from new_rfp.pcap
#
# [132/231] Processing new_rfp_on_wire.pcap
# Loading packets from E:\pcap\new_rfp_on_wire.pcap...
# Loaded 154 packets from new_rfp_on_wire.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 154 packets from new_rfp_on_wire.pcap
#
# [133/231] Processing nflog.pcap
# Loading packets from E:\pcap\nflog.pcap...
# Loaded 39 packets from nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from nflog.pcap
#
# [134/231] Processing nlmon-big.pcap
# Loading packets from E:\pcap\nlmon-big.pcap...
# Loaded 13 packets from nlmon-big.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from nlmon-big.pcap
#
# [135/231] Processing nntp.pcap
# Loading packets from E:\pcap\nntp.pcap...
# Loaded 32 packets from nntp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from nntp.pcap
#
# [136/231] Processing notifyLTE.pcap
# Loading packets from E:\pcap\notifyLTE.pcap...
# Loaded 1 packets from notifyLTE.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from notifyLTE.pcap
#
# [137/231] Processing nspi.pcap
# Loading packets from E:\pcap\nspi.pcap...
# Loaded 25 packets from nspi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from nspi.pcap
#
# [138/231] Processing NTLM-wenchao.pcap
# Loading packets from E:\pcap\NTLM-wenchao.pcap...
# Loaded 80 packets from NTLM-wenchao.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 80 packets from NTLM-wenchao.pcap
#
# [139/231] Processing NTP_sync.pcap
# Loading packets from E:\pcap\NTP_sync.pcap...
# Loaded 32 packets from NTP_sync.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from NTP_sync.pcap
#
# [140/231] Processing opensafety_epl_trace.pcap
# Loading packets from E:\pcap\opensafety_epl_trace.pcap...
# Loaded 31161 packets from opensafety_epl_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
# Extracted features for 31161 packets from opensafety_epl_trace.pcap
#
# [141/231] Processing opensafety_sercosiii_trace.pcap
# Loading packets from E:\pcap\opensafety_sercosiii_trace.pcap...
# Loaded 426 packets from opensafety_sercosiii_trace.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 426 packets from opensafety_sercosiii_trace.pcap
#
# [142/231] Processing opensafety_udp_trace.pcap
# Loading packets from E:\pcap\opensafety_udp_trace.pcap...
# Loaded 16036 packets from opensafety_udp_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
# Extracted features for 16036 packets from opensafety_udp_trace.pcap
#
# [143/231] Processing OptoMMP.pcap
# Loading packets from E:\pcap\OptoMMP.pcap...
# Loaded 20 packets from OptoMMP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 20 packets from OptoMMP.pcap
#
# [144/231] Processing p772-transfer-success.pcap
# Loading packets from E:\pcap\p772-transfer-success.pcap...
# Loaded 29 packets from p772-transfer-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from p772-transfer-success.pcap
#
# [145/231] Processing policy-authorizeNV.pcap
# Loading packets from E:\pcap\policy-authorizeNV.pcap...
# Loaded 117 packets from policy-authorizeNV.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from policy-authorizeNV.pcap
#
# [146/231] Processing ppp_lcp_ipcp.pcap
# Loading packets from E:\pcap\ppp_lcp_ipcp.pcap...
# Loaded 23 packets from ppp_lcp_ipcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from ppp_lcp_ipcp.pcap
#
# [147/231] Processing ptpv2.pcap
# Loading packets from E:\pcap\ptpv2.pcap...
# Loaded 39 packets from ptpv2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from ptpv2.pcap
#
# [148/231] Processing pvfs2-sample.pcap
# Loading packets from E:\pcap\pvfs2-sample.pcap...
# Loaded 44 packets from pvfs2-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 44 packets from pvfs2-sample.pcap
#
# [149/231] Processing rsasnakeoil2.pcap
# Loading packets from E:\pcap\rsasnakeoil2.pcap...
# Loaded 58 packets from rsasnakeoil2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 58 packets from rsasnakeoil2.pcap
#
# [150/231] Processing rtp-norm-transfer.pcap
# Loading packets from E:\pcap\rtp-norm-transfer.pcap...
# Loaded 226 packets from rtp-norm-transfer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 226 packets from rtp-norm-transfer.pcap
#
# [151/231] Processing rtp-opus-only.pcap
# Loading packets from E:\pcap\rtp-opus-only.pcap...
# Loaded 425 packets from rtp-opus-only.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 425 packets from rtp-opus-only.pcap
#
# [152/231] Processing s101glow.pcap
# Loading packets from E:\pcap\s101glow.pcap...
# ...
#
# [179/231] Processing siso_std_002_transmitter.pcap
# Loading packets from E:\pcap\siso_std_002_transmitter.pcap...
# Loaded 1 packets from siso_std_002_transmitter.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from siso_std_002_transmitter.pcap
#
# [180/231] Processing smb3-aes-128-ccm.pcap
# Loading packets from E:\pcap\smb3-aes-128-ccm.pcap...
# Loaded 54 packets from smb3-aes-128-ccm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 54 packets from smb3-aes-128-ccm.pcap
#
# [181/231] Processing smb311-aes-128-ccm-filt.pcap
# Loading packets from E:\pcap\smb311-aes-128-ccm-filt.pcap...
# Loaded 34 packets from smb311-aes-128-ccm-filt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 34 packets from smb311-aes-128-ccm-filt.pcap
#
# [182/231] Processing smtp.pcap
# Loading packets from E:\pcap\smtp.pcap...
# Loaded 60 packets from smtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 60 packets from smtp.pcap
#
# [183/231] Processing snakeoil-dtls.pcap
# Loading packets from E:\pcap\snakeoil-dtls.pcap...
# Loaded 9 packets from snakeoil-dtls.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from snakeoil-dtls.pcap
#
# [184/231] Processing snmp_usm.pcap
# Loading packets from E:\pcap\snmp_usm.pcap...
# Loaded 144 packets from snmp_usm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from snmp_usm.pcap
#
# [185/231] Processing sr-header.pcap
# Loading packets from E:\pcap\sr-header.pcap...
# Loaded 10 packets from sr-header.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from sr-header.pcap
#
# [186/231] Processing stanag-5602-simple-example.pcap
# Loading packets from E:\pcap\stanag-5602-simple-example.pcap...
# Loaded 2 packets from stanag-5602-simple-example.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from stanag-5602-simple-example.pcap
#
# [187/231] Processing Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Loading packets from E:\pcap\Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap...
# WARNING: PcapReader: unknown LL type [237]/[0xed]. Using Raw packets
# Loaded 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#
# [188/231] Processing steam-ihs-discovery.pcap
# Loading packets from E:\pcap\steam-ihs-discovery.pcap...
# Loaded 113 packets from steam-ihs-discovery.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 113 packets from steam-ihs-discovery.pcap
#
# [189/231] Processing stp.pcap
# Loading packets from E:\pcap\stp.pcap...
# Loaded 96 packets from stp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 96 packets from stp.pcap
#
# [190/231] Processing tcp-ecn-sample.pcap
# Loading packets from E:\pcap\tcp-ecn-sample.pcap...
# Loaded 479 packets from tcp-ecn-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 479 packets from tcp-ecn-sample.pcap
#
# [191/231] Processing TeamSpeak2.pcap
# Loading packets from E:\pcap\TeamSpeak2.pcap...
# Loaded 24 packets from TeamSpeak2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from TeamSpeak2.pcap
#
# [192/231] Processing telecomitalia-pppoe.pcap
# Loading packets from E:\pcap\telecomitalia-pppoe.pcap...
# Loaded 28 packets from telecomitalia-pppoe.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from telecomitalia-pppoe.pcap
#
# [193/231] Processing telnet-cooked.pcap
# Loading packets from E:\pcap\telnet-cooked.pcap...
# Loaded 92 packets from telnet-cooked.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from telnet-cooked.pcap
#
# [194/231] Processing telnet-raw.pcap
# Loading packets from E:\pcap\telnet-raw.pcap...
# Loaded 272 packets from telnet-raw.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 272 packets from telnet-raw.pcap
#
# [195/231] Processing Teredo.pcap
# Loading packets from E:\pcap\Teredo.pcap...
# Loaded 78 packets from Teredo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from Teredo.pcap
#
# [196/231] Processing tftp_rrq.pcap
# Loading packets from E:\pcap\tftp_rrq.pcap...
# Loaded 99 packets from tftp_rrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 99 packets from tftp_rrq.pcap
#
# [197/231] Processing tftp_wrq.pcap
# Loading packets from E:\pcap\tftp_wrq.pcap...
# Loaded 100 packets from tftp_wrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from tftp_wrq.pcap
#
# [198/231] Processing tipc-publication-payload-withdrawal.pcap
# Loading packets from E:\pcap\tipc-publication-payload-withdrawal.pcap...
# Loaded 40 packets from tipc-publication-payload-withdrawal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 40 packets from tipc-publication-payload-withdrawal.pcap
#
# [199/231] Processing TNS_Oracle1.pcap
# Loading packets from E:\pcap\TNS_Oracle1.pcap...
# Loaded 78 packets from TNS_Oracle1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from TNS_Oracle1.pcap
#
# [200/231] Processing TNS_Oracle2.pcap
# Loading packets from E:\pcap\TNS_Oracle2.pcap...
# Loaded 36 packets from TNS_Oracle2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle2.pcap
#
# [201/231] Processing TNS_Oracle3.pcap
# Loading packets from E:\pcap\TNS_Oracle3.pcap...
# Loaded 36 packets from TNS_Oracle3.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle3.pcap
#
# [202/231] Processing TNS_Oracle4.pcap
# Loading packets from E:\pcap\TNS_Oracle4.pcap...
# Loaded 10 packets from TNS_Oracle4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from TNS_Oracle4.pcap
#
# [203/231] Processing TNS_Oracle5.pcap
# Loading packets from E:\pcap\TNS_Oracle5.pcap...
# Loaded 56 packets from TNS_Oracle5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 56 packets from TNS_Oracle5.pcap
#
# [204/231] Processing tpncp_tcp.pcap
# Loading packets from E:\pcap\tpncp_tcp.pcap...
# Loaded 116 packets from tpncp_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from tpncp_tcp.pcap
#
# [205/231] Processing tpncp_udp.pcap
# Loading packets from E:\pcap\tpncp_udp.pcap...
# Loaded 132 packets from tpncp_udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 132 packets from tpncp_udp.pcap
#
# [206/231] Processing TTE_mix_small.pcap
# Loading packets from E:\pcap\TTE_mix_small.pcap...
# Loaded 25 packets from TTE_mix_small.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from TTE_mix_small.pcap
#
# [207/231] Processing tunnel.pcap
# Loading packets from E:\pcap\tunnel.pcap...
# Loaded 218 packets from tunnel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 218 packets from tunnel.pcap
#
# [208/231] Processing ua3g_freeseating_ipv4.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv4.pcap...
# Loaded 64 packets from ua3g_freeseating_ipv4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 64 packets from ua3g_freeseating_ipv4.pcap
#
# [209/231] Processing ua3g_freeseating_ipv6.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv6.pcap...
# Loaded 339 packets from ua3g_freeseating_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 339 packets from ua3g_freeseating_ipv6.pcap
#
# [210/231] Processing uaudp_ipv6.pcap
# Loading packets from E:\pcap\uaudp_ipv6.pcap...
# Loaded 2544 packets from uaudp_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2544 packets from uaudp_ipv6.pcap
#
# [211/231] Processing udp-nm_anon.pcap
# Loading packets from E:\pcap\udp-nm_anon.pcap...
# Loaded 1 packets from udp-nm_anon.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp-nm_anon.pcap
#
# [212/231] Processing udp_lite_checksum_0.pcap
# Loading packets from E:\pcap\udp_lite_checksum_0.pcap...
# Loaded 1 packets from udp_lite_checksum_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_checksum_0.pcap
#
# [213/231] Processing udp_lite_full_coverage_0.pcap
# Loading packets from E:\pcap\udp_lite_full_coverage_0.pcap...
# Loaded 1 packets from udp_lite_full_coverage_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_full_coverage_0.pcap
#
# [214/231] Processing udp_lite_illegal_1-7.pcap
# Loading packets from E:\pcap\udp_lite_illegal_1-7.pcap...
# Loaded 7 packets from udp_lite_illegal_1-7.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 7 packets from udp_lite_illegal_1-7.pcap
#
# [215/231] Processing udp_lite_illegal_large-coverage.pcap
# Loading packets from E:\pcap\udp_lite_illegal_large-coverage.pcap...
# Loaded 3 packets from udp_lite_illegal_large-coverage.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from udp_lite_illegal_large-coverage.pcap
#
# [216/231] Processing udp_lite_normal_coverage_8-20.pcap
# Loading packets from E:\pcap\udp_lite_normal_coverage_8-20.pcap...
# Loaded 13 packets from udp_lite_normal_coverage_8-20.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from udp_lite_normal_coverage_8-20.pcap
#
# [217/231] Processing UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Loading packets from E:\pcap\UMTS_FP_MAC_RLC_RRC_NBAP.pcap...
# Loaded 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
# Extracted features for 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#
# [218/231] Processing unistim-call.pcap
# Loading packets from E:\pcap\unistim-call.pcap...
# Loaded 105 packets from unistim-call.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from unistim-call.pcap
#
# [219/231] Processing usb_memory_stick.pcap
# Loading packets from E:\pcap\usb_memory_stick.pcap...
# WARNING: PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 1041 packets from usb_memory_stick.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1041 packets from usb_memory_stick.pcap
#
# [220/231] Processing usb_memory_stick_create_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_create_file.pcap...
# WARNING: more PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 144 packets from usb_memory_stick_create_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from usb_memory_stick_create_file.pcap
#
# [221/231] Processing usb_memory_stick_delete_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_delete_file.pcap...
# Loaded 66 packets from usb_memory_stick_delete_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from usb_memory_stick_delete_file.pcap
#
# [222/231] Processing UserLog.pcap
# Loading packets from E:\pcap\UserLog.pcap...
# Loaded 650 packets from UserLog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 650 packets from UserLog.pcap
#
# [223/231] Processing v6.pcap
# Loading packets from E:\pcap\v6.pcap...
# Loaded 161 packets from v6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 161 packets from v6.pcap
#
# [224/231] Processing VariousUSBDevices.pcap
# Loading packets from E:\pcap\VariousUSBDevices.pcap...
# Loaded 8206 packets from VariousUSBDevices.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
# Extracted features for 8206 packets from VariousUSBDevices.pcap
#
# [225/231] Processing vnc-sample.pcap
# Loading packets from E:\pcap\vnc-sample.pcap...
# Loaded 81 packets from vnc-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 81 packets from vnc-sample.pcap
#
# [226/231] Processing wap_google.pcap
# Loading packets from E:\pcap\wap_google.pcap...
# Loaded 4 packets from wap_google.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from wap_google.pcap
#
# [227/231] Processing win_s4u2self.pcap
# Loading packets from E:\pcap\win_s4u2self.pcap...
# Loaded 14 packets from win_s4u2self.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from win_s4u2self.pcap
#
# [228/231] Processing wpa-Induction.pcap
# Loading packets from E:\pcap\wpa-Induction.pcap...
# Loaded 1093 packets from wpa-Induction.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1093 packets from wpa-Induction.pcap
#
# [229/231] Processing x400-ping-refuse.pcap
# Loading packets from E:\pcap\x400-ping-refuse.pcap...
# Loaded 10 packets from x400-ping-refuse.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from x400-ping-refuse.pcap
#
# [230/231] Processing x400-ping-success.pcap
# Loading packets from E:\pcap\x400-ping-success.pcap...
# Loaded 12 packets from x400-ping-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from x400-ping-success.pcap
#
# [231/231] Processing yami.pcap
# Loading packets from E:\pcap\yami.pcap...
# Loaded 2 packets from yami.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from yami.pcap
#
# Combining data from 231 files...
# Total packets processed: 214523
#
# Overall label distribution:
# label
# other_tcp        81387
# non_ip           62423
# other_udp        60934
# other_ip          6769
# web_traffic       1205
# dns                612
# remote_access      413
# database           317
# snmp               144
# icmp                81
# ntp                 66
# dhcp                61
# file_transfer       58
# email               53
# Name: count, dtype: int64
#
# Dataset shape: (214523, 18)
# Number of classes: 14
#
# Training model...
# Cleaning data...
# Cleaned dataset: 214523/214523 packets retained
#
# Model Accuracy: 1.000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      database       0.98      0.94      0.96        63
#          dhcp       1.00      1.00      1.00        12
#           dns       1.00      1.00      1.00       122
#         email       1.00      1.00      1.00        11
# file_transfer       1.00      1.00      1.00        12
#          icmp       1.00      1.00      1.00        16
#        non_ip       1.00      1.00      1.00     12485
#           ntp       1.00      1.00      1.00        13
#      other_ip       1.00      1.00      1.00      1354
#     other_tcp       1.00      1.00      1.00     16277
#     other_udp       1.00      1.00      1.00     12187
# remote_access       1.00      1.00      1.00        83
#          snmp       1.00      1.00      1.00        29
#   web_traffic       1.00      0.99      0.99       241
#
#      accuracy                           1.00     42905
#     macro avg       1.00      0.99      1.00     42905
#  weighted avg       1.00      1.00      1.00     42905
#
#
# Top 10 Most Important Features:
#         feature  importance
# 7        is_tcp    0.152725
# 1        has_ip    0.101746
# 3        ip_ttl    0.080404
# 6      ip_proto    0.075668
# 13   tcp_window    0.074978
# 12    tcp_flags    0.072696
# 16  tcp_dataofs    0.069056
# 2     ip_length    0.066414
# 14      tcp_seq    0.063193
# 10     src_port    0.058224
# Model trained successfully!
# You can now use the classifier for predictions:
# predicted_class, confidence = classifier.predict_packet_class(packet)

# %%
# Examples of how to use your trained classifier for predictions

# Method 1: Classify packets from a new pcap file
def classify_new_pcap_file(classifier, pcap_file_path):
    """Classify all packets in a new pcap file"""
    print(f"Classifying packets in: {pcap_file_path}")
    
    try:
        from scapy.all import rdpcap
        packets = rdpcap(pcap_file_path)
        
        results = []
        for i, packet in enumerate(packets):
            predicted_class, confidence = classifier.predict_packet_class(packet)
            results.append({
                'packet_id': i,
                'predicted_class': predicted_class,
                'confidence': confidence
            })
            
            # Print first 10 predictions as examples
            if i < 10:
                print(f"Packet {i}: {predicted_class} (confidence: {confidence:.3f})")
        
        return results
        
    except Exception as e:
        print(f"Error: {e}")
        return None

# Method 2: Classify packets in real-time from network interface
def classify_live_packets(classifier, interface='eth0', packet_count=50):
    """Classify packets captured live from network interface"""
    print(f"Starting live packet classification on interface: {interface}")
    print("Press Ctrl+C to stop...")
    
    try:
        from scapy.all import sniff
        
        def packet_handler(packet):
            predicted_class, confidence = classifier.predict_packet_class(packet)
            print(f"Live packet: {predicted_class} (confidence: {confidence:.3f})")
        
        # Capture packets live
        sniff(iface=interface, prn=packet_handler, count=packet_count)
        
    except Exception as e:
        print(f"Error in live capture: {e}")
        print("Note: Live capture may require root/admin privileges")

# Method 3: Classify specific packet types
def classify_packet_examples(classifier):
    """Examples of classifying different types of packets"""
    from scapy.all import IP, TCP, UDP, ICMP
    
    # Example 1: HTTP packet
    http_packet = IP(dst="192.168.1.1")/TCP(dport=80)
    pred_class, confidence = classifier.predict_packet_class(http_packet)
    print(f"HTTP packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 2: DNS packet  
    dns_packet = IP(dst="8.8.8.8")/UDP(dport=53)
    pred_class, confidence = classifier.predict_packet_class(dns_packet)
    print(f"DNS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 3: HTTPS packet
    https_packet = IP(dst="www.google.com")/TCP(dport=443)
    pred_class, confidence = classifier.predict_packet_class(https_packet)
    print(f"HTTPS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 4: ICMP packet
    icmp_packet = IP(dst="192.168.1.1")/ICMP()
    pred_class, confidence = classifier.predict_packet_class(icmp_packet)
    print(f"ICMP packet: {pred_class} (confidence: {confidence:.3f})")

# Method 4: Batch classification with detailed analysis
def detailed_packet_analysis(classifier, pcap_file_path):
    """Detailed analysis of packets in a pcap file"""
    from scapy.all import rdpcap
    import pandas as pd
    
    print(f"Analyzing: {pcap_file_path}")
    packets = rdpcap(pcap_file_path)
    
    results = []
    class_counts = {}
    
    for i, packet in enumerate(packets):
        predicted_class, confidence = classifier.predict_packet_class(packet)
        
        # Count classes
        if predicted_class not in class_counts:
            class_counts[predicted_class] = 0
        class_counts[predicted_class] += 1
        
        # Store detailed info
        packet_info = {
            'packet_id': i,
            'predicted_class': predicted_class,
            'confidence': confidence,
            'packet_size': len(packet),
            'has_ip': 1 if packet.haslayer(IP) else 0,
            'protocol': 'Unknown'
        }
        
        if packet.haslayer(IP):
            if packet.haslayer(TCP):
                packet_info['protocol'] = 'TCP'
                packet_info['src_port'] = packet[TCP].sport
                packet_info['dst_port'] = packet[TCP].dport
            elif packet.haslayer(UDP):
                packet_info['protocol'] = 'UDP'
                packet_info['src_port'] = packet[UDP].sport
                packet_info['dst_port'] = packet[UDP].dport
            elif packet.haslayer(ICMP):
                packet_info['protocol'] = 'ICMP'
        
        results.append(packet_info)
    
    # Create DataFrame for analysis
    df = pd.DataFrame(results)
    
    print("\n=== CLASSIFICATION SUMMARY ===")
    print(f"Total packets analyzed: {len(packets)}")
    print("\nClass distribution:")
    for class_name, count in sorted(class_counts.items()):
        percentage = (count / len(packets)) * 100
        print(f"  {class_name}: {count} packets ({percentage:.1f}%)")
    
    print(f"\nAverage confidence: {df['confidence'].mean():.3f}")
    print(f"Low confidence packets (<0.5): {sum(df['confidence'] < 0.5)}")
    
    # Show some examples of each class
    print("\n=== EXAMPLES BY CLASS ===")
    for class_name in df['predicted_class'].unique():
        class_examples = df[df['predicted_class'] == class_name].head(3)
        print(f"\n{class_name.upper()}:")
        for _, example in class_examples.iterrows():
            print(f"  Packet {example['packet_id']}: "
                  f"{example['protocol']} - "
                  f"Size: {example['packet_size']} bytes - "
                  f"Confidence: {example['confidence']:.3f}")
    
    return df

# Method 5: Real-time monitoring with filtering
def monitor_specific_traffic(classifier, target_class='web_traffic', min_confidence=0.7):
    """Monitor and alert for specific types of network traffic"""
    from scapy.all import sniff
    import time
    
    print(f"Monitoring for {target_class} with confidence >= {min_confidence}")
    print("Press Ctrl+C to stop...")
    
    detected_count = 0
    start_time = time.time()
    
    def packet_handler(packet):
        nonlocal detected_count
        
        predicted_class, confidence = classifier.predict_packet_class(packet)
        
        if predicted_class == target_class and confidence >= min_confidence:
            detected_count += 1
            timestamp = time.strftime("%H:%M:%S", time.localtime())
            print(f"[{timestamp}] DETECTED: {predicted_class} "
                  f"(confidence: {confidence:.3f}) - "
                  f"Total detected: {detected_count}")
    
    try:
        sniff(prn=packet_handler, timeout=60)  # Monitor for 60 seconds
        
        elapsed_time = time.time() - start_time
        print(f"\nMonitoring completed:")
        print(f"Time elapsed: {elapsed_time:.1f} seconds")
        print(f"Total {target_class} detected: {detected_count}")
        
    except KeyboardInterrupt:
        print(f"\nMonitoring stopped by user")
        print(f"Total {target_class} detected: {detected_count}")

# Example usage functions
if __name__ == "__main__":
    # Assuming your classifier is already trained and available
    # Replace 'classifier' with your actual trained classifier object
    
    print("=== PACKET CLASSIFICATION EXAMPLES ===\n")
    
    # Example 1: Classify a new pcap file
    print("1. Classifying packets from a new pcap file:")
    new_pcap = "E:\for soln\sample.pcap"  # Update with your file
    # results = classify_new_pcap_file(classifier, new_pcap)
    
    print("\n2. Classifying synthetic packets:")
    # classify_packet_examples(classifier)
    
    print("\n3. Detailed analysis of a pcap file:")
    # analysis_df = detailed_packet_analysis(classifier, new_pcap)
    
    print("\n4. Live packet classification:")
    # classify_live_packets(classifier, interface='Wi-Fi', packet_count=20)
    
    print("\n5. Monitor specific traffic:")
    # monitor_specific_traffic(classifier, target_class='web_traffic', min_confidence=0.8)
    
    print("\n=== USAGE INSTRUCTIONS ===")
    print("To use these functions with your trained classifier:")
    print("1. Ensure your classifier object is available in the scope")
    print("2. Uncomment the function calls above")
    print("3. Update file paths and interface names as needed")
    print("4. Run the specific function you want to use")

# Quick prediction function for single packets
def quick_predict(classifier, packet):
    """Quick prediction with formatted output"""
    predicted_class, confidence = classifier.predict_packet_class(packet)
    
    print(f"Prediction: {predicted_class}")
    print(f"Confidence: {confidence:.3f}")
    
    if confidence > 0.8:
        print("Classification: High confidence ✓")
    elif confidence > 0.5:
        print("Classification: Medium confidence ~")
    else:
        print("Classification: Low confidence ⚠️")
    
    return predicted_class, confidence
# Out:
# === PACKET CLASSIFICATION EXAMPLES ===
#
# 1. Classifying packets from a new pcap file:
#
# 2. Classifying synthetic packets:
#
# 3. Detailed analysis of a pcap file:
#
# 4. Live packet classification:
#
# 5. Monitor specific traffic:
#
# === USAGE INSTRUCTIONS ===
# To use these functions with your trained classifier:
# 1. Ensure your classifier object is available in the scope
# 2. Uncomment the function calls above
# 3. Update file paths and interface names as needed
# 4. Run the specific function you want to use

# %%
# Force the classifier to be global and available
def create_classifier():
    global classifier
    classifier = PacketClassifier()
    
    pcap_folder = r"E:\pcap"
    
    if not os.path.exists(pcap_folder):
        print(f"Error: Folder '{pcap_folder}' does not exist")
        return None
    
    # Load and process data
    features, labels = classifier.load_and_process_folder(pcap_folder)
    
    if features is not None and not features.empty:
        print(f"\nDataset shape: {features.shape}")
        print(f"Number of classes: {labels.nunique()}")
        
        # Train the model
        X_test, y_test, y_pred = classifier.train_model(features, labels)
        
        if X_test is not None:
            classifier.plot_results(y_test, y_pred)
        
        print("\nModel trained successfully!")
        print("Classifier is now available globally!")
        return classifier
    else:
        print("No valid data extracted from pcap files.")
        return None

# Create the classifier
create_classifier()

# Test it immediately
print(f"Classifier type: {type(classifier)}")
print("Classifier is ready for predictions!")
# Out:
# Scanning folder: E:\pcap
# Found 231 pcap files:
#   - 6to4.pcap
#   - aaa.pcap
#   - abis-accept-network.pcap
#   - abis-reject-network.pcap
#   - airtunes-1.pcap
#   - alp-sample1.pcap
#   - alp-sample2.pcap
#   - anony-tcp-std.pcap
#   - ansi_map_ota.pcap
#   - ansi_map_win.pcap
#   - ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#   - Apple_IP-over-IEEE_1394_Packet.pcap
#   - arp-storm.pcap
#   - Asterisk_ZFONE_XLITE.pcap
#   - bfd-raw-auth-md5.pcap
#   - bfd-raw-auth-sha1.pcap
#   - bgpsec.pcap
#   - bgp_shutdown_communication.pcap
#   - bicc.pcap
#   - BITTORRENT.pcap
#   - bmp.pcap
#   - c1222_over_ipv6.pcap
#   - c1222_std_example8.pcap
#   - camel.pcap
#   - camel2.pcap
#   - can-2003-0003.pcap
#   - cdp.pcap
#   - cdp_v2.pcap
#   - ch11-25-slt.pcap
#   - chargen-tcp.pcap
#   - chargen-udp.pcap
#   - cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#   - cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#   - coap-cbor.pcap
#   - couchbase-lww.pcap
#   - couchbase_subdoc_multi.pcap
#   - dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#   - dhcp-nanosecond.pcap
#   - dhcp.pcap
#   - dhcpv6_1.pcap
#   - DICOM_C-ECHO-echoscu.pcap
#   - dlep.pcap
#   - dnp3_read.pcap
#   - dnp3_select_operate.pcap
#   - dnp3_write.pcap
#   - dns-remoteshell.pcap
#   - dns_port.pcap
#   - DTMFsipinfo.pcap
#   - dvb-ci_1.pcap
#   - dvb-ci_2.pcap
#   - dvb-ci_UV1_0000.pcap
#   - eapol-mka.pcap
#   - ecpri.pcap
#   - eia709.1-over-eia852.pcap
#   - eigrp-for-ipv6-auth.pcap
#   - eigrp-for-ipv6-stub.pcap
#   - eigrp-for-ipv6-updates.pcap
#   - eigrp-ipx.pcap
#   - epmd.pcap
#   - exablaze_trailer.pcap
#   - exec-sample.pcap
#   - FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#   - fix-ssl.pcap
#   - fix.pcap
#   - fuzz-2008-09-30-17714.pcap
#   - gopher.pcap
#   - greb_filterlist.pcap
#   - gsm-r.uus1.pcap
#   - gsm_map_with_ussd_string.pcap
#   - h263-over-rtp.pcap
#   - hart_ip.pcap
#   - hcrt.pcap
#   - hdcp_authentication_sample.pcap
#   - homeplug_network_statistics_basic.pcap
#   - homeplug_request_channel_estimation.pcap
#   - homeplug_request_parameters_and_statistics.pcap
#   - hsrp.pcap
#   - http-chunked-gzip.pcap
#   - iec104.pcap
#   - IGMP-dataset.pcap
#   - infiniband.pcap
#   - iperf-mptcp-0-0.pcap
#   - ipmb.multi.packets.pcap
#   - ipmi.SDR.FRU.SEL.pcap
#   - ipmi.sensor.event.RR.pcap
#   - ipp.pcap
#   - ipv4frags.pcap
#   - ipv4_cipso_option.pcap
#   - isup_load_generator.pcap
#   - jaeger-compact.pcap
#   - japan_tcap_over_m2pa.pcap
#   - jxta-mcast-sample.pcap
#   - jxta-sample.pcap
#   - kismet-client-server-dump-1.pcap
#   - ldap-and-search.pcap
#   - ldap-attribute-value-list.pcap
#   - ldap-extensible-match-with-dn.pcap
#   - ldap-extensible-match.pcap
#   - ldap-substring.pcap
#   - lldp.detailed.pcap
#   - lldp.minimal.pcap
#   - lldpmed_civicloc.pcap
#   - llt-sample.pcap
#   - macsec_cisco_trunk.pcap
#   - mdb_bill_validator.pcap
#   - mdb_cashless_1.pcap
#   - mesh.pcap
#   - metamako_trailer.pcap
#   - metasploit-sip-invite-spoof.pcap
#   - MGCP.pcap
#   - mndp.pcap
#   - Mobile-Originating-Call(AMR).pcap
#   - Mobile-Terminating-Call(AMR).pcap
#   - mouse_replug2.pcap
#   - mp4-ftyp-styp-sidx.pcap
#   - mpeg2_mp2t_with_cc_drop01.pcap
#   - msgpack-generated.pcap
#   - msnms.pcap
#   - mysql_complete.pcap
#   - nano.pcap
#   - nano_tcp.pcap
#   - nb6-hotspot.pcap
#   - nb6-http.pcap
#   - nb6-startup.pcap
#   - nb6-telephone.pcap
#   - netlink-conntrack.pcap
#   - netlink-ipset.pcap
#   - netlink-nflog.pcap
#   - netlink.pcap
#   - Network_Join_Nokia_Mobile.pcap
#   - new_rfp.pcap
#   - new_rfp_on_wire.pcap
#   - nflog.pcap
#   - nlmon-big.pcap
#   - nntp.pcap
#   - notifyLTE.pcap
#   - nspi.pcap
#   - NTLM-wenchao.pcap
#   - NTP_sync.pcap
#   - opensafety_epl_trace.pcap
#   - opensafety_sercosiii_trace.pcap
#   - opensafety_udp_trace.pcap
#   - OptoMMP.pcap
#   - p772-transfer-success.pcap
#   - policy-authorizeNV.pcap
#   - ppp_lcp_ipcp.pcap
#   - ptpv2.pcap
#   - pvfs2-sample.pcap
#   - rsasnakeoil2.pcap
#   - rtp-norm-transfer.pcap
#   - rtp-opus-only.pcap
#   - s101glow.pcap
#   - S5066-Expedited.pcap
#   - S5066-HFChat-1.pcap
#   - S5066-HFChat-Rejected.pcap
#   - s7comm_downloading_block_db1.pcap
#   - s7comm_program_blocklist_onlineview.pcap
#   - s7comm_reading_plc_status.pcap
#   - s7comm_reading_setting_plc_time.pcap
#   - s7comm_varservice_libnodavedemo.pcap
#   - s7comm_varservice_libnodavedemo_bench.pcap
#   - sbus.pcap
#   - scsi-osd-example-001.pcap
#   - segmented_fpm.pcap
#   - SIMULCRYPT.pcap
#   - sip-rtp-dvi4.pcap
#   - sip-rtp-g711.pcap
#   - sip-rtp-g722.pcap
#   - sip-rtp-g726.pcap
#   - sip-rtp-g729a.pcap
#   - sip-rtp-gsm.pcap
#   - sip-rtp-ilbc.pcap
#   - sip-rtp-l16.pcap
#   - sip-rtp-lpc.pcap
#   - sip-rtp-opus-hybrid.pcap
#   - sip-rtp-opus.pcap
#   - sip-rtp-speex.pcap
#   - siso_std_002_annex_b_example.pcap
#   - siso_std_002_transmitter.pcap
#   - smb3-aes-128-ccm.pcap
#   - smb311-aes-128-ccm-filt.pcap
#   - smtp.pcap
#   - snakeoil-dtls.pcap
#   - snmp_usm.pcap
#   - sr-header.pcap
#   - stanag-5602-simple-example.pcap
#   - Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#   - steam-ihs-discovery.pcap
#   - stp.pcap
#   - tcp-ecn-sample.pcap
#   - TeamSpeak2.pcap
#   - telecomitalia-pppoe.pcap
#   - telnet-cooked.pcap
#   - telnet-raw.pcap
#   - Teredo.pcap
#   - tftp_rrq.pcap
#   - tftp_wrq.pcap
#   - tipc-publication-payload-withdrawal.pcap
#   - TNS_Oracle1.pcap
#   - TNS_Oracle2.pcap
#   - TNS_Oracle3.pcap
#   - TNS_Oracle4.pcap
#   - TNS_Oracle5.pcap
#   - tpncp_tcp.pcap
#   - tpncp_udp.pcap
#   - TTE_mix_small.pcap
#   - tunnel.pcap
#   - ua3g_freeseating_ipv4.pcap
#   - ua3g_freeseating_ipv6.pcap
#   - uaudp_ipv6.pcap
#   - udp-nm_anon.pcap
#   - udp_lite_checksum_0.pcap
#   - udp_lite_full_coverage_0.pcap
#   - udp_lite_illegal_1-7.pcap
#   - udp_lite_illegal_large-coverage.pcap
#   - udp_lite_normal_coverage_8-20.pcap
#   - UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#   - unistim-call.pcap
#   - usb_memory_stick.pcap
#   - usb_memory_stick_create_file.pcap
#   - usb_memory_stick_delete_file.pcap
#   - UserLog.pcap
#   - v6.pcap
#   - VariousUSBDevices.pcap
#   - vnc-sample.pcap
#   - wap_google.pcap
#   - win_s4u2self.pcap
#   - wpa-Induction.pcap
#   - x400-ping-refuse.pcap
#   - x400-ping-success.pcap
#   - yami.pcap
#
# [1/231] Processing 6to4.pcap
# Loading packets from E:\pcap\6to4.pcap...
# Loaded 5 packets from 6to4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from 6to4.pcap
#
# [2/231] Processing aaa.pcap
# Loading packets from E:\pcap\aaa.pcap...
# Loaded 691 packets from aaa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 691 packets from aaa.pcap
#
# [3/231] Processing abis-accept-network.pcap
# Loading packets from E:\pcap\abis-accept-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 85 packets from abis-accept-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from abis-accept-network.pcap
#
# [4/231] Processing abis-reject-network.pcap
# Loading packets from E:\pcap\abis-reject-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 78 packets from abis-reject-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from abis-reject-network.pcap
#
# [5/231] Processing airtunes-1.pcap
# Loading packets from E:\pcap\airtunes-1.pcap...
# Loaded 1748 packets from airtunes-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1748 packets from airtunes-1.pcap
#
# [6/231] Processing alp-sample1.pcap
# Loading packets from E:\pcap\alp-sample1.pcap...
# WARNING: more PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 17 packets from alp-sample1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from alp-sample1.pcap
#
# [7/231] Processing alp-sample2.pcap
# Loading packets from E:\pcap\alp-sample2.pcap...
# Loaded 85 packets from alp-sample2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from alp-sample2.pcap
#
# [8/231] Processing anony-tcp-std.pcap
# Loading packets from E:\pcap\anony-tcp-std.pcap...
# Loaded 170 packets from anony-tcp-std.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 170 packets from anony-tcp-std.pcap
#
# [9/231] Processing ansi_map_ota.pcap
# Loading packets from E:\pcap\ansi_map_ota.pcap...
# Loaded 24 packets from ansi_map_ota.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from ansi_map_ota.pcap
#
# [10/231] Processing ansi_map_win.pcap
# Loading packets from E:\pcap\ansi_map_win.pcap...
# Loaded 9 packets from ansi_map_win.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from ansi_map_win.pcap
#
# [11/231] Processing ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Loading packets from E:\pcap\ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap...
# Loaded 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#
# [12/231] Processing Apple_IP-over-IEEE_1394_Packet.pcap
# Loading packets from E:\pcap\Apple_IP-over-IEEE_1394_Packet.pcap...
# Loaded 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
#
# [13/231] Processing arp-storm.pcap
# Loading packets from E:\pcap\arp-storm.pcap...
# Loaded 622 packets from arp-storm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 622 packets from arp-storm.pcap
#
# [14/231] Processing Asterisk_ZFONE_XLITE.pcap
# Loading packets from E:\pcap\Asterisk_ZFONE_XLITE.pcap...
# Loaded 1042 packets from Asterisk_ZFONE_XLITE.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1042 packets from Asterisk_ZFONE_XLITE.pcap
#
# [15/231] Processing bfd-raw-auth-md5.pcap
# Loading packets from E:\pcap\bfd-raw-auth-md5.pcap...
# Loaded 31 packets from bfd-raw-auth-md5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 31 packets from bfd-raw-auth-md5.pcap
#
# [16/231] Processing bfd-raw-auth-sha1.pcap
# Loading packets from E:\pcap\bfd-raw-auth-sha1.pcap...
# Loaded 25 packets from bfd-raw-auth-sha1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from bfd-raw-auth-sha1.pcap
#
# [17/231] Processing bgpsec.pcap
# Loading packets from E:\pcap\bgpsec.pcap...
# Loaded 1127 packets from bgpsec.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1127 packets from bgpsec.pcap
#
# [18/231] Processing bgp_shutdown_communication.pcap
# Loading packets from E:\pcap\bgp_shutdown_communication.pcap...
# Loaded 9 packets from bgp_shutdown_communication.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from bgp_shutdown_communication.pcap
#
# [19/231] Processing bicc.pcap
# Loading packets from E:\pcap\bicc.pcap...
# Loaded 1 packets from bicc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from bicc.pcap
#
# [20/231] Processing BITTORRENT.pcap
# Loading packets from E:\pcap\BITTORRENT.pcap...
# Loaded 53 packets from BITTORRENT.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 53 packets from BITTORRENT.pcap
#
# [21/231] Processing bmp.pcap
# Loading packets from E:\pcap\bmp.pcap...
# Loaded 39 packets from bmp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from bmp.pcap
#
# [22/231] Processing c1222_over_ipv6.pcap
# Loading packets from E:\pcap\c1222_over_ipv6.pcap...
# Loaded 11 packets from c1222_over_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 11 packets from c1222_over_ipv6.pcap
#
# [23/231] Processing c1222_std_example8.pcap
# Loading packets from E:\pcap\c1222_std_example8.pcap...
# Loaded 2 packets from c1222_std_example8.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from c1222_std_example8.pcap
#
# [24/231] Processing camel.pcap
# Loading packets from E:\pcap\camel.pcap...
# Loaded 5 packets from camel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from camel.pcap
#
# [25/231] Processing camel2.pcap
# Loading packets from E:\pcap\camel2.pcap...
# Loaded 4 packets from camel2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from camel2.pcap
#
# [26/231] Processing can-2003-0003.pcap
# Loading packets from E:\pcap\can-2003-0003.pcap...
# Loaded 27 packets from can-2003-0003.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 27 packets from can-2003-0003.pcap
#
# [27/231] Processing cdp.pcap
# Loading packets from E:\pcap\cdp.pcap...
# Loaded 1 packets from cdp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from cdp.pcap
#
# [28/231] Processing cdp_v2.pcap
# Loading packets from E:\pcap\cdp_v2.pcap...
# Loaded 4 packets from cdp_v2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from cdp_v2.pcap
#
# [29/231] Processing ch11-25-slt.pcap
# Loading packets from E:\pcap\ch11-25-slt.pcap...
# Loaded 68 packets from ch11-25-slt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from ch11-25-slt.pcap
#
# [30/231] Processing chargen-tcp.pcap
# Loading packets from E:\pcap\chargen-tcp.pcap...
# Loaded 22 packets from chargen-tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from chargen-tcp.pcap
#
# [31/231] Processing chargen-udp.pcap
# Loading packets from E:\pcap\chargen-udp.pcap...
# Loaded 2 packets from chargen-udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from chargen-udp.pcap
#
# [32/231] Processing cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_-OpenSSL-EJBCA.pcap...
# Loaded 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#
# [33/231] Processing cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_OpenSSL-Cryptlib.pcap...
# Loaded 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#
# [34/231] Processing coap-cbor.pcap
# Loading packets from E:\pcap\coap-cbor.pcap...
# Loaded 164 packets from coap-cbor.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 164 packets from coap-cbor.pcap
#
# [35/231] Processing couchbase-lww.pcap
# Loading packets from E:\pcap\couchbase-lww.pcap...
# Loaded 240 packets from couchbase-lww.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 240 packets from couchbase-lww.pcap
#
# [36/231] Processing couchbase_subdoc_multi.pcap
# Loading packets from E:\pcap\couchbase_subdoc_multi.pcap...
# Loaded 477 packets from couchbase_subdoc_multi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 477 packets from couchbase_subdoc_multi.pcap
#
# [37/231] Processing dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Loading packets from E:\pcap\dcerpc-winreg-with-rpc-sec-verification-trailer.pcap...
# Loaded 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#
# [38/231] Processing dhcp-nanosecond.pcap
# Loading packets from E:\pcap\dhcp-nanosecond.pcap...
# Loaded 4 packets from dhcp-nanosecond.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp-nanosecond.pcap
#
# [39/231] Processing dhcp.pcap
# Loading packets from E:\pcap\dhcp.pcap...
# Loaded 4 packets from dhcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp.pcap
#
# [40/231] Processing dhcpv6_1.pcap
# Loading packets from E:\pcap\dhcpv6_1.pcap...
# Loaded 10 packets from dhcpv6_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from dhcpv6_1.pcap
#
# [41/231] Processing DICOM_C-ECHO-echoscu.pcap
# Loading packets from E:\pcap\DICOM_C-ECHO-echoscu.pcap...
# Loaded 25 packets from DICOM_C-ECHO-echoscu.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from DICOM_C-ECHO-echoscu.pcap
#
# [42/231] Processing dlep.pcap
# Loading packets from E:\pcap\dlep.pcap...
# Loaded 23 packets from dlep.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from dlep.pcap
#
# [43/231] Processing dnp3_read.pcap
# Loading packets from E:\pcap\dnp3_read.pcap...
# Loaded 8 packets from dnp3_read.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_read.pcap
#
# [44/231] Processing dnp3_select_operate.pcap
# Loading packets from E:\pcap\dnp3_select_operate.pcap...
# Loaded 12 packets from dnp3_select_operate.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from dnp3_select_operate.pcap
#
# [45/231] Processing dnp3_write.pcap
# Loading packets from E:\pcap\dnp3_write.pcap...
# Loaded 8 packets from dnp3_write.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_write.pcap
#
# [46/231] Processing dns-remoteshell.pcap
# Loading packets from E:\pcap\dns-remoteshell.pcap...
# Loaded 131 packets from dns-remoteshell.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 131 packets from dns-remoteshell.pcap
#
# [47/231] Processing dns_port.pcap
# Loading packets from E:\pcap\dns_port.pcap...
# Loaded 2 packets from dns_port.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from dns_port.pcap
#
# [48/231] Processing DTMFsipinfo.pcap
# Loading packets from E:\pcap\DTMFsipinfo.pcap...
# Loaded 32 packets from DTMFsipinfo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from DTMFsipinfo.pcap
#
# [49/231] Processing dvb-ci_1.pcap
# Loading packets from E:\pcap\dvb-ci_1.pcap...
# Loaded 396 packets from dvb-ci_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 396 packets from dvb-ci_1.pcap
#
# [50/231] Processing dvb-ci_2.pcap
# Loading packets from E:\pcap\dvb-ci_2.pcap...
# Loaded 273 packets from dvb-ci_2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from dvb-ci_2.pcap
#
# [51/231] Processing dvb-ci_UV1_0000.pcap
# Loading packets from E:\pcap\dvb-ci_UV1_0000.pcap...
# Loaded 1 packets from dvb-ci_UV1_0000.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from dvb-ci_UV1_0000.pcap
#
# [52/231] Processing eapol-mka.pcap
# Loading packets from E:\pcap\eapol-mka.pcap...
# Loaded 68 packets from eapol-mka.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from eapol-mka.pcap
#
# [53/231] Processing ecpri.pcap
# Loading packets from E:\pcap\ecpri.pcap...
# Loaded 18 packets from ecpri.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 18 packets from ecpri.pcap
#
# [54/231] Processing eia709.1-over-eia852.pcap
# Loading packets from E:\pcap\eia709.1-over-eia852.pcap...
# Loaded 12028 packets from eia709.1-over-eia852.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
# Extracted features for 12028 packets from eia709.1-over-eia852.pcap
#
# [55/231] Processing eigrp-for-ipv6-auth.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-auth.pcap...
# Loaded 570 packets from eigrp-for-ipv6-auth.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 570 packets from eigrp-for-ipv6-auth.pcap
#
# [56/231] Processing eigrp-for-ipv6-stub.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-stub.pcap...
# Loaded 273 packets from eigrp-for-ipv6-stub.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from eigrp-for-ipv6-stub.pcap
#
# [57/231] Processing eigrp-for-ipv6-updates.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-updates.pcap...
# Loaded 421 packets from eigrp-for-ipv6-updates.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 421 packets from eigrp-for-ipv6-updates.pcap
#
# [58/231] Processing eigrp-ipx.pcap
# Loading packets from E:\pcap\eigrp-ipx.pcap...
# WARNING: PcapReader: unknown LL type [104]/[0x68]. Using Raw packets
# Loaded 74 packets from eigrp-ipx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 74 packets from eigrp-ipx.pcap
#
# [59/231] Processing epmd.pcap
# Loading packets from E:\pcap\epmd.pcap...
# Loaded 10 packets from epmd.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from epmd.pcap
#
# [60/231] Processing exablaze_trailer.pcap
# Loading packets from E:\pcap\exablaze_trailer.pcap...
# Loaded 24 packets from exablaze_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from exablaze_trailer.pcap
#
# [61/231] Processing exec-sample.pcap
# Loading packets from E:\pcap\exec-sample.pcap...
# Loaded 14 packets from exec-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from exec-sample.pcap
#
# [62/231] Processing FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Loading packets from E:\pcap\FAX-Call-t38-CA-TDM-SIP-FB-1.pcap...
# Loaded 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
# Extracted features for 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#
# [63/231] Processing fix-ssl.pcap
# Loading packets from E:\pcap\fix-ssl.pcap...
# Loaded 1237 packets from fix-ssl.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1237 packets from fix-ssl.pcap
#
# [64/231] Processing fix.pcap
# Loading packets from E:\pcap\fix.pcap...
# Loaded 485 packets from fix.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 485 packets from fix.pcap
#
# [65/231] Processing fuzz-2008-09-30-17714.pcap
# Loading packets from E:\pcap\fuzz-2008-09-30-17714.pcap...
# Loaded 68294 packets from fuzz-2008-09-30-17714.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
#   Processed 32000 packets...
#   Processed 33000 packets...
#   Processed 34000 packets...
#   Processed 35000 packets...
#   Processed 36000 packets...
#   Processed 37000 packets...
#   Processed 38000 packets...
#   Processed 39000 packets...
#   Processed 40000 packets...
#   Processed 41000 packets...
#   Processed 42000 packets...
#   Processed 43000 packets...
#   Processed 44000 packets...
#   Processed 45000 packets...
#   Processed 46000 packets...
#   Processed 47000 packets...
#   Processed 48000 packets...
#   Processed 49000 packets...
#   Processed 50000 packets...
#   Processed 51000 packets...
#   Processed 52000 packets...
#   Processed 53000 packets...
#   Processed 54000 packets...
#   Processed 55000 packets...
#   Processed 56000 packets...
#   Processed 57000 packets...
#   Processed 58000 packets...
#   Processed 59000 packets...
#   Processed 60000 packets...
#   Processed 61000 packets...
#   Processed 62000 packets...
#   Processed 63000 packets...
#   Processed 64000 packets...
#   Processed 65000 packets...
#   Processed 66000 packets...
#   Processed 67000 packets...
#   Processed 68000 packets...
# Extracted features for 68294 packets from fuzz-2008-09-30-17714.pcap
#
# [66/231] Processing gopher.pcap
# Loading packets from E:\pcap\gopher.pcap...
# Loaded 92 packets from gopher.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from gopher.pcap
#
# [67/231] Processing greb_filterlist.pcap
# Loading packets from E:\pcap\greb_filterlist.pcap...
# Loaded 1 packets from greb_filterlist.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from greb_filterlist.pcap
#
# [68/231] Processing gsm-r.uus1.pcap
# Loading packets from E:\pcap\gsm-r.uus1.pcap...
# WARNING: PcapReader: unknown LL type [141]/[0x8d]. Using Raw packets
# Loaded 9 packets from gsm-r.uus1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from gsm-r.uus1.pcap
#
# [69/231] Processing gsm_map_with_ussd_string.pcap
# Loading packets from E:\pcap\gsm_map_with_ussd_string.pcap...
# Loaded 1 packets from gsm_map_with_ussd_string.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from gsm_map_with_ussd_string.pcap
#
# [70/231] Processing h263-over-rtp.pcap
# Loading packets from E:\pcap\h263-over-rtp.pcap...
# Loaded 49 packets from h263-over-rtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 49 packets from h263-over-rtp.pcap
#
# [71/231] Processing hart_ip.pcap
# Loading packets from E:\pcap\hart_ip.pcap...
# Loaded 116 packets from hart_ip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from hart_ip.pcap
#
# [72/231] Processing hcrt.pcap
# Loading packets from E:\pcap\hcrt.pcap...
# Loaded 10 packets from hcrt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from hcrt.pcap
#
# [73/231] Processing hdcp_authentication_sample.pcap
# Loading packets from E:\pcap\hdcp_authentication_sample.pcap...
# Loaded 8 packets from hdcp_authentication_sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from hdcp_authentication_sample.pcap
#
# [74/231] Processing homeplug_network_statistics_basic.pcap
# Loading packets from E:\pcap\homeplug_network_statistics_basic.pcap...
# Loaded 1 packets from homeplug_network_statistics_basic.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_network_statistics_basic.pcap
#
# [75/231] Processing homeplug_request_channel_estimation.pcap
# Loading packets from E:\pcap\homeplug_request_channel_estimation.pcap...
# Loaded 1 packets from homeplug_request_channel_estimation.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_channel_estimation.pcap
#
# [76/231] Processing homeplug_request_parameters_and_statistics.pcap
# Loading packets from E:\pcap\homeplug_request_parameters_and_statistics.pcap...
# Loaded 1 packets from homeplug_request_parameters_and_statistics.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_parameters_and_statistics.pcap
#
# [77/231] Processing hsrp.pcap
# Loading packets from E:\pcap\hsrp.pcap...
# Loaded 100 packets from hsrp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from hsrp.pcap
#
# [78/231] Processing http-chunked-gzip.pcap
# Loading packets from E:\pcap\http-chunked-gzip.pcap...
# Loaded 28 packets from http-chunked-gzip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from http-chunked-gzip.pcap
#
# [79/231] Processing iec104.pcap
# Loading packets from E:\pcap\iec104.pcap...
# Loaded 105 packets from iec104.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from iec104.pcap
#
# [80/231] Processing IGMP-dataset.pcap
# Loading packets from E:\pcap\IGMP-dataset.pcap...
# Loaded 147 packets from IGMP-dataset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 147 packets from IGMP-dataset.pcap
#
# [81/231] Processing infiniband.pcap
# Loading packets from E:\pcap\infiniband.pcap...
# WARNING: PcapReader: unknown LL type [197]/[0xc5]. Using Raw packets
# Loaded 43 packets from infiniband.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 43 packets from infiniband.pcap
#
# [82/231] Processing iperf-mptcp-0-0.pcap
# Loading packets from E:\pcap\iperf-mptcp-0-0.pcap...
# Loaded 2560 packets from iperf-mptcp-0-0.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2560 packets from iperf-mptcp-0-0.pcap
#
# [83/231] Processing ipmb.multi.packets.pcap
# Loading packets from E:\pcap\ipmb.multi.packets.pcap...
# WARNING: more PcapReader: unknown LL type [199]/[0xc7]. Using Raw packets
# Loaded 357 packets from ipmb.multi.packets.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 357 packets from ipmb.multi.packets.pcap
#
# [84/231] Processing ipmi.SDR.FRU.SEL.pcap
# Loading packets from E:\pcap\ipmi.SDR.FRU.SEL.pcap...
# Loaded 1138 packets from ipmi.SDR.FRU.SEL.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1138 packets from ipmi.SDR.FRU.SEL.pcap
#
# [85/231] Processing ipmi.sensor.event.RR.pcap
# Loading packets from E:\pcap\ipmi.sensor.event.RR.pcap...
# Loaded 726 packets from ipmi.sensor.event.RR.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 726 packets from ipmi.sensor.event.RR.pcap
#
# [86/231] Processing ipp.pcap
# Loading packets from E:\pcap\ipp.pcap...
# Loaded 279 packets from ipp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 279 packets from ipp.pcap
#
# [87/231] Processing ipv4frags.pcap
# Loading packets from E:\pcap\ipv4frags.pcap...
# Loaded 3 packets from ipv4frags.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from ipv4frags.pcap
#
# [88/231] Processing ipv4_cipso_option.pcap
# Loading packets from E:\pcap\ipv4_cipso_option.pcap...
# Loaded 6 packets from ipv4_cipso_option.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from ipv4_cipso_option.pcap
#
# [89/231] Processing isup_load_generator.pcap
# Loading packets from E:\pcap\isup_load_generator.pcap...
# Loaded 5265 packets from isup_load_generator.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
# Extracted features for 5265 packets from isup_load_generator.pcap
#
# [90/231] Processing jaeger-compact.pcap
# Loading packets from E:\pcap\jaeger-compact.pcap...
# Loaded 2 packets from jaeger-compact.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from jaeger-compact.pcap
#
# [91/231] Processing japan_tcap_over_m2pa.pcap
# Loading packets from E:\pcap\japan_tcap_over_m2pa.pcap...
# Loaded 6 packets from japan_tcap_over_m2pa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from japan_tcap_over_m2pa.pcap
#
# [92/231] Processing jxta-mcast-sample.pcap
# Loading packets from E:\pcap\jxta-mcast-sample.pcap...
# Loaded 401 packets from jxta-mcast-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 401 packets from jxta-mcast-sample.pcap
#
# [93/231] Processing jxta-sample.pcap
# Loading packets from E:\pcap\jxta-sample.pcap...
# Loaded 255 packets from jxta-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 255 packets from jxta-sample.pcap
#
# [94/231] Processing kismet-client-server-dump-1.pcap
# Loading packets from E:\pcap\kismet-client-server-dump-1.pcap...
# Loaded 35 packets from kismet-client-server-dump-1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 35 packets from kismet-client-server-dump-1.pcap
#
# [95/231] Processing ldap-and-search.pcap
# Loading packets from E:\pcap\ldap-and-search.pcap...
# Loaded 13 packets from ldap-and-search.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-and-search.pcap
#
# [96/231] Processing ldap-attribute-value-list.pcap
# Loading packets from E:\pcap\ldap-attribute-value-list.pcap...
# Loaded 13 packets from ldap-attribute-value-list.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-attribute-value-list.pcap
#
# [97/231] Processing ldap-extensible-match-with-dn.pcap
# Loading packets from E:\pcap\ldap-extensible-match-with-dn.pcap...
# Loaded 13 packets from ldap-extensible-match-with-dn.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match-with-dn.pcap
#
# [98/231] Processing ldap-extensible-match.pcap
# Loading packets from E:\pcap\ldap-extensible-match.pcap...
# Loaded 13 packets from ldap-extensible-match.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match.pcap
#
# [99/231] Processing ldap-substring.pcap
# Loading packets from E:\pcap\ldap-substring.pcap...
# Loaded 26 packets from ldap-substring.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 26 packets from ldap-substring.pcap
#
# [100/231] Processing lldp.detailed.pcap
# Loading packets from E:\pcap\lldp.detailed.pcap...
# Loaded 1 packets from lldp.detailed.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.detailed.pcap
#
# [101/231] Processing lldp.minimal.pcap
# Loading packets from E:\pcap\lldp.minimal.pcap...
# Loaded 1 packets from lldp.minimal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.minimal.pcap
#
# [102/231] Processing lldpmed_civicloc.pcap
# Loading packets from E:\pcap\lldpmed_civicloc.pcap...
# Loaded 1 packets from lldpmed_civicloc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldpmed_civicloc.pcap
#
# [103/231] Processing llt-sample.pcap
# Loading packets from E:\pcap\llt-sample.pcap...
# Loaded 10 packets from llt-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from llt-sample.pcap
#
# [104/231] Processing macsec_cisco_trunk.pcap
# Loading packets from E:\pcap\macsec_cisco_trunk.pcap...
# Loaded 1614 packets from macsec_cisco_trunk.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1614 packets from macsec_cisco_trunk.pcap
#
# [105/231] Processing mdb_bill_validator.pcap
# Loading packets from E:\pcap\mdb_bill_validator.pcap...
# Loaded 10 packets from mdb_bill_validator.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mdb_bill_validator.pcap
#
# [106/231] Processing mdb_cashless_1.pcap
# Loading packets from E:\pcap\mdb_cashless_1.pcap...
# Loaded 278 packets from mdb_cashless_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 278 packets from mdb_cashless_1.pcap
#
# [107/231] Processing mesh.pcap
# Loading packets from E:\pcap\mesh.pcap...
# Loaded 780 packets from mesh.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 780 packets from mesh.pcap
#
# [108/231] Processing metamako_trailer.pcap
# Loading packets from E:\pcap\metamako_trailer.pcap...
# Loaded 111 packets from metamako_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 111 packets from metamako_trailer.pcap
#
# [109/231] Processing metasploit-sip-invite-spoof.pcap
# Loading packets from E:\pcap\metasploit-sip-invite-spoof.pcap...
# Loaded 3 packets from metasploit-sip-invite-spoof.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from metasploit-sip-invite-spoof.pcap
#
# [110/231] Processing MGCP.pcap
# Loading packets from E:\pcap\MGCP.pcap...
# Loaded 14 packets from MGCP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from MGCP.pcap
#
# [111/231] Processing mndp.pcap
# Loading packets from E:\pcap\mndp.pcap...
# Loaded 10 packets from mndp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mndp.pcap
#
# [112/231] Processing Mobile-Originating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Originating-Call(AMR).pcap...
# Loaded 299 packets from Mobile-Originating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 299 packets from Mobile-Originating-Call(AMR).pcap
#
# [113/231] Processing Mobile-Terminating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Terminating-Call(AMR).pcap...
# Loaded 308 packets from Mobile-Terminating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 308 packets from Mobile-Terminating-Call(AMR).pcap
#
# [114/231] Processing mouse_replug2.pcap
# Loading packets from E:\pcap\mouse_replug2.pcap...
# WARNING: PcapReader: unknown LL type [186]/[0xba]. Using Raw packets
# Loaded 17 packets from mouse_replug2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from mouse_replug2.pcap
#
# [115/231] Processing mp4-ftyp-styp-sidx.pcap
# Loading packets from E:\pcap\mp4-ftyp-styp-sidx.pcap...
# WARNING: PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 5 packets from mp4-ftyp-styp-sidx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from mp4-ftyp-styp-sidx.pcap
#
# [116/231] Processing mpeg2_mp2t_with_cc_drop01.pcap
# Loading packets from E:\pcap\mpeg2_mp2t_with_cc_drop01.pcap...
# Loaded 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
#
# [117/231] Processing msgpack-generated.pcap
# Loading packets from E:\pcap\msgpack-generated.pcap...
# WARNING: more PcapReader: unknown LL type [252]/[0xfc]. Using Raw packets
# Loaded 23 packets from msgpack-generated.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from msgpack-generated.pcap
#
# [118/231] Processing msnms.pcap
# Loading packets from E:\pcap\msnms.pcap...
# Loaded 364 packets from msnms.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 364 packets from msnms.pcap
#
# [119/231] Processing mysql_complete.pcap
# Loading packets from E:\pcap\mysql_complete.pcap...
# Loaded 57 packets from mysql_complete.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 57 packets from mysql_complete.pcap
#
# [120/231] Processing nano.pcap
# Loading packets from E:\pcap\nano.pcap...
# Loaded 2500 packets from nano.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2500 packets from nano.pcap
#
# [121/231] Processing nano_tcp.pcap
# Loading packets from E:\pcap\nano_tcp.pcap...
# Loaded 117 packets from nano_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from nano_tcp.pcap
#
# [122/231] Processing nb6-hotspot.pcap
# Loading packets from E:\pcap\nb6-hotspot.pcap...
# Loaded 347 packets from nb6-hotspot.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 347 packets from nb6-hotspot.pcap
#
# [123/231] Processing nb6-http.pcap
# Loading packets from E:\pcap\nb6-http.pcap...
# Loaded 62 packets from nb6-http.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 62 packets from nb6-http.pcap
#
# [124/231] Processing nb6-startup.pcap
# Loading packets from E:\pcap\nb6-startup.pcap...
# Loaded 531 packets from nb6-startup.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 531 packets from nb6-startup.pcap
#
# [125/231] Processing nb6-telephone.pcap
# Loading packets from E:\pcap\nb6-telephone.pcap...
# Loaded 527 packets from nb6-telephone.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 527 packets from nb6-telephone.pcap
#
# [126/231] Processing netlink-conntrack.pcap
# Loading packets from E:\pcap\netlink-conntrack.pcap...
# Loaded 107 packets from netlink-conntrack.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 107 packets from netlink-conntrack.pcap
#
# [127/231] Processing netlink-ipset.pcap
# Loading packets from E:\pcap\netlink-ipset.pcap...
# Loaded 300 packets from netlink-ipset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 300 packets from netlink-ipset.pcap
#
# [128/231] Processing netlink-nflog.pcap
# Loading packets from E:\pcap\netlink-nflog.pcap...
# Loaded 22 packets from netlink-nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from netlink-nflog.pcap
#
# [129/231] Processing netlink.pcap
# Loading packets from E:\pcap\netlink.pcap...
# Loaded 673 packets from netlink.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 673 packets from netlink.pcap
#
# [130/231] Processing Network_Join_Nokia_Mobile.pcap
# Loading packets from E:\pcap\Network_Join_Nokia_Mobile.pcap...
# Loaded 1180 packets from Network_Join_Nokia_Mobile.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1180 packets from Network_Join_Nokia_Mobile.pcap
#
# [131/231] Processing new_rfp.pcap
# Loading packets from E:\pcap\new_rfp.pcap...
# Loaded 66 packets from new_rfp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from new_rfp.pcap
#
# [132/231] Processing new_rfp_on_wire.pcap
# Loading packets from E:\pcap\new_rfp_on_wire.pcap...
# Loaded 154 packets from new_rfp_on_wire.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 154 packets from new_rfp_on_wire.pcap
#
# [133/231] Processing nflog.pcap
# Loading packets from E:\pcap\nflog.pcap...
# Loaded 39 packets from nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from nflog.pcap
#
# [134/231] Processing nlmon-big.pcap
# Loading packets from E:\pcap\nlmon-big.pcap...
# Loaded 13 packets from nlmon-big.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from nlmon-big.pcap
#
# [135/231] Processing nntp.pcap
# Loading packets from E:\pcap\nntp.pcap...
# Loaded 32 packets from nntp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from nntp.pcap
#
# [136/231] Processing notifyLTE.pcap
# Loading packets from E:\pcap\notifyLTE.pcap...
# Loaded 1 packets from notifyLTE.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from notifyLTE.pcap
#
# [137/231] Processing nspi.pcap
# Loading packets from E:\pcap\nspi.pcap...
# Loaded 25 packets from nspi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from nspi.pcap
#
# [138/231] Processing NTLM-wenchao.pcap
# Loading packets from E:\pcap\NTLM-wenchao.pcap...
# Loaded 80 packets from NTLM-wenchao.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 80 packets from NTLM-wenchao.pcap
#
# [139/231] Processing NTP_sync.pcap
# Loading packets from E:\pcap\NTP_sync.pcap...
# Loaded 32 packets from NTP_sync.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from NTP_sync.pcap
#
# [140/231] Processing opensafety_epl_trace.pcap
# Loading packets from E:\pcap\opensafety_epl_trace.pcap...
# Loaded 31161 packets from opensafety_epl_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
# Extracted features for 31161 packets from opensafety_epl_trace.pcap
#
# [141/231] Processing opensafety_sercosiii_trace.pcap
# Loading packets from E:\pcap\opensafety_sercosiii_trace.pcap...
# Loaded 426 packets from opensafety_sercosiii_trace.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 426 packets from opensafety_sercosiii_trace.pcap
#
# [142/231] Processing opensafety_udp_trace.pcap
# Loading packets from E:\pcap\opensafety_udp_trace.pcap...
# Loaded 16036 packets from opensafety_udp_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
# Extracted features for 16036 packets from opensafety_udp_trace.pcap
#
# [143/231] Processing OptoMMP.pcap
# Loading packets from E:\pcap\OptoMMP.pcap...
# Loaded 20 packets from OptoMMP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 20 packets from OptoMMP.pcap
#
# [144/231] Processing p772-transfer-success.pcap
# Loading packets from E:\pcap\p772-transfer-success.pcap...
# Loaded 29 packets from p772-transfer-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from p772-transfer-success.pcap
#
# [145/231] Processing policy-authorizeNV.pcap
# Loading packets from E:\pcap\policy-authorizeNV.pcap...
# Loaded 117 packets from policy-authorizeNV.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from policy-authorizeNV.pcap
#
# [146/231] Processing ppp_lcp_ipcp.pcap
# Loading packets from E:\pcap\ppp_lcp_ipcp.pcap...
# Loaded 23 packets from ppp_lcp_ipcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from ppp_lcp_ipcp.pcap
#
# [147/231] Processing ptpv2.pcap
# Loading packets from E:\pcap\ptpv2.pcap...
# Loaded 39 packets from ptpv2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from ptpv2.pcap
#
# [148/231] Processing pvfs2-sample.pcap
# Loading packets from E:\pcap\pvfs2-sample.pcap...
# Loaded 44 packets from pvfs2-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 44 packets from pvfs2-sample.pcap
#
# [149/231] Processing rsasnakeoil2.pcap
# Loading packets from E:\pcap\rsasnakeoil2.pcap...
# Loaded 58 packets from rsasnakeoil2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 58 packets from rsasnakeoil2.pcap
#
# [150/231] Processing rtp-norm-transfer.pcap
# Loading packets from E:\pcap\rtp-norm-transfer.pcap...
# Loaded 226 packets from rtp-norm-transfer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 226 packets from rtp-norm-transfer.pcap
#
# [151/231] Processing rtp-opus-only.pcap
# Loading packets from E:\pcap\rtp-opus-only.pcap...
# Loaded 425 packets from rtp-opus-only.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 425 packets from rtp-opus-only.pcap
#
# [152/231] Processing s101glow.pcap
# Loading packets from E:\pcap\s101glow.pcap...
# Loaded 204 packets from s101glow.pcap
# Extracting features...
#   Processed 0 packets...
# ...
# Loaded 1 packets from siso_std_002_transmitter.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from siso_std_002_transmitter.pcap
#
# [180/231] Processing smb3-aes-128-ccm.pcap
# Loading packets from E:\pcap\smb3-aes-128-ccm.pcap...
# Loaded 54 packets from smb3-aes-128-ccm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 54 packets from smb3-aes-128-ccm.pcap
#
# [181/231] Processing smb311-aes-128-ccm-filt.pcap
# Loading packets from E:\pcap\smb311-aes-128-ccm-filt.pcap...
# Loaded 34 packets from smb311-aes-128-ccm-filt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 34 packets from smb311-aes-128-ccm-filt.pcap
#
# [182/231] Processing smtp.pcap
# Loading packets from E:\pcap\smtp.pcap...
# Loaded 60 packets from smtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 60 packets from smtp.pcap
#
# [183/231] Processing snakeoil-dtls.pcap
# Loading packets from E:\pcap\snakeoil-dtls.pcap...
# Loaded 9 packets from snakeoil-dtls.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from snakeoil-dtls.pcap
#
# [184/231] Processing snmp_usm.pcap
# Loading packets from E:\pcap\snmp_usm.pcap...
# Loaded 144 packets from snmp_usm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from snmp_usm.pcap
#
# [185/231] Processing sr-header.pcap
# Loading packets from E:\pcap\sr-header.pcap...
# Loaded 10 packets from sr-header.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from sr-header.pcap
#
# [186/231] Processing stanag-5602-simple-example.pcap
# Loading packets from E:\pcap\stanag-5602-simple-example.pcap...
# Loaded 2 packets from stanag-5602-simple-example.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from stanag-5602-simple-example.pcap
#
# [187/231] Processing Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Loading packets from E:\pcap\Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap...
# WARNING: PcapReader: unknown LL type [237]/[0xed]. Using Raw packets
# Loaded 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#
# [188/231] Processing steam-ihs-discovery.pcap
# Loading packets from E:\pcap\steam-ihs-discovery.pcap...
# Loaded 113 packets from steam-ihs-discovery.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 113 packets from steam-ihs-discovery.pcap
#
# [189/231] Processing stp.pcap
# Loading packets from E:\pcap\stp.pcap...
# Loaded 96 packets from stp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 96 packets from stp.pcap
#
# [190/231] Processing tcp-ecn-sample.pcap
# Loading packets from E:\pcap\tcp-ecn-sample.pcap...
# Loaded 479 packets from tcp-ecn-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 479 packets from tcp-ecn-sample.pcap
#
# [191/231] Processing TeamSpeak2.pcap
# Loading packets from E:\pcap\TeamSpeak2.pcap...
# Loaded 24 packets from TeamSpeak2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from TeamSpeak2.pcap
#
# [192/231] Processing telecomitalia-pppoe.pcap
# Loading packets from E:\pcap\telecomitalia-pppoe.pcap...
# Loaded 28 packets from telecomitalia-pppoe.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from telecomitalia-pppoe.pcap
#
# [193/231] Processing telnet-cooked.pcap
# Loading packets from E:\pcap\telnet-cooked.pcap...
# Loaded 92 packets from telnet-cooked.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from telnet-cooked.pcap
#
# [194/231] Processing telnet-raw.pcap
# Loading packets from E:\pcap\telnet-raw.pcap...
# Loaded 272 packets from telnet-raw.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 272 packets from telnet-raw.pcap
#
# [195/231] Processing Teredo.pcap
# Loading packets from E:\pcap\Teredo.pcap...
# Loaded 78 packets from Teredo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from Teredo.pcap
#
# [196/231] Processing tftp_rrq.pcap
# Loading packets from E:\pcap\tftp_rrq.pcap...
# Loaded 99 packets from tftp_rrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 99 packets from tftp_rrq.pcap
#
# [197/231] Processing tftp_wrq.pcap
# Loading packets from E:\pcap\tftp_wrq.pcap...
# Loaded 100 packets from tftp_wrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from tftp_wrq.pcap
#
# [198/231] Processing tipc-publication-payload-withdrawal.pcap
# Loading packets from E:\pcap\tipc-publication-payload-withdrawal.pcap...
# Loaded 40 packets from tipc-publication-payload-withdrawal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 40 packets from tipc-publication-payload-withdrawal.pcap
#
# [199/231] Processing TNS_Oracle1.pcap
# Loading packets from E:\pcap\TNS_Oracle1.pcap...
# Loaded 78 packets from TNS_Oracle1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from TNS_Oracle1.pcap
#
# [200/231] Processing TNS_Oracle2.pcap
# Loading packets from E:\pcap\TNS_Oracle2.pcap...
# Loaded 36 packets from TNS_Oracle2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle2.pcap
#
# [201/231] Processing TNS_Oracle3.pcap
# Loading packets from E:\pcap\TNS_Oracle3.pcap...
# Loaded 36 packets from TNS_Oracle3.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle3.pcap
#
# [202/231] Processing TNS_Oracle4.pcap
# Loading packets from E:\pcap\TNS_Oracle4.pcap...
# Loaded 10 packets from TNS_Oracle4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from TNS_Oracle4.pcap
#
# [203/231] Processing TNS_Oracle5.pcap
# Loading packets from E:\pcap\TNS_Oracle5.pcap...
# Loaded 56 packets from TNS_Oracle5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 56 packets from TNS_Oracle5.pcap
#
# [204/231] Processing tpncp_tcp.pcap
# Loading packets from E:\pcap\tpncp_tcp.pcap...
# Loaded 116 packets from tpncp_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from tpncp_tcp.pcap
#
# [205/231] Processing tpncp_udp.pcap
# Loading packets from E:\pcap\tpncp_udp.pcap...
# Loaded 132 packets from tpncp_udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 132 packets from tpncp_udp.pcap
#
# [206/231] Processing TTE_mix_small.pcap
# Loading packets from E:\pcap\TTE_mix_small.pcap...
# Loaded 25 packets from TTE_mix_small.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from TTE_mix_small.pcap
#
# [207/231] Processing tunnel.pcap
# Loading packets from E:\pcap\tunnel.pcap...
# Loaded 218 packets from tunnel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 218 packets from tunnel.pcap
#
# [208/231] Processing ua3g_freeseating_ipv4.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv4.pcap...
# Loaded 64 packets from ua3g_freeseating_ipv4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 64 packets from ua3g_freeseating_ipv4.pcap
#
# [209/231] Processing ua3g_freeseating_ipv6.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv6.pcap...
# Loaded 339 packets from ua3g_freeseating_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 339 packets from ua3g_freeseating_ipv6.pcap
#
# [210/231] Processing uaudp_ipv6.pcap
# Loading packets from E:\pcap\uaudp_ipv6.pcap...
# Loaded 2544 packets from uaudp_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2544 packets from uaudp_ipv6.pcap
#
# [211/231] Processing udp-nm_anon.pcap
# Loading packets from E:\pcap\udp-nm_anon.pcap...
# Loaded 1 packets from udp-nm_anon.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp-nm_anon.pcap
#
# [212/231] Processing udp_lite_checksum_0.pcap
# Loading packets from E:\pcap\udp_lite_checksum_0.pcap...
# Loaded 1 packets from udp_lite_checksum_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_checksum_0.pcap
#
# [213/231] Processing udp_lite_full_coverage_0.pcap
# Loading packets from E:\pcap\udp_lite_full_coverage_0.pcap...
# Loaded 1 packets from udp_lite_full_coverage_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_full_coverage_0.pcap
#
# [214/231] Processing udp_lite_illegal_1-7.pcap
# Loading packets from E:\pcap\udp_lite_illegal_1-7.pcap...
# Loaded 7 packets from udp_lite_illegal_1-7.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 7 packets from udp_lite_illegal_1-7.pcap
#
# [215/231] Processing udp_lite_illegal_large-coverage.pcap
# Loading packets from E:\pcap\udp_lite_illegal_large-coverage.pcap...
# Loaded 3 packets from udp_lite_illegal_large-coverage.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from udp_lite_illegal_large-coverage.pcap
#
# [216/231] Processing udp_lite_normal_coverage_8-20.pcap
# Loading packets from E:\pcap\udp_lite_normal_coverage_8-20.pcap...
# Loaded 13 packets from udp_lite_normal_coverage_8-20.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from udp_lite_normal_coverage_8-20.pcap
#
# [217/231] Processing UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Loading packets from E:\pcap\UMTS_FP_MAC_RLC_RRC_NBAP.pcap...
# Loaded 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
# Extracted features for 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#
# [218/231] Processing unistim-call.pcap
# Loading packets from E:\pcap\unistim-call.pcap...
# Loaded 105 packets from unistim-call.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from unistim-call.pcap
#
# [219/231] Processing usb_memory_stick.pcap
# Loading packets from E:\pcap\usb_memory_stick.pcap...
# WARNING: PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 1041 packets from usb_memory_stick.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1041 packets from usb_memory_stick.pcap
#
# [220/231] Processing usb_memory_stick_create_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_create_file.pcap...
# WARNING: PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 144 packets from usb_memory_stick_create_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from usb_memory_stick_create_file.pcap
#
# [221/231] Processing usb_memory_stick_delete_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_delete_file.pcap...
# WARNING: PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 66 packets from usb_memory_stick_delete_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from usb_memory_stick_delete_file.pcap
#
# [222/231] Processing UserLog.pcap
# Loading packets from E:\pcap\UserLog.pcap...
# Loaded 650 packets from UserLog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 650 packets from UserLog.pcap
#
# [223/231] Processing v6.pcap
# Loading packets from E:\pcap\v6.pcap...
# Loaded 161 packets from v6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 161 packets from v6.pcap
#
# [224/231] Processing VariousUSBDevices.pcap
# Loading packets from E:\pcap\VariousUSBDevices.pcap...
# WARNING: more PcapReader: unknown LL type [186]/[0xba]. Using Raw packets
# Loaded 8206 packets from VariousUSBDevices.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
# Extracted features for 8206 packets from VariousUSBDevices.pcap
#
# [225/231] Processing vnc-sample.pcap
# Loading packets from E:\pcap\vnc-sample.pcap...
# Loaded 81 packets from vnc-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 81 packets from vnc-sample.pcap
#
# [226/231] Processing wap_google.pcap
# Loading packets from E:\pcap\wap_google.pcap...
# Loaded 4 packets from wap_google.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from wap_google.pcap
#
# [227/231] Processing win_s4u2self.pcap
# Loading packets from E:\pcap\win_s4u2self.pcap...
# Loaded 14 packets from win_s4u2self.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from win_s4u2self.pcap
#
# [228/231] Processing wpa-Induction.pcap
# Loading packets from E:\pcap\wpa-Induction.pcap...
# Loaded 1093 packets from wpa-Induction.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1093 packets from wpa-Induction.pcap
#
# [229/231] Processing x400-ping-refuse.pcap
# Loading packets from E:\pcap\x400-ping-refuse.pcap...
# Loaded 10 packets from x400-ping-refuse.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from x400-ping-refuse.pcap
#
# [230/231] Processing x400-ping-success.pcap
# Loading packets from E:\pcap\x400-ping-success.pcap...
# Loaded 12 packets from x400-ping-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from x400-ping-success.pcap
#
# [231/231] Processing yami.pcap
# Loading packets from E:\pcap\yami.pcap...
# Loaded 2 packets from yami.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from yami.pcap
#
# Combining data from 231 files...
# Total packets processed: 214523
#
# Overall label distribution:
# label
# other_tcp        81387
# non_ip           62423
# other_udp        60934
# other_ip          6769
# web_traffic       1205
# dns                612
# remote_access      413
# database           317
# snmp               144
# icmp                81
# ntp                 66
# dhcp                61
# file_transfer       58
# email               53
# Name: count, dtype: int64
#
# Dataset shape: (214523, 18)
# Number of classes: 14
#
# Training model...
# Cleaning data...
# Cleaned dataset: 214523/214523 packets retained
#
# Model Accuracy: 1.000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      database       0.98      0.94      0.96        63
#          dhcp       1.00      1.00      1.00        12
#           dns       1.00      1.00      1.00       122
#         email       1.00      1.00      1.00        11
# file_transfer       1.00      1.00      1.00        12
#          icmp       1.00      1.00      1.00        16
#        non_ip       1.00      1.00      1.00     12485
#           ntp       1.00      1.00      1.00        13
#      other_ip       1.00      1.00      1.00      1354
#     other_tcp       1.00      1.00      1.00     16277
#     other_udp       1.00      1.00      1.00     12187
# remote_access       1.00      1.00      1.00        83
#          snmp       1.00      1.00      1.00        29
#   web_traffic       1.00      0.99      0.99       241
#
#      accuracy                           1.00     42905
#     macro avg       1.00      0.99      1.00     42905
#  weighted avg       1.00      1.00      1.00     42905
#
#
# Top 10 Most Important Features:
#         feature  importance
# 7        is_tcp    0.152725
# 1        has_ip    0.101746
# 3        ip_ttl    0.080404
# 6      ip_proto    0.075668
# 13   tcp_window    0.074978
# 12    tcp_flags    0.072696
# 16  tcp_dataofs    0.069056
# 2     ip_length    0.066414
# 14      tcp_seq    0.063193
# 10     src_port    0.058224
# Model trained successfully!
# Classifier is now available globally!
# Classifier type: <class '__main__.PacketClassifier'>
# Classifier is ready for predictions!

# %%
import pandas as pd
import numpy as np
from scapy.all import rdpcap, IP, TCP, UDP, ICMP
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import os
import glob
import warnings
warnings.filterwarnings('ignore')

class PacketClassifier:
    def __init__(self):
        self.scaler = StandardScaler()
        self.label_encoder = LabelEncoder()
        self.model = RandomForestClassifier(n_estimators=100, random_state=42)
        self.feature_columns = []
        
    def extract_packet_features(self, packet):
        """Extract features from a single packet"""
        features = {}
        
        try:
            # Basic packet features
            features['packet_length'] = len(packet)
            features['has_ip'] = 1 if packet.haslayer(IP) else 0
            
            if packet.haslayer(IP):
                ip_layer = packet[IP]
                features['ip_length'] = self._safe_int(ip_layer.len)
                features['ip_ttl'] = self._safe_int(ip_layer.ttl)
                features['ip_flags'] = self._safe_int(ip_layer.flags)
                features['ip_frag'] = self._safe_int(ip_layer.frag)
                features['ip_proto'] = self._safe_int(ip_layer.proto)
                
                # Protocol-specific features
                features['is_tcp'] = 1 if packet.haslayer(TCP) else 0
                features['is_udp'] = 1 if packet.haslayer(UDP) else 0
                features['is_icmp'] = 1 if packet.haslayer(ICMP) else 0
                
                if packet.haslayer(TCP):
                    tcp_layer = packet[TCP]
                    features['src_port'] = self._safe_int(tcp_layer.sport)
                    features['dst_port'] = self._safe_int(tcp_layer.dport)
                    features['tcp_flags'] = self._safe_int(tcp_layer.flags)
                    features['tcp_window'] = self._safe_int(tcp_layer.window)
                    features['tcp_seq'] = self._safe_int(tcp_layer.seq)
                    features['tcp_ack'] = self._safe_int(tcp_layer.ack)
                    features['tcp_dataofs'] = self._safe_int(tcp_layer.dataofs)
                else:
                    features['src_port'] = 0
                    features['dst_port'] = 0
                    features['tcp_flags'] = 0
                    features['tcp_window'] = 0
                    features['tcp_seq'] = 0
                    features['tcp_ack'] = 0
                    features['tcp_dataofs'] = 0
                    
                if packet.haslayer(UDP):
                    udp_layer = packet[UDP]
                    features['src_port'] = self._safe_int(udp_layer.sport)
                    features['dst_port'] = self._safe_int(udp_layer.dport)
                    features['udp_length'] = self._safe_int(udp_layer.len)
                else:
                    features['udp_length'] = 0
                    
            else:
                # Default values for non-IP packets
                for key in ['ip_length', 'ip_ttl', 'ip_flags', 'ip_frag', 'ip_proto',
                           'is_tcp', 'is_udp', 'is_icmp', 'src_port', 'dst_port',
                           'tcp_flags', 'tcp_window', 'tcp_seq', 'tcp_ack', 
                           'tcp_dataofs', 'udp_length']:
                    features[key] = 0
                    
        except Exception as e:
            print(f"Warning: Error extracting features from packet: {e}")
            # Return default features in case of error
            for key in ['packet_length', 'has_ip', 'ip_length', 'ip_ttl', 'ip_flags', 
                       'ip_frag', 'ip_proto', 'is_tcp', 'is_udp', 'is_icmp', 
                       'src_port', 'dst_port', 'tcp_flags', 'tcp_window', 
                       'tcp_seq', 'tcp_ack', 'tcp_dataofs', 'udp_length']:
                features[key] = 0
                
        return features
    
    def _safe_int(self, value):
        """Safely convert value to integer, handling FlagValue and other objects"""
        try:
            # Handle Scapy FlagValue objects
            if hasattr(value, 'value'):
                return int(value.value)
            # Handle None values
            elif value is None:
                return 0
            # Handle regular numeric values
            else:
                return int(value)
        except (ValueError, TypeError, AttributeError):
            # Return 0 for any conversion errors
            return 0
    
    def classify_packet(self, packet):
        """Classify packet based on common patterns"""
        try:
            if not packet.haslayer(IP):
                return 'non_ip'
                
            ip_layer = packet[IP]
            
            if packet.haslayer(TCP):
                tcp_layer = packet[TCP]
                src_port = self._safe_int(tcp_layer.sport)
                dst_port = self._safe_int(tcp_layer.dport)
                
                # Web traffic
                if dst_port in [80, 443, 8080, 8443] or src_port in [80, 443, 8080, 8443]:
                    return 'web_traffic'
                # Email
                elif dst_port in [25, 587, 465, 993, 995, 143, 110] or src_port in [25, 587, 465, 993, 995, 143, 110]:
                    return 'email'
                # SSH/Telnet
                elif dst_port in [22, 23] or src_port in [22, 23]:
                    return 'remote_access'
                # FTP
                elif dst_port in [21, 20] or src_port in [21, 20]:
                    return 'file_transfer'
                # Database
                elif dst_port in [1433, 3306, 5432, 1521] or src_port in [1433, 3306, 5432, 1521]:
                    return 'database'
                else:
                    return 'other_tcp'
                    
            elif packet.haslayer(UDP):
                udp_layer = packet[UDP]
                src_port = self._safe_int(udp_layer.sport)
                dst_port = self._safe_int(udp_layer.dport)
                
                # DNS
                if dst_port == 53 or src_port == 53:
                    return 'dns'
                # DHCP
                elif dst_port in [67, 68] or src_port in [67, 68]:
                    return 'dhcp'
                # NTP
                elif dst_port == 123 or src_port == 123:
                    return 'ntp'
                # SNMP
                elif dst_port in [161, 162] or src_port in [161, 162]:
                    return 'snmp'
                else:
                    return 'other_udp'
                    
            elif packet.haslayer(ICMP):
                return 'icmp'
            else:
                return 'other_ip'
                
        except Exception as e:
            print(f"Warning: Error classifying packet: {e}")
            return 'unknown'
    
    def load_and_process_pcap(self, pcap_file_path):
        """Load single pcap file and extract features"""
        print(f"Loading packets from {pcap_file_path}...")
        
        try:
            packets = rdpcap(pcap_file_path)
            print(f"Loaded {len(packets)} packets from {os.path.basename(pcap_file_path)}")
        except Exception as e:
            print(f"Error loading pcap file {pcap_file_path}: {e}")
            return None, None
        
        features_list = []
        labels_list = []
        
        print("Extracting features...")
        for i, packet in enumerate(packets):
            if i % 1000 == 0:
                print(f"  Processed {i} packets...")
                
            try:
                # Extract features
                features = self.extract_packet_features(packet)
                features_list.append(features)
                
                # Generate label
                label = self.classify_packet(packet)
                labels_list.append(label)
                
            except Exception as e:
                print(f"Error processing packet {i}: {e}")
                continue
        
        # Convert to DataFrame
        df_features = pd.DataFrame(features_list)
        df_labels = pd.Series(labels_list, name='label')
        
        print(f"Extracted features for {len(df_features)} packets from {os.path.basename(pcap_file_path)}")
        
        return df_features, df_labels
    
    def load_and_process_folder(self, folder_path, file_limit=None):
        """Load and process multiple pcap files from a folder"""
        print(f"Scanning folder: {folder_path}")
        
        # Find all pcap/pcapng files
        pcap_patterns = ['*.pcap', '*.pcapng', '*.cap']
        pcap_files = []
        
        for pattern in pcap_patterns:
            pcap_files.extend(glob.glob(os.path.join(folder_path, pattern)))
        
        if not pcap_files:
            print(f"No pcap/pcapng files found in {folder_path}")
            print("Supported file extensions: .pcap, .pcapng, .cap")
            return None, None
        
        print(f"Found {len(pcap_files)} pcap files:")
        for file in pcap_files:
            print(f"  - {os.path.basename(file)}")
        
        # Limit files if specified
        if file_limit:
            pcap_files = pcap_files[:file_limit]
            print(f"Processing first {len(pcap_files)} files due to limit")
        
        all_features = []
        all_labels = []
        
        for i, pcap_file in enumerate(pcap_files, 1):
            print(f"\n[{i}/{len(pcap_files)}] Processing {os.path.basename(pcap_file)}")
            
            features, labels = self.load_and_process_pcap(pcap_file)
            
            if features is not None and not features.empty:
                all_features.append(features)
                all_labels.append(labels)
            else:
                print(f"Skipping {os.path.basename(pcap_file)} due to processing errors")
        
        if not all_features:
            print("No valid features extracted from any files")
            return None, None
        
        # Combine all data
        print(f"\nCombining data from {len(all_features)} files...")
        combined_features = pd.concat(all_features, ignore_index=True)
        combined_labels = pd.concat(all_labels, ignore_index=True)
        
        print(f"Total packets processed: {len(combined_features)}")
        print("\nOverall label distribution:")
        print(combined_labels.value_counts())
        
        return combined_features, combined_labels
    
    def train_model(self, features, labels):
        """Train the classification model"""
        print("\nTraining model...")
        
        # Store feature columns
        self.feature_columns = features.columns.tolist()
        
        # Clean the data: remove any rows with non-numeric values
        print("Cleaning data...")
        original_size = len(features)
        
        # Replace any remaining non-numeric values with 0
        features_cleaned = features.copy()
        for col in features_cleaned.columns:
            features_cleaned[col] = pd.to_numeric(features_cleaned[col], errors='coerce').fillna(0)
        
        # Remove rows where all features are 0 (likely corrupted packets)
        valid_rows = (features_cleaned != 0).any(axis=1)
        features_cleaned = features_cleaned[valid_rows]
        labels_cleaned = labels[valid_rows]
        
        print(f"Cleaned dataset: {len(features_cleaned)}/{original_size} packets retained")
        
        if len(features_cleaned) == 0:
            print("Error: No valid data remaining after cleaning")
            return None, None, None
        
        # Encode labels
        labels_encoded = self.label_encoder.fit_transform(labels_cleaned)
        
        # Scale features
        features_scaled = self.scaler.fit_transform(features_cleaned)
        
        # Check if we have enough samples for each class
        unique_labels, label_counts = np.unique(labels_encoded, return_counts=True)
        min_samples = min(label_counts)
        
        if min_samples < 2:
            print("Warning: Some classes have very few samples. Results may not be reliable.")
        
        # Split data with stratification if possible
        try:
            X_train, X_test, y_train, y_test = train_test_split(
                features_scaled, labels_encoded, test_size=0.2, random_state=42, 
                stratify=labels_encoded if min_samples >= 2 else None
            )
        except ValueError:
            # Fall back to random split if stratification fails
            X_train, X_test, y_train, y_test = train_test_split(
                features_scaled, labels_encoded, test_size=0.2, random_state=42
            )
        
        # Train model
        self.model.fit(X_train, y_train)
        
        # Evaluate
        y_pred = self.model.predict(X_test)
        
        accuracy = accuracy_score(y_test, y_pred)
        print(f"\nModel Accuracy: {accuracy:.3f}")
        
        # Classification report
        print("\nClassification Report:")
        class_names = self.label_encoder.classes_
        
        # Get unique labels in test set to avoid mismatch
        unique_test_labels = np.unique(y_test)
        test_class_names = [class_names[i] for i in unique_test_labels]
        
        print(classification_report(y_test, y_pred, 
                                  target_names=test_class_names if len(test_class_names) == len(np.unique(y_pred)) else None,
                                  zero_division=0))
        
        # Feature importance
        feature_importance = pd.DataFrame({
            'feature': self.feature_columns,
            'importance': self.model.feature_importances_
        }).sort_values('importance', ascending=False)
        
        print("\nTop 10 Most Important Features:")
        print(feature_importance.head(10))
        
        return X_test, y_test, y_pred
    
    def plot_results(self, y_test, y_pred):
        """Plot confusion matrix and feature importance"""
        plt.figure(figsize=(15, 5))
        
        # Confusion Matrix
        plt.subplot(1, 3, 1)
        cm = confusion_matrix(y_test, y_pred)
        class_names = self.label_encoder.classes_
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                   xticklabels=class_names, yticklabels=class_names)
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.xticks(rotation=45)
        plt.yticks(rotation=0)
        
        # Feature Importance
        plt.subplot(1, 3, 2)
        feature_importance = pd.DataFrame({
            'feature': self.feature_columns,
            'importance': self.model.feature_importances_
        }).sort_values('importance', ascending=True).tail(10)
        
        plt.barh(feature_importance['feature'], feature_importance['importance'])
        plt.title('Top 10 Feature Importance')
        plt.xlabel('Importance')
        
        # Label Distribution
        plt.subplot(1, 3, 3)
        label_counts = pd.Series(self.label_encoder.inverse_transform(y_test)).value_counts()
        plt.pie(label_counts.values, labels=label_counts.index, autopct='%1.1f%%')
        plt.title('Test Set Label Distribution')
        
        plt.tight_layout()
        plt.show()
    
    def predict_packet_class(self, packet):
        """Predict the class of a single packet"""
        features = self.extract_packet_features(packet)
        features_df = pd.DataFrame([features])
        
        # Ensure all columns are present
        for col in self.feature_columns:
            if col not in features_df.columns:
                features_df[col] = 0
        
        features_df = features_df[self.feature_columns]
        features_scaled = self.scaler.transform(features_df)
        
        prediction = self.model.predict(features_scaled)[0]
        probability = self.model.predict_proba(features_scaled)[0]
        
        predicted_class = self.label_encoder.inverse_transform([prediction])[0]
        confidence = max(probability)
        
        return predicted_class, confidence

# Global classifier variable for Jupyter notebook usage
classifier = None

# Example usage
def main():
    """
    Main function to demonstrate the packet classifier
    
    To use this:
    1. Install required packages: pip install scapy scikit-learn pandas matplotlib seaborn
    2. Update the folder_path below to point to your pcap files folder
    3. Run the script
    """
    
    global classifier
    classifier = PacketClassifier()
    
    # Update this path to your pcap files folder
    pcap_folder = r"E:\pcap"  # Replace with your folder path
    # Alternative examples:
    # pcap_folder = "/path/to/your/pcap/files"  # Linux/Mac
    # pcap_folder = r"C:\path\to\your\pcap\files"  # Windows
    
    print("Network Packet Classification ML Model")
    print("=" * 50)
    
    # Check if folder exists
    if not os.path.exists(pcap_folder):
        print(f"Error: Folder '{pcap_folder}' does not exist")
        print("\nPlease:")
        print("1. Create the folder or update the path")
        print("2. Place your .pcap/.pcapng files in the folder")
        print("3. Update the 'pcap_folder' variable in the code")
        return None
    
    try:
        # Option 1: Process all files in folder
        features, labels = classifier.load_and_process_folder(pcap_folder)
        
        # Option 2: Process with file limit (uncomment to use)
        # features, labels = classifier.load_and_process_folder(pcap_folder, file_limit=5)
        
        # Option 3: Process single file (uncomment to use)
        # single_file = os.path.join(pcap_folder, "your_file.pcap")
        # features, labels = classifier.load_and_process_pcap(single_file)
        
        if features is not None and not features.empty:
            print(f"\nDataset shape: {features.shape}")
            print(f"Number of classes: {labels.nunique()}")
            
            # Check if we have enough data for training
            if len(features) < 100:
                print("Warning: Very small dataset. Consider adding more pcap files.")
            
            # Train the model
            X_test, y_test, y_pred = classifier.train_model(features, labels)
            
            # Plot results
            if X_test is not None:
                classifier.plot_results(y_test, y_pred)
            
            # Save model info
            print("\nModel trained successfully!")
            print("You can now use the classifier for predictions:")
            print("predicted_class, confidence = classifier.predict_packet_class(packet)")
            
            return classifier
            
        else:
            print("No valid data extracted from pcap files.")
            return None
            
    except Exception as e:
        print(f"Error during processing: {e}")
        return None

# Test functions for Jupyter notebook usage
def classify_packet_examples(trained_classifier):
    """Examples of classifying different types of packets"""
    if trained_classifier is None:
        print("Error: Classifier not trained. Please run main() first.")
        return
    
    from scapy.all import IP, TCP, UDP, ICMP
    
    print("\n" + "="*50)
    print("TESTING PACKET CLASSIFICATION")
    print("="*50)
    
    # Example 1: HTTP packet
    http_packet = IP(dst="192.168.1.1")/TCP(dport=80)
    pred_class, confidence = trained_classifier.predict_packet_class(http_packet)
    print(f"HTTP packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 2: DNS packet  
    dns_packet = IP(dst="8.8.8.8")/UDP(dport=53)
    pred_class, confidence = trained_classifier.predict_packet_class(dns_packet)
    print(f"DNS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 3: HTTPS packet
    https_packet = IP(dst="www.google.com")/TCP(dport=443)
    pred_class, confidence = trained_classifier.predict_packet_class(https_packet)
    print(f"HTTPS packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 4: ICMP packet
    icmp_packet = IP(dst="192.168.1.1")/ICMP()
    pred_class, confidence = trained_classifier.predict_packet_class(icmp_packet)
    print(f"ICMP packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 5: SSH packet
    ssh_packet = IP(dst="192.168.1.100")/TCP(dport=22)
    pred_class, confidence = trained_classifier.predict_packet_class(ssh_packet)
    print(f"SSH packet: {pred_class} (confidence: {confidence:.3f})")
    
    # Example 6: FTP packet
    ftp_packet = IP(dst="ftp.example.com")/TCP(dport=21)
    pred_class, confidence = trained_classifier.predict_packet_class(ftp_packet)
    print(f"FTP packet: {pred_class} (confidence: {confidence:.3f})")

def classify_new_pcap_file(trained_classifier, pcap_file_path):
    """Classify all packets in a new pcap file"""
    if trained_classifier is None:
        print("Error: Classifier not trained. Please run main() first.")
        return None
        
    print(f"Classifying packets in: {pcap_file_path}")
    
    try:
        from scapy.all import rdpcap
        packets = rdpcap(pcap_file_path)
        
        results = []
        for i, packet in enumerate(packets):
            predicted_class, confidence = trained_classifier.predict_packet_class(packet)
            results.append({
                'packet_id': i,
                'predicted_class': predicted_class,
                'confidence': confidence
            })
            
            # Print first 10 predictions as examples
            if i < 10:
                print(f"Packet {i}: {predicted_class} (confidence: {confidence:.3f})")
        
        return results
        
    except Exception as e:
        print(f"Error: {e}")
        return None

# Additional utility functions
def list_pcap_files(folder_path):
    """List all pcap files in a folder"""
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist")
        return []
    
    pcap_patterns = ['*.pcap', '*.pcapng', '*.cap']
    pcap_files = []
    
    for pattern in pcap_patterns:
        pcap_files.extend(glob.glob(os.path.join(folder_path, pattern)))
    
    return pcap_files

def get_file_info(folder_path):
    """Get information about pcap files in folder"""
    files = list_pcap_files(folder_path)
    
    print(f"PCAP Files in '{folder_path}':")
    print("-" * 60)
    
    if not files:
        print("No pcap files found")
        return
    
    total_size = 0
    for file in files:
        size = os.path.getsize(file)
        total_size += size
        print(f"{os.path.basename(file):30} {size/1024/1024:.2f} MB")
    
    print("-" * 60)
    print(f"Total files: {len(files)}")
    print(f"Total size: {total_size/1024/1024:.2f} MB")

if __name__ == "__main__":
    # Uncomment to see file info first
    # get_file_info("./pcap_files")
    
    main()
# Out:
# Network Packet Classification ML Model
# ==================================================
# Scanning folder: E:\pcap
# Found 231 pcap files:
#   - 6to4.pcap
#   - aaa.pcap
#   - abis-accept-network.pcap
#   - abis-reject-network.pcap
#   - airtunes-1.pcap
#   - alp-sample1.pcap
#   - alp-sample2.pcap
#   - anony-tcp-std.pcap
#   - ansi_map_ota.pcap
#   - ansi_map_win.pcap
#   - ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#   - Apple_IP-over-IEEE_1394_Packet.pcap
#   - arp-storm.pcap
#   - Asterisk_ZFONE_XLITE.pcap
#   - bfd-raw-auth-md5.pcap
#   - bfd-raw-auth-sha1.pcap
#   - bgpsec.pcap
#   - bgp_shutdown_communication.pcap
#   - bicc.pcap
#   - BITTORRENT.pcap
#   - bmp.pcap
#   - c1222_over_ipv6.pcap
#   - c1222_std_example8.pcap
#   - camel.pcap
#   - camel2.pcap
#   - can-2003-0003.pcap
#   - cdp.pcap
#   - cdp_v2.pcap
#   - ch11-25-slt.pcap
#   - chargen-tcp.pcap
#   - chargen-udp.pcap
#   - cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#   - cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#   - coap-cbor.pcap
#   - couchbase-lww.pcap
#   - couchbase_subdoc_multi.pcap
#   - dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#   - dhcp-nanosecond.pcap
#   - dhcp.pcap
#   - dhcpv6_1.pcap
#   - DICOM_C-ECHO-echoscu.pcap
#   - dlep.pcap
#   - dnp3_read.pcap
#   - dnp3_select_operate.pcap
#   - dnp3_write.pcap
#   - dns-remoteshell.pcap
#   - dns_port.pcap
#   - DTMFsipinfo.pcap
#   - dvb-ci_1.pcap
#   - dvb-ci_2.pcap
#   - dvb-ci_UV1_0000.pcap
#   - eapol-mka.pcap
#   - ecpri.pcap
#   - eia709.1-over-eia852.pcap
#   - eigrp-for-ipv6-auth.pcap
#   - eigrp-for-ipv6-stub.pcap
#   - eigrp-for-ipv6-updates.pcap
#   - eigrp-ipx.pcap
#   - epmd.pcap
#   - exablaze_trailer.pcap
#   - exec-sample.pcap
#   - FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#   - fix-ssl.pcap
#   - fix.pcap
#   - fuzz-2008-09-30-17714.pcap
#   - gopher.pcap
#   - greb_filterlist.pcap
#   - gsm-r.uus1.pcap
#   - gsm_map_with_ussd_string.pcap
#   - h263-over-rtp.pcap
#   - hart_ip.pcap
#   - hcrt.pcap
#   - hdcp_authentication_sample.pcap
#   - homeplug_network_statistics_basic.pcap
#   - homeplug_request_channel_estimation.pcap
#   - homeplug_request_parameters_and_statistics.pcap
#   - hsrp.pcap
#   - http-chunked-gzip.pcap
#   - iec104.pcap
#   - IGMP-dataset.pcap
#   - infiniband.pcap
#   - iperf-mptcp-0-0.pcap
#   - ipmb.multi.packets.pcap
#   - ipmi.SDR.FRU.SEL.pcap
#   - ipmi.sensor.event.RR.pcap
#   - ipp.pcap
#   - ipv4frags.pcap
#   - ipv4_cipso_option.pcap
#   - isup_load_generator.pcap
#   - jaeger-compact.pcap
#   - japan_tcap_over_m2pa.pcap
#   - jxta-mcast-sample.pcap
#   - jxta-sample.pcap
#   - kismet-client-server-dump-1.pcap
#   - ldap-and-search.pcap
#   - ldap-attribute-value-list.pcap
#   - ldap-extensible-match-with-dn.pcap
#   - ldap-extensible-match.pcap
#   - ldap-substring.pcap
#   - lldp.detailed.pcap
#   - lldp.minimal.pcap
#   - lldpmed_civicloc.pcap
#   - llt-sample.pcap
#   - macsec_cisco_trunk.pcap
#   - mdb_bill_validator.pcap
#   - mdb_cashless_1.pcap
#   - mesh.pcap
#   - metamako_trailer.pcap
#   - metasploit-sip-invite-spoof.pcap
#   - MGCP.pcap
#   - mndp.pcap
#   - Mobile-Originating-Call(AMR).pcap
#   - Mobile-Terminating-Call(AMR).pcap
#   - mouse_replug2.pcap
#   - mp4-ftyp-styp-sidx.pcap
#   - mpeg2_mp2t_with_cc_drop01.pcap
#   - msgpack-generated.pcap
#   - msnms.pcap
#   - mysql_complete.pcap
#   - nano.pcap
#   - nano_tcp.pcap
#   - nb6-hotspot.pcap
#   - nb6-http.pcap
#   - nb6-startup.pcap
#   - nb6-telephone.pcap
#   - netlink-conntrack.pcap
#   - netlink-ipset.pcap
#   - netlink-nflog.pcap
#   - netlink.pcap
#   - Network_Join_Nokia_Mobile.pcap
#   - new_rfp.pcap
#   - new_rfp_on_wire.pcap
#   - nflog.pcap
#   - nlmon-big.pcap
#   - nntp.pcap
#   - notifyLTE.pcap
#   - nspi.pcap
#   - NTLM-wenchao.pcap
#   - NTP_sync.pcap
#   - opensafety_epl_trace.pcap
#   - opensafety_sercosiii_trace.pcap
#   - opensafety_udp_trace.pcap
#   - OptoMMP.pcap
#   - p772-transfer-success.pcap
#   - policy-authorizeNV.pcap
#   - ppp_lcp_ipcp.pcap
#   - ptpv2.pcap
#   - pvfs2-sample.pcap
#   - rsasnakeoil2.pcap
#   - rtp-norm-transfer.pcap
#   - rtp-opus-only.pcap
#   - s101glow.pcap
#   - S5066-Expedited.pcap
#   - S5066-HFChat-1.pcap
#   - S5066-HFChat-Rejected.pcap
#   - s7comm_downloading_block_db1.pcap
#   - s7comm_program_blocklist_onlineview.pcap
#   - s7comm_reading_plc_status.pcap
#   - s7comm_reading_setting_plc_time.pcap
#   - s7comm_varservice_libnodavedemo.pcap
#   - s7comm_varservice_libnodavedemo_bench.pcap
#   - sbus.pcap
#   - scsi-osd-example-001.pcap
#   - segmented_fpm.pcap
#   - SIMULCRYPT.pcap
#   - sip-rtp-dvi4.pcap
#   - sip-rtp-g711.pcap
#   - sip-rtp-g722.pcap
#   - sip-rtp-g726.pcap
#   - sip-rtp-g729a.pcap
#   - sip-rtp-gsm.pcap
#   - sip-rtp-ilbc.pcap
#   - sip-rtp-l16.pcap
#   - sip-rtp-lpc.pcap
#   - sip-rtp-opus-hybrid.pcap
#   - sip-rtp-opus.pcap
#   - sip-rtp-speex.pcap
#   - siso_std_002_annex_b_example.pcap
#   - siso_std_002_transmitter.pcap
#   - smb3-aes-128-ccm.pcap
#   - smb311-aes-128-ccm-filt.pcap
#   - smtp.pcap
#   - snakeoil-dtls.pcap
#   - snmp_usm.pcap
#   - sr-header.pcap
#   - stanag-5602-simple-example.pcap
#   - Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#   - steam-ihs-discovery.pcap
#   - stp.pcap
#   - tcp-ecn-sample.pcap
#   - TeamSpeak2.pcap
#   - telecomitalia-pppoe.pcap
#   - telnet-cooked.pcap
#   - telnet-raw.pcap
#   - Teredo.pcap
#   - tftp_rrq.pcap
#   - tftp_wrq.pcap
#   - tipc-publication-payload-withdrawal.pcap
#   - TNS_Oracle1.pcap
#   - TNS_Oracle2.pcap
#   - TNS_Oracle3.pcap
#   - TNS_Oracle4.pcap
#   - TNS_Oracle5.pcap
#   - tpncp_tcp.pcap
#   - tpncp_udp.pcap
#   - TTE_mix_small.pcap
#   - tunnel.pcap
#   - ua3g_freeseating_ipv4.pcap
#   - ua3g_freeseating_ipv6.pcap
#   - uaudp_ipv6.pcap
#   - udp-nm_anon.pcap
#   - udp_lite_checksum_0.pcap
#   - udp_lite_full_coverage_0.pcap
#   - udp_lite_illegal_1-7.pcap
#   - udp_lite_illegal_large-coverage.pcap
#   - udp_lite_normal_coverage_8-20.pcap
#   - UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#   - unistim-call.pcap
#   - usb_memory_stick.pcap
#   - usb_memory_stick_create_file.pcap
#   - usb_memory_stick_delete_file.pcap
#   - UserLog.pcap
#   - v6.pcap
#   - VariousUSBDevices.pcap
#   - vnc-sample.pcap
#   - wap_google.pcap
#   - win_s4u2self.pcap
#   - wpa-Induction.pcap
#   - x400-ping-refuse.pcap
#   - x400-ping-success.pcap
#   - yami.pcap
#
# [1/231] Processing 6to4.pcap
# Loading packets from E:\pcap\6to4.pcap...
# Loaded 5 packets from 6to4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from 6to4.pcap
#
# [2/231] Processing aaa.pcap
# Loading packets from E:\pcap\aaa.pcap...
# Loaded 691 packets from aaa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 691 packets from aaa.pcap
#
# [3/231] Processing abis-accept-network.pcap
# Loading packets from E:\pcap\abis-accept-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 85 packets from abis-accept-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from abis-accept-network.pcap
#
# [4/231] Processing abis-reject-network.pcap
# Loading packets from E:\pcap\abis-reject-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 78 packets from abis-reject-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from abis-reject-network.pcap
#
# [5/231] Processing airtunes-1.pcap
# Loading packets from E:\pcap\airtunes-1.pcap...
# Loaded 1748 packets from airtunes-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1748 packets from airtunes-1.pcap
#
# [6/231] Processing alp-sample1.pcap
# Loading packets from E:\pcap\alp-sample1.pcap...
# WARNING: more PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 17 packets from alp-sample1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from alp-sample1.pcap
#
# [7/231] Processing alp-sample2.pcap
# Loading packets from E:\pcap\alp-sample2.pcap...
# Loaded 85 packets from alp-sample2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from alp-sample2.pcap
#
# [8/231] Processing anony-tcp-std.pcap
# Loading packets from E:\pcap\anony-tcp-std.pcap...
# Loaded 170 packets from anony-tcp-std.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 170 packets from anony-tcp-std.pcap
#
# [9/231] Processing ansi_map_ota.pcap
# Loading packets from E:\pcap\ansi_map_ota.pcap...
# Loaded 24 packets from ansi_map_ota.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from ansi_map_ota.pcap
#
# [10/231] Processing ansi_map_win.pcap
# Loading packets from E:\pcap\ansi_map_win.pcap...
# Loaded 9 packets from ansi_map_win.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from ansi_map_win.pcap
#
# [11/231] Processing ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Loading packets from E:\pcap\ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap...
# Loaded 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#
# [12/231] Processing Apple_IP-over-IEEE_1394_Packet.pcap
# Loading packets from E:\pcap\Apple_IP-over-IEEE_1394_Packet.pcap...
# Loaded 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from Apple_IP-over-IEEE_1394_Packet.pcap
#
# [13/231] Processing arp-storm.pcap
# Loading packets from E:\pcap\arp-storm.pcap...
# Loaded 622 packets from arp-storm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 622 packets from arp-storm.pcap
#
# [14/231] Processing Asterisk_ZFONE_XLITE.pcap
# Loading packets from E:\pcap\Asterisk_ZFONE_XLITE.pcap...
# Loaded 1042 packets from Asterisk_ZFONE_XLITE.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1042 packets from Asterisk_ZFONE_XLITE.pcap
#
# [15/231] Processing bfd-raw-auth-md5.pcap
# Loading packets from E:\pcap\bfd-raw-auth-md5.pcap...
# Loaded 31 packets from bfd-raw-auth-md5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 31 packets from bfd-raw-auth-md5.pcap
#
# [16/231] Processing bfd-raw-auth-sha1.pcap
# Loading packets from E:\pcap\bfd-raw-auth-sha1.pcap...
# Loaded 25 packets from bfd-raw-auth-sha1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from bfd-raw-auth-sha1.pcap
#
# [17/231] Processing bgpsec.pcap
# Loading packets from E:\pcap\bgpsec.pcap...
# Loaded 1127 packets from bgpsec.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1127 packets from bgpsec.pcap
#
# [18/231] Processing bgp_shutdown_communication.pcap
# Loading packets from E:\pcap\bgp_shutdown_communication.pcap...
# Loaded 9 packets from bgp_shutdown_communication.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from bgp_shutdown_communication.pcap
#
# [19/231] Processing bicc.pcap
# Loading packets from E:\pcap\bicc.pcap...
# Loaded 1 packets from bicc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from bicc.pcap
#
# [20/231] Processing BITTORRENT.pcap
# Loading packets from E:\pcap\BITTORRENT.pcap...
# Loaded 53 packets from BITTORRENT.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 53 packets from BITTORRENT.pcap
#
# [21/231] Processing bmp.pcap
# Loading packets from E:\pcap\bmp.pcap...
# Loaded 39 packets from bmp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from bmp.pcap
#
# [22/231] Processing c1222_over_ipv6.pcap
# Loading packets from E:\pcap\c1222_over_ipv6.pcap...
# Loaded 11 packets from c1222_over_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 11 packets from c1222_over_ipv6.pcap
#
# [23/231] Processing c1222_std_example8.pcap
# Loading packets from E:\pcap\c1222_std_example8.pcap...
# Loaded 2 packets from c1222_std_example8.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from c1222_std_example8.pcap
#
# [24/231] Processing camel.pcap
# Loading packets from E:\pcap\camel.pcap...
# Loaded 5 packets from camel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from camel.pcap
#
# [25/231] Processing camel2.pcap
# Loading packets from E:\pcap\camel2.pcap...
# Loaded 4 packets from camel2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from camel2.pcap
#
# [26/231] Processing can-2003-0003.pcap
# Loading packets from E:\pcap\can-2003-0003.pcap...
# Loaded 27 packets from can-2003-0003.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 27 packets from can-2003-0003.pcap
#
# [27/231] Processing cdp.pcap
# Loading packets from E:\pcap\cdp.pcap...
# Loaded 1 packets from cdp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from cdp.pcap
#
# [28/231] Processing cdp_v2.pcap
# Loading packets from E:\pcap\cdp_v2.pcap...
# Loaded 4 packets from cdp_v2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from cdp_v2.pcap
#
# [29/231] Processing ch11-25-slt.pcap
# Loading packets from E:\pcap\ch11-25-slt.pcap...
# Loaded 68 packets from ch11-25-slt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from ch11-25-slt.pcap
#
# [30/231] Processing chargen-tcp.pcap
# Loading packets from E:\pcap\chargen-tcp.pcap...
# Loaded 22 packets from chargen-tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from chargen-tcp.pcap
#
# [31/231] Processing chargen-udp.pcap
# Loading packets from E:\pcap\chargen-udp.pcap...
# Loaded 2 packets from chargen-udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from chargen-udp.pcap
#
# [32/231] Processing cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_-OpenSSL-EJBCA.pcap...
# Loaded 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#
# [33/231] Processing cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Loading packets from E:\pcap\cmp_IR_sequence_OpenSSL-Cryptlib.pcap...
# Loaded 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#
# [34/231] Processing coap-cbor.pcap
# Loading packets from E:\pcap\coap-cbor.pcap...
# Loaded 164 packets from coap-cbor.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 164 packets from coap-cbor.pcap
#
# [35/231] Processing couchbase-lww.pcap
# Loading packets from E:\pcap\couchbase-lww.pcap...
# Loaded 240 packets from couchbase-lww.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 240 packets from couchbase-lww.pcap
#
# [36/231] Processing couchbase_subdoc_multi.pcap
# Loading packets from E:\pcap\couchbase_subdoc_multi.pcap...
# Loaded 477 packets from couchbase_subdoc_multi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 477 packets from couchbase_subdoc_multi.pcap
#
# [37/231] Processing dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Loading packets from E:\pcap\dcerpc-winreg-with-rpc-sec-verification-trailer.pcap...
# Loaded 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1017 packets from dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#
# [38/231] Processing dhcp-nanosecond.pcap
# Loading packets from E:\pcap\dhcp-nanosecond.pcap...
# Loaded 4 packets from dhcp-nanosecond.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp-nanosecond.pcap
#
# [39/231] Processing dhcp.pcap
# Loading packets from E:\pcap\dhcp.pcap...
# Loaded 4 packets from dhcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from dhcp.pcap
#
# [40/231] Processing dhcpv6_1.pcap
# Loading packets from E:\pcap\dhcpv6_1.pcap...
# Loaded 10 packets from dhcpv6_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from dhcpv6_1.pcap
#
# [41/231] Processing DICOM_C-ECHO-echoscu.pcap
# Loading packets from E:\pcap\DICOM_C-ECHO-echoscu.pcap...
# Loaded 25 packets from DICOM_C-ECHO-echoscu.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from DICOM_C-ECHO-echoscu.pcap
#
# [42/231] Processing dlep.pcap
# Loading packets from E:\pcap\dlep.pcap...
# Loaded 23 packets from dlep.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from dlep.pcap
#
# [43/231] Processing dnp3_read.pcap
# Loading packets from E:\pcap\dnp3_read.pcap...
# Loaded 8 packets from dnp3_read.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_read.pcap
#
# [44/231] Processing dnp3_select_operate.pcap
# Loading packets from E:\pcap\dnp3_select_operate.pcap...
# Loaded 12 packets from dnp3_select_operate.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from dnp3_select_operate.pcap
#
# [45/231] Processing dnp3_write.pcap
# Loading packets from E:\pcap\dnp3_write.pcap...
# Loaded 8 packets from dnp3_write.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from dnp3_write.pcap
#
# [46/231] Processing dns-remoteshell.pcap
# Loading packets from E:\pcap\dns-remoteshell.pcap...
# Loaded 131 packets from dns-remoteshell.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 131 packets from dns-remoteshell.pcap
#
# [47/231] Processing dns_port.pcap
# Loading packets from E:\pcap\dns_port.pcap...
# Loaded 2 packets from dns_port.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from dns_port.pcap
#
# [48/231] Processing DTMFsipinfo.pcap
# Loading packets from E:\pcap\DTMFsipinfo.pcap...
# Loaded 32 packets from DTMFsipinfo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from DTMFsipinfo.pcap
#
# [49/231] Processing dvb-ci_1.pcap
# Loading packets from E:\pcap\dvb-ci_1.pcap...
# Loaded 396 packets from dvb-ci_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 396 packets from dvb-ci_1.pcap
#
# [50/231] Processing dvb-ci_2.pcap
# Loading packets from E:\pcap\dvb-ci_2.pcap...
# Loaded 273 packets from dvb-ci_2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from dvb-ci_2.pcap
#
# [51/231] Processing dvb-ci_UV1_0000.pcap
# Loading packets from E:\pcap\dvb-ci_UV1_0000.pcap...
# Loaded 1 packets from dvb-ci_UV1_0000.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from dvb-ci_UV1_0000.pcap
#
# [52/231] Processing eapol-mka.pcap
# Loading packets from E:\pcap\eapol-mka.pcap...
# Loaded 68 packets from eapol-mka.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 68 packets from eapol-mka.pcap
#
# [53/231] Processing ecpri.pcap
# Loading packets from E:\pcap\ecpri.pcap...
# Loaded 18 packets from ecpri.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 18 packets from ecpri.pcap
#
# [54/231] Processing eia709.1-over-eia852.pcap
# Loading packets from E:\pcap\eia709.1-over-eia852.pcap...
# Loaded 12028 packets from eia709.1-over-eia852.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
# Extracted features for 12028 packets from eia709.1-over-eia852.pcap
#
# [55/231] Processing eigrp-for-ipv6-auth.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-auth.pcap...
# Loaded 570 packets from eigrp-for-ipv6-auth.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 570 packets from eigrp-for-ipv6-auth.pcap
#
# [56/231] Processing eigrp-for-ipv6-stub.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-stub.pcap...
# Loaded 273 packets from eigrp-for-ipv6-stub.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 273 packets from eigrp-for-ipv6-stub.pcap
#
# [57/231] Processing eigrp-for-ipv6-updates.pcap
# Loading packets from E:\pcap\eigrp-for-ipv6-updates.pcap...
# Loaded 421 packets from eigrp-for-ipv6-updates.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 421 packets from eigrp-for-ipv6-updates.pcap
#
# [58/231] Processing eigrp-ipx.pcap
# Loading packets from E:\pcap\eigrp-ipx.pcap...
# WARNING: PcapReader: unknown LL type [104]/[0x68]. Using Raw packets
# Loaded 74 packets from eigrp-ipx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 74 packets from eigrp-ipx.pcap
#
# [59/231] Processing epmd.pcap
# Loading packets from E:\pcap\epmd.pcap...
# Loaded 10 packets from epmd.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from epmd.pcap
#
# [60/231] Processing exablaze_trailer.pcap
# Loading packets from E:\pcap\exablaze_trailer.pcap...
# Loaded 24 packets from exablaze_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from exablaze_trailer.pcap
#
# [61/231] Processing exec-sample.pcap
# Loading packets from E:\pcap\exec-sample.pcap...
# Loaded 14 packets from exec-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from exec-sample.pcap
#
# [62/231] Processing FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Loading packets from E:\pcap\FAX-Call-t38-CA-TDM-SIP-FB-1.pcap...
# Loaded 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
# Extracted features for 7217 packets from FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#
# [63/231] Processing fix-ssl.pcap
# Loading packets from E:\pcap\fix-ssl.pcap...
# Loaded 1237 packets from fix-ssl.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1237 packets from fix-ssl.pcap
#
# [64/231] Processing fix.pcap
# Loading packets from E:\pcap\fix.pcap...
# Loaded 485 packets from fix.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 485 packets from fix.pcap
#
# [65/231] Processing fuzz-2008-09-30-17714.pcap
# Loading packets from E:\pcap\fuzz-2008-09-30-17714.pcap...
# Loaded 68294 packets from fuzz-2008-09-30-17714.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
#   Processed 32000 packets...
#   Processed 33000 packets...
#   Processed 34000 packets...
#   Processed 35000 packets...
#   Processed 36000 packets...
#   Processed 37000 packets...
#   Processed 38000 packets...
#   Processed 39000 packets...
#   Processed 40000 packets...
#   Processed 41000 packets...
#   Processed 42000 packets...
#   Processed 43000 packets...
#   Processed 44000 packets...
#   Processed 45000 packets...
#   Processed 46000 packets...
#   Processed 47000 packets...
#   Processed 48000 packets...
#   Processed 49000 packets...
#   Processed 50000 packets...
#   Processed 51000 packets...
#   Processed 52000 packets...
#   Processed 53000 packets...
#   Processed 54000 packets...
#   Processed 55000 packets...
#   Processed 56000 packets...
#   Processed 57000 packets...
#   Processed 58000 packets...
#   Processed 59000 packets...
#   Processed 60000 packets...
#   Processed 61000 packets...
#   Processed 62000 packets...
#   Processed 63000 packets...
#   Processed 64000 packets...
#   Processed 65000 packets...
#   Processed 66000 packets...
#   Processed 67000 packets...
#   Processed 68000 packets...
# Extracted features for 68294 packets from fuzz-2008-09-30-17714.pcap
#
# [66/231] Processing gopher.pcap
# Loading packets from E:\pcap\gopher.pcap...
# Loaded 92 packets from gopher.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from gopher.pcap
#
# [67/231] Processing greb_filterlist.pcap
# Loading packets from E:\pcap\greb_filterlist.pcap...
# Loaded 1 packets from greb_filterlist.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from greb_filterlist.pcap
#
# [68/231] Processing gsm-r.uus1.pcap
# Loading packets from E:\pcap\gsm-r.uus1.pcap...
# WARNING: PcapReader: unknown LL type [141]/[0x8d]. Using Raw packets
# Loaded 9 packets from gsm-r.uus1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from gsm-r.uus1.pcap
#
# [69/231] Processing gsm_map_with_ussd_string.pcap
# Loading packets from E:\pcap\gsm_map_with_ussd_string.pcap...
# Loaded 1 packets from gsm_map_with_ussd_string.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from gsm_map_with_ussd_string.pcap
#
# [70/231] Processing h263-over-rtp.pcap
# Loading packets from E:\pcap\h263-over-rtp.pcap...
# Loaded 49 packets from h263-over-rtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 49 packets from h263-over-rtp.pcap
#
# [71/231] Processing hart_ip.pcap
# Loading packets from E:\pcap\hart_ip.pcap...
# Loaded 116 packets from hart_ip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from hart_ip.pcap
#
# [72/231] Processing hcrt.pcap
# Loading packets from E:\pcap\hcrt.pcap...
# Loaded 10 packets from hcrt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from hcrt.pcap
#
# [73/231] Processing hdcp_authentication_sample.pcap
# Loading packets from E:\pcap\hdcp_authentication_sample.pcap...
# Loaded 8 packets from hdcp_authentication_sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 8 packets from hdcp_authentication_sample.pcap
#
# [74/231] Processing homeplug_network_statistics_basic.pcap
# Loading packets from E:\pcap\homeplug_network_statistics_basic.pcap...
# Loaded 1 packets from homeplug_network_statistics_basic.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_network_statistics_basic.pcap
#
# [75/231] Processing homeplug_request_channel_estimation.pcap
# Loading packets from E:\pcap\homeplug_request_channel_estimation.pcap...
# Loaded 1 packets from homeplug_request_channel_estimation.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_channel_estimation.pcap
#
# [76/231] Processing homeplug_request_parameters_and_statistics.pcap
# Loading packets from E:\pcap\homeplug_request_parameters_and_statistics.pcap...
# Loaded 1 packets from homeplug_request_parameters_and_statistics.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from homeplug_request_parameters_and_statistics.pcap
#
# [77/231] Processing hsrp.pcap
# Loading packets from E:\pcap\hsrp.pcap...
# Loaded 100 packets from hsrp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from hsrp.pcap
#
# [78/231] Processing http-chunked-gzip.pcap
# Loading packets from E:\pcap\http-chunked-gzip.pcap...
# Loaded 28 packets from http-chunked-gzip.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from http-chunked-gzip.pcap
#
# [79/231] Processing iec104.pcap
# Loading packets from E:\pcap\iec104.pcap...
# Loaded 105 packets from iec104.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from iec104.pcap
#
# [80/231] Processing IGMP-dataset.pcap
# Loading packets from E:\pcap\IGMP-dataset.pcap...
# Loaded 147 packets from IGMP-dataset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 147 packets from IGMP-dataset.pcap
#
# [81/231] Processing infiniband.pcap
# Loading packets from E:\pcap\infiniband.pcap...
# WARNING: PcapReader: unknown LL type [197]/[0xc5]. Using Raw packets
# Loaded 43 packets from infiniband.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 43 packets from infiniband.pcap
#
# [82/231] Processing iperf-mptcp-0-0.pcap
# Loading packets from E:\pcap\iperf-mptcp-0-0.pcap...
# Loaded 2560 packets from iperf-mptcp-0-0.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2560 packets from iperf-mptcp-0-0.pcap
#
# [83/231] Processing ipmb.multi.packets.pcap
# Loading packets from E:\pcap\ipmb.multi.packets.pcap...
# WARNING: more PcapReader: unknown LL type [199]/[0xc7]. Using Raw packets
# Loaded 357 packets from ipmb.multi.packets.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 357 packets from ipmb.multi.packets.pcap
#
# [84/231] Processing ipmi.SDR.FRU.SEL.pcap
# Loading packets from E:\pcap\ipmi.SDR.FRU.SEL.pcap...
# Loaded 1138 packets from ipmi.SDR.FRU.SEL.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1138 packets from ipmi.SDR.FRU.SEL.pcap
#
# [85/231] Processing ipmi.sensor.event.RR.pcap
# Loading packets from E:\pcap\ipmi.sensor.event.RR.pcap...
# Loaded 726 packets from ipmi.sensor.event.RR.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 726 packets from ipmi.sensor.event.RR.pcap
#
# [86/231] Processing ipp.pcap
# Loading packets from E:\pcap\ipp.pcap...
# Loaded 279 packets from ipp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 279 packets from ipp.pcap
#
# [87/231] Processing ipv4frags.pcap
# Loading packets from E:\pcap\ipv4frags.pcap...
# Loaded 3 packets from ipv4frags.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from ipv4frags.pcap
#
# [88/231] Processing ipv4_cipso_option.pcap
# Loading packets from E:\pcap\ipv4_cipso_option.pcap...
# Loaded 6 packets from ipv4_cipso_option.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from ipv4_cipso_option.pcap
#
# [89/231] Processing isup_load_generator.pcap
# Loading packets from E:\pcap\isup_load_generator.pcap...
# Loaded 5265 packets from isup_load_generator.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
# Extracted features for 5265 packets from isup_load_generator.pcap
#
# [90/231] Processing jaeger-compact.pcap
# Loading packets from E:\pcap\jaeger-compact.pcap...
# Loaded 2 packets from jaeger-compact.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from jaeger-compact.pcap
#
# [91/231] Processing japan_tcap_over_m2pa.pcap
# Loading packets from E:\pcap\japan_tcap_over_m2pa.pcap...
# Loaded 6 packets from japan_tcap_over_m2pa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 6 packets from japan_tcap_over_m2pa.pcap
#
# [92/231] Processing jxta-mcast-sample.pcap
# Loading packets from E:\pcap\jxta-mcast-sample.pcap...
# Loaded 401 packets from jxta-mcast-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 401 packets from jxta-mcast-sample.pcap
#
# [93/231] Processing jxta-sample.pcap
# Loading packets from E:\pcap\jxta-sample.pcap...
# Loaded 255 packets from jxta-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 255 packets from jxta-sample.pcap
#
# [94/231] Processing kismet-client-server-dump-1.pcap
# Loading packets from E:\pcap\kismet-client-server-dump-1.pcap...
# Loaded 35 packets from kismet-client-server-dump-1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 35 packets from kismet-client-server-dump-1.pcap
#
# [95/231] Processing ldap-and-search.pcap
# Loading packets from E:\pcap\ldap-and-search.pcap...
# Loaded 13 packets from ldap-and-search.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-and-search.pcap
#
# [96/231] Processing ldap-attribute-value-list.pcap
# Loading packets from E:\pcap\ldap-attribute-value-list.pcap...
# Loaded 13 packets from ldap-attribute-value-list.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-attribute-value-list.pcap
#
# [97/231] Processing ldap-extensible-match-with-dn.pcap
# Loading packets from E:\pcap\ldap-extensible-match-with-dn.pcap...
# Loaded 13 packets from ldap-extensible-match-with-dn.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match-with-dn.pcap
#
# [98/231] Processing ldap-extensible-match.pcap
# Loading packets from E:\pcap\ldap-extensible-match.pcap...
# Loaded 13 packets from ldap-extensible-match.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from ldap-extensible-match.pcap
#
# [99/231] Processing ldap-substring.pcap
# Loading packets from E:\pcap\ldap-substring.pcap...
# Loaded 26 packets from ldap-substring.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 26 packets from ldap-substring.pcap
#
# [100/231] Processing lldp.detailed.pcap
# Loading packets from E:\pcap\lldp.detailed.pcap...
# Loaded 1 packets from lldp.detailed.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.detailed.pcap
#
# [101/231] Processing lldp.minimal.pcap
# Loading packets from E:\pcap\lldp.minimal.pcap...
# Loaded 1 packets from lldp.minimal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldp.minimal.pcap
#
# [102/231] Processing lldpmed_civicloc.pcap
# Loading packets from E:\pcap\lldpmed_civicloc.pcap...
# Loaded 1 packets from lldpmed_civicloc.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from lldpmed_civicloc.pcap
#
# [103/231] Processing llt-sample.pcap
# Loading packets from E:\pcap\llt-sample.pcap...
# Loaded 10 packets from llt-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from llt-sample.pcap
#
# [104/231] Processing macsec_cisco_trunk.pcap
# Loading packets from E:\pcap\macsec_cisco_trunk.pcap...
# Loaded 1614 packets from macsec_cisco_trunk.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1614 packets from macsec_cisco_trunk.pcap
#
# [105/231] Processing mdb_bill_validator.pcap
# Loading packets from E:\pcap\mdb_bill_validator.pcap...
# Loaded 10 packets from mdb_bill_validator.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mdb_bill_validator.pcap
#
# [106/231] Processing mdb_cashless_1.pcap
# Loading packets from E:\pcap\mdb_cashless_1.pcap...
# Loaded 278 packets from mdb_cashless_1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 278 packets from mdb_cashless_1.pcap
#
# [107/231] Processing mesh.pcap
# Loading packets from E:\pcap\mesh.pcap...
# Loaded 780 packets from mesh.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 780 packets from mesh.pcap
#
# [108/231] Processing metamako_trailer.pcap
# Loading packets from E:\pcap\metamako_trailer.pcap...
# Loaded 111 packets from metamako_trailer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 111 packets from metamako_trailer.pcap
#
# [109/231] Processing metasploit-sip-invite-spoof.pcap
# Loading packets from E:\pcap\metasploit-sip-invite-spoof.pcap...
# Loaded 3 packets from metasploit-sip-invite-spoof.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from metasploit-sip-invite-spoof.pcap
#
# [110/231] Processing MGCP.pcap
# Loading packets from E:\pcap\MGCP.pcap...
# Loaded 14 packets from MGCP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from MGCP.pcap
#
# [111/231] Processing mndp.pcap
# Loading packets from E:\pcap\mndp.pcap...
# Loaded 10 packets from mndp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from mndp.pcap
#
# [112/231] Processing Mobile-Originating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Originating-Call(AMR).pcap...
# Loaded 299 packets from Mobile-Originating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 299 packets from Mobile-Originating-Call(AMR).pcap
#
# [113/231] Processing Mobile-Terminating-Call(AMR).pcap
# Loading packets from E:\pcap\Mobile-Terminating-Call(AMR).pcap...
# Loaded 308 packets from Mobile-Terminating-Call(AMR).pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 308 packets from Mobile-Terminating-Call(AMR).pcap
#
# [114/231] Processing mouse_replug2.pcap
# Loading packets from E:\pcap\mouse_replug2.pcap...
# WARNING: PcapReader: unknown LL type [186]/[0xba]. Using Raw packets
# Loaded 17 packets from mouse_replug2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 17 packets from mouse_replug2.pcap
#
# [115/231] Processing mp4-ftyp-styp-sidx.pcap
# Loading packets from E:\pcap\mp4-ftyp-styp-sidx.pcap...
# WARNING: PcapReader: unknown LL type [289]/[0x121]. Using Raw packets
# Loaded 5 packets from mp4-ftyp-styp-sidx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from mp4-ftyp-styp-sidx.pcap
#
# [116/231] Processing mpeg2_mp2t_with_cc_drop01.pcap
# Loading packets from E:\pcap\mpeg2_mp2t_with_cc_drop01.pcap...
# Loaded 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from mpeg2_mp2t_with_cc_drop01.pcap
#
# [117/231] Processing msgpack-generated.pcap
# Loading packets from E:\pcap\msgpack-generated.pcap...
# WARNING: more PcapReader: unknown LL type [252]/[0xfc]. Using Raw packets
# Loaded 23 packets from msgpack-generated.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from msgpack-generated.pcap
#
# [118/231] Processing msnms.pcap
# Loading packets from E:\pcap\msnms.pcap...
# Loaded 364 packets from msnms.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 364 packets from msnms.pcap
#
# [119/231] Processing mysql_complete.pcap
# Loading packets from E:\pcap\mysql_complete.pcap...
# Loaded 57 packets from mysql_complete.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 57 packets from mysql_complete.pcap
#
# [120/231] Processing nano.pcap
# Loading packets from E:\pcap\nano.pcap...
# Loaded 2500 packets from nano.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2500 packets from nano.pcap
#
# [121/231] Processing nano_tcp.pcap
# Loading packets from E:\pcap\nano_tcp.pcap...
# Loaded 117 packets from nano_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from nano_tcp.pcap
#
# [122/231] Processing nb6-hotspot.pcap
# Loading packets from E:\pcap\nb6-hotspot.pcap...
# Loaded 347 packets from nb6-hotspot.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 347 packets from nb6-hotspot.pcap
#
# [123/231] Processing nb6-http.pcap
# Loading packets from E:\pcap\nb6-http.pcap...
# Loaded 62 packets from nb6-http.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 62 packets from nb6-http.pcap
#
# [124/231] Processing nb6-startup.pcap
# Loading packets from E:\pcap\nb6-startup.pcap...
# Loaded 531 packets from nb6-startup.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 531 packets from nb6-startup.pcap
#
# [125/231] Processing nb6-telephone.pcap
# Loading packets from E:\pcap\nb6-telephone.pcap...
# Loaded 527 packets from nb6-telephone.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 527 packets from nb6-telephone.pcap
#
# [126/231] Processing netlink-conntrack.pcap
# Loading packets from E:\pcap\netlink-conntrack.pcap...
# Loaded 107 packets from netlink-conntrack.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 107 packets from netlink-conntrack.pcap
#
# [127/231] Processing netlink-ipset.pcap
# Loading packets from E:\pcap\netlink-ipset.pcap...
# Loaded 300 packets from netlink-ipset.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 300 packets from netlink-ipset.pcap
#
# [128/231] Processing netlink-nflog.pcap
# Loading packets from E:\pcap\netlink-nflog.pcap...
# Loaded 22 packets from netlink-nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 22 packets from netlink-nflog.pcap
#
# [129/231] Processing netlink.pcap
# Loading packets from E:\pcap\netlink.pcap...
# Loaded 673 packets from netlink.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 673 packets from netlink.pcap
#
# [130/231] Processing Network_Join_Nokia_Mobile.pcap
# Loading packets from E:\pcap\Network_Join_Nokia_Mobile.pcap...
# Loaded 1180 packets from Network_Join_Nokia_Mobile.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1180 packets from Network_Join_Nokia_Mobile.pcap
#
# [131/231] Processing new_rfp.pcap
# Loading packets from E:\pcap\new_rfp.pcap...
# Loaded 66 packets from new_rfp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from new_rfp.pcap
#
# [132/231] Processing new_rfp_on_wire.pcap
# Loading packets from E:\pcap\new_rfp_on_wire.pcap...
# Loaded 154 packets from new_rfp_on_wire.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 154 packets from new_rfp_on_wire.pcap
#
# [133/231] Processing nflog.pcap
# Loading packets from E:\pcap\nflog.pcap...
# Loaded 39 packets from nflog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from nflog.pcap
#
# [134/231] Processing nlmon-big.pcap
# Loading packets from E:\pcap\nlmon-big.pcap...
# Loaded 13 packets from nlmon-big.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from nlmon-big.pcap
#
# [135/231] Processing nntp.pcap
# Loading packets from E:\pcap\nntp.pcap...
# Loaded 32 packets from nntp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from nntp.pcap
#
# [136/231] Processing notifyLTE.pcap
# Loading packets from E:\pcap\notifyLTE.pcap...
# Loaded 1 packets from notifyLTE.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from notifyLTE.pcap
#
# [137/231] Processing nspi.pcap
# Loading packets from E:\pcap\nspi.pcap...
# Loaded 25 packets from nspi.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from nspi.pcap
#
# [138/231] Processing NTLM-wenchao.pcap
# Loading packets from E:\pcap\NTLM-wenchao.pcap...
# Loaded 80 packets from NTLM-wenchao.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 80 packets from NTLM-wenchao.pcap
#
# [139/231] Processing NTP_sync.pcap
# Loading packets from E:\pcap\NTP_sync.pcap...
# Loaded 32 packets from NTP_sync.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 32 packets from NTP_sync.pcap
#
# [140/231] Processing opensafety_epl_trace.pcap
# Loading packets from E:\pcap\opensafety_epl_trace.pcap...
# Loaded 31161 packets from opensafety_epl_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
#   Processed 17000 packets...
#   Processed 18000 packets...
#   Processed 19000 packets...
#   Processed 20000 packets...
#   Processed 21000 packets...
#   Processed 22000 packets...
#   Processed 23000 packets...
#   Processed 24000 packets...
#   Processed 25000 packets...
#   Processed 26000 packets...
#   Processed 27000 packets...
#   Processed 28000 packets...
#   Processed 29000 packets...
#   Processed 30000 packets...
#   Processed 31000 packets...
# Extracted features for 31161 packets from opensafety_epl_trace.pcap
#
# [141/231] Processing opensafety_sercosiii_trace.pcap
# Loading packets from E:\pcap\opensafety_sercosiii_trace.pcap...
# Loaded 426 packets from opensafety_sercosiii_trace.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 426 packets from opensafety_sercosiii_trace.pcap
#
# [142/231] Processing opensafety_udp_trace.pcap
# Loading packets from E:\pcap\opensafety_udp_trace.pcap...
# Loaded 16036 packets from opensafety_udp_trace.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
#   Processed 9000 packets...
#   Processed 10000 packets...
#   Processed 11000 packets...
#   Processed 12000 packets...
#   Processed 13000 packets...
#   Processed 14000 packets...
#   Processed 15000 packets...
#   Processed 16000 packets...
# Extracted features for 16036 packets from opensafety_udp_trace.pcap
#
# [143/231] Processing OptoMMP.pcap
# Loading packets from E:\pcap\OptoMMP.pcap...
# Loaded 20 packets from OptoMMP.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 20 packets from OptoMMP.pcap
#
# [144/231] Processing p772-transfer-success.pcap
# Loading packets from E:\pcap\p772-transfer-success.pcap...
# Loaded 29 packets from p772-transfer-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 29 packets from p772-transfer-success.pcap
#
# [145/231] Processing policy-authorizeNV.pcap
# Loading packets from E:\pcap\policy-authorizeNV.pcap...
# Loaded 117 packets from policy-authorizeNV.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 117 packets from policy-authorizeNV.pcap
#
# [146/231] Processing ppp_lcp_ipcp.pcap
# Loading packets from E:\pcap\ppp_lcp_ipcp.pcap...
# Loaded 23 packets from ppp_lcp_ipcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 23 packets from ppp_lcp_ipcp.pcap
#
# [147/231] Processing ptpv2.pcap
# Loading packets from E:\pcap\ptpv2.pcap...
# Loaded 39 packets from ptpv2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 39 packets from ptpv2.pcap
#
# [148/231] Processing pvfs2-sample.pcap
# Loading packets from E:\pcap\pvfs2-sample.pcap...
# Loaded 44 packets from pvfs2-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 44 packets from pvfs2-sample.pcap
#
# [149/231] Processing rsasnakeoil2.pcap
# Loading packets from E:\pcap\rsasnakeoil2.pcap...
# Loaded 58 packets from rsasnakeoil2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 58 packets from rsasnakeoil2.pcap
#
# [150/231] Processing rtp-norm-transfer.pcap
# Loading packets from E:\pcap\rtp-norm-transfer.pcap...
# Loaded 226 packets from rtp-norm-transfer.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 226 packets from rtp-norm-transfer.pcap
#
# [151/231] Processing rtp-opus-only.pcap
# Loading packets from E:\pcap\rtp-opus-only.pcap...
# Loaded 425 packets from rtp-opus-only.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 425 packets from rtp-opus-only.pcap
#
# [152/231] Processing s101glow.pcap
# Loading packets from E:\pcap\s101glow.pcap...
# ...
#
# [179/231] Processing siso_std_002_transmitter.pcap
# Loading packets from E:\pcap\siso_std_002_transmitter.pcap...
# Loaded 1 packets from siso_std_002_transmitter.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from siso_std_002_transmitter.pcap
#
# [180/231] Processing smb3-aes-128-ccm.pcap
# Loading packets from E:\pcap\smb3-aes-128-ccm.pcap...
# Loaded 54 packets from smb3-aes-128-ccm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 54 packets from smb3-aes-128-ccm.pcap
#
# [181/231] Processing smb311-aes-128-ccm-filt.pcap
# Loading packets from E:\pcap\smb311-aes-128-ccm-filt.pcap...
# Loaded 34 packets from smb311-aes-128-ccm-filt.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 34 packets from smb311-aes-128-ccm-filt.pcap
#
# [182/231] Processing smtp.pcap
# Loading packets from E:\pcap\smtp.pcap...
# Loaded 60 packets from smtp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 60 packets from smtp.pcap
#
# [183/231] Processing snakeoil-dtls.pcap
# Loading packets from E:\pcap\snakeoil-dtls.pcap...
# Loaded 9 packets from snakeoil-dtls.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 9 packets from snakeoil-dtls.pcap
#
# [184/231] Processing snmp_usm.pcap
# Loading packets from E:\pcap\snmp_usm.pcap...
# Loaded 144 packets from snmp_usm.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from snmp_usm.pcap
#
# [185/231] Processing sr-header.pcap
# Loading packets from E:\pcap\sr-header.pcap...
# Loaded 10 packets from sr-header.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from sr-header.pcap
#
# [186/231] Processing stanag-5602-simple-example.pcap
# Loading packets from E:\pcap\stanag-5602-simple-example.pcap...
# Loaded 2 packets from stanag-5602-simple-example.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from stanag-5602-simple-example.pcap
#
# [187/231] Processing Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Loading packets from E:\pcap\Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap...
# WARNING: PcapReader: unknown LL type [237]/[0xed]. Using Raw packets
# Loaded 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#
# [188/231] Processing steam-ihs-discovery.pcap
# Loading packets from E:\pcap\steam-ihs-discovery.pcap...
# Loaded 113 packets from steam-ihs-discovery.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 113 packets from steam-ihs-discovery.pcap
#
# [189/231] Processing stp.pcap
# Loading packets from E:\pcap\stp.pcap...
# Loaded 96 packets from stp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 96 packets from stp.pcap
#
# [190/231] Processing tcp-ecn-sample.pcap
# Loading packets from E:\pcap\tcp-ecn-sample.pcap...
# Loaded 479 packets from tcp-ecn-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 479 packets from tcp-ecn-sample.pcap
#
# [191/231] Processing TeamSpeak2.pcap
# Loading packets from E:\pcap\TeamSpeak2.pcap...
# Loaded 24 packets from TeamSpeak2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 24 packets from TeamSpeak2.pcap
#
# [192/231] Processing telecomitalia-pppoe.pcap
# Loading packets from E:\pcap\telecomitalia-pppoe.pcap...
# Loaded 28 packets from telecomitalia-pppoe.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 28 packets from telecomitalia-pppoe.pcap
#
# [193/231] Processing telnet-cooked.pcap
# Loading packets from E:\pcap\telnet-cooked.pcap...
# Loaded 92 packets from telnet-cooked.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 92 packets from telnet-cooked.pcap
#
# [194/231] Processing telnet-raw.pcap
# Loading packets from E:\pcap\telnet-raw.pcap...
# Loaded 272 packets from telnet-raw.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 272 packets from telnet-raw.pcap
#
# [195/231] Processing Teredo.pcap
# Loading packets from E:\pcap\Teredo.pcap...
# Loaded 78 packets from Teredo.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from Teredo.pcap
#
# [196/231] Processing tftp_rrq.pcap
# Loading packets from E:\pcap\tftp_rrq.pcap...
# Loaded 99 packets from tftp_rrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 99 packets from tftp_rrq.pcap
#
# [197/231] Processing tftp_wrq.pcap
# Loading packets from E:\pcap\tftp_wrq.pcap...
# Loaded 100 packets from tftp_wrq.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 100 packets from tftp_wrq.pcap
#
# [198/231] Processing tipc-publication-payload-withdrawal.pcap
# Loading packets from E:\pcap\tipc-publication-payload-withdrawal.pcap...
# Loaded 40 packets from tipc-publication-payload-withdrawal.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 40 packets from tipc-publication-payload-withdrawal.pcap
#
# [199/231] Processing TNS_Oracle1.pcap
# Loading packets from E:\pcap\TNS_Oracle1.pcap...
# Loaded 78 packets from TNS_Oracle1.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 78 packets from TNS_Oracle1.pcap
#
# [200/231] Processing TNS_Oracle2.pcap
# Loading packets from E:\pcap\TNS_Oracle2.pcap...
# Loaded 36 packets from TNS_Oracle2.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle2.pcap
#
# [201/231] Processing TNS_Oracle3.pcap
# Loading packets from E:\pcap\TNS_Oracle3.pcap...
# Loaded 36 packets from TNS_Oracle3.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 36 packets from TNS_Oracle3.pcap
#
# [202/231] Processing TNS_Oracle4.pcap
# Loading packets from E:\pcap\TNS_Oracle4.pcap...
# Loaded 10 packets from TNS_Oracle4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from TNS_Oracle4.pcap
#
# [203/231] Processing TNS_Oracle5.pcap
# Loading packets from E:\pcap\TNS_Oracle5.pcap...
# Loaded 56 packets from TNS_Oracle5.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 56 packets from TNS_Oracle5.pcap
#
# [204/231] Processing tpncp_tcp.pcap
# Loading packets from E:\pcap\tpncp_tcp.pcap...
# Loaded 116 packets from tpncp_tcp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 116 packets from tpncp_tcp.pcap
#
# [205/231] Processing tpncp_udp.pcap
# Loading packets from E:\pcap\tpncp_udp.pcap...
# Loaded 132 packets from tpncp_udp.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 132 packets from tpncp_udp.pcap
#
# [206/231] Processing TTE_mix_small.pcap
# Loading packets from E:\pcap\TTE_mix_small.pcap...
# Loaded 25 packets from TTE_mix_small.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 25 packets from TTE_mix_small.pcap
#
# [207/231] Processing tunnel.pcap
# Loading packets from E:\pcap\tunnel.pcap...
# Loaded 218 packets from tunnel.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 218 packets from tunnel.pcap
#
# [208/231] Processing ua3g_freeseating_ipv4.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv4.pcap...
# Loaded 64 packets from ua3g_freeseating_ipv4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 64 packets from ua3g_freeseating_ipv4.pcap
#
# [209/231] Processing ua3g_freeseating_ipv6.pcap
# Loading packets from E:\pcap\ua3g_freeseating_ipv6.pcap...
# Loaded 339 packets from ua3g_freeseating_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 339 packets from ua3g_freeseating_ipv6.pcap
#
# [210/231] Processing uaudp_ipv6.pcap
# Loading packets from E:\pcap\uaudp_ipv6.pcap...
# Loaded 2544 packets from uaudp_ipv6.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
# Extracted features for 2544 packets from uaudp_ipv6.pcap
#
# [211/231] Processing udp-nm_anon.pcap
# Loading packets from E:\pcap\udp-nm_anon.pcap...
# Loaded 1 packets from udp-nm_anon.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp-nm_anon.pcap
#
# [212/231] Processing udp_lite_checksum_0.pcap
# Loading packets from E:\pcap\udp_lite_checksum_0.pcap...
# Loaded 1 packets from udp_lite_checksum_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_checksum_0.pcap
#
# [213/231] Processing udp_lite_full_coverage_0.pcap
# Loading packets from E:\pcap\udp_lite_full_coverage_0.pcap...
# Loaded 1 packets from udp_lite_full_coverage_0.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 1 packets from udp_lite_full_coverage_0.pcap
#
# [214/231] Processing udp_lite_illegal_1-7.pcap
# Loading packets from E:\pcap\udp_lite_illegal_1-7.pcap...
# Loaded 7 packets from udp_lite_illegal_1-7.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 7 packets from udp_lite_illegal_1-7.pcap
#
# [215/231] Processing udp_lite_illegal_large-coverage.pcap
# Loading packets from E:\pcap\udp_lite_illegal_large-coverage.pcap...
# Loaded 3 packets from udp_lite_illegal_large-coverage.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 3 packets from udp_lite_illegal_large-coverage.pcap
#
# [216/231] Processing udp_lite_normal_coverage_8-20.pcap
# Loading packets from E:\pcap\udp_lite_normal_coverage_8-20.pcap...
# Loaded 13 packets from udp_lite_normal_coverage_8-20.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 13 packets from udp_lite_normal_coverage_8-20.pcap
#
# [217/231] Processing UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Loading packets from E:\pcap\UMTS_FP_MAC_RLC_RRC_NBAP.pcap...
# Loaded 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
# Extracted features for 4128 packets from UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#
# [218/231] Processing unistim-call.pcap
# Loading packets from E:\pcap\unistim-call.pcap...
# Loaded 105 packets from unistim-call.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 105 packets from unistim-call.pcap
#
# [219/231] Processing usb_memory_stick.pcap
# Loading packets from E:\pcap\usb_memory_stick.pcap...
# WARNING: PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 1041 packets from usb_memory_stick.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1041 packets from usb_memory_stick.pcap
#
# [220/231] Processing usb_memory_stick_create_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_create_file.pcap...
# WARNING: more PcapReader: unknown LL type [189]/[0xbd]. Using Raw packets
# Loaded 144 packets from usb_memory_stick_create_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 144 packets from usb_memory_stick_create_file.pcap
#
# [221/231] Processing usb_memory_stick_delete_file.pcap
# Loading packets from E:\pcap\usb_memory_stick_delete_file.pcap...
# Loaded 66 packets from usb_memory_stick_delete_file.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 66 packets from usb_memory_stick_delete_file.pcap
#
# [222/231] Processing UserLog.pcap
# Loading packets from E:\pcap\UserLog.pcap...
# Loaded 650 packets from UserLog.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 650 packets from UserLog.pcap
#
# [223/231] Processing v6.pcap
# Loading packets from E:\pcap\v6.pcap...
# Loaded 161 packets from v6.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 161 packets from v6.pcap
#
# [224/231] Processing VariousUSBDevices.pcap
# Loading packets from E:\pcap\VariousUSBDevices.pcap...
# Loaded 8206 packets from VariousUSBDevices.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
#   Processed 2000 packets...
#   Processed 3000 packets...
#   Processed 4000 packets...
#   Processed 5000 packets...
#   Processed 6000 packets...
#   Processed 7000 packets...
#   Processed 8000 packets...
# Extracted features for 8206 packets from VariousUSBDevices.pcap
#
# [225/231] Processing vnc-sample.pcap
# Loading packets from E:\pcap\vnc-sample.pcap...
# Loaded 81 packets from vnc-sample.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 81 packets from vnc-sample.pcap
#
# [226/231] Processing wap_google.pcap
# Loading packets from E:\pcap\wap_google.pcap...
# Loaded 4 packets from wap_google.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 4 packets from wap_google.pcap
#
# [227/231] Processing win_s4u2self.pcap
# Loading packets from E:\pcap\win_s4u2self.pcap...
# Loaded 14 packets from win_s4u2self.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 14 packets from win_s4u2self.pcap
#
# [228/231] Processing wpa-Induction.pcap
# Loading packets from E:\pcap\wpa-Induction.pcap...
# Loaded 1093 packets from wpa-Induction.pcap
# Extracting features...
#   Processed 0 packets...
#   Processed 1000 packets...
# Extracted features for 1093 packets from wpa-Induction.pcap
#
# [229/231] Processing x400-ping-refuse.pcap
# Loading packets from E:\pcap\x400-ping-refuse.pcap...
# Loaded 10 packets from x400-ping-refuse.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 10 packets from x400-ping-refuse.pcap
#
# [230/231] Processing x400-ping-success.pcap
# Loading packets from E:\pcap\x400-ping-success.pcap...
# Loaded 12 packets from x400-ping-success.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 12 packets from x400-ping-success.pcap
#
# [231/231] Processing yami.pcap
# Loading packets from E:\pcap\yami.pcap...
# Loaded 2 packets from yami.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 2 packets from yami.pcap
#
# Combining data from 231 files...
# Total packets processed: 214523
#
# Overall label distribution:
# label
# other_tcp        81387
# non_ip           62423
# other_udp        60934
# other_ip          6769
# web_traffic       1205
# dns                612
# remote_access      413
# database           317
# snmp               144
# icmp                81
# ntp                 66
# dhcp                61
# file_transfer       58
# email               53
# Name: count, dtype: int64
#
# Dataset shape: (214523, 18)
# Number of classes: 14
#
# Training model...
# Cleaning data...
# Cleaned dataset: 214523/214523 packets retained
#
# Model Accuracy: 1.000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      database       0.98      0.94      0.96        63
#          dhcp       1.00      1.00      1.00        12
#           dns       1.00      1.00      1.00       122
#         email       1.00      1.00      1.00        11
# file_transfer       1.00      1.00      1.00        12
#          icmp       1.00      1.00      1.00        16
#        non_ip       1.00      1.00      1.00     12485
#           ntp       1.00      1.00      1.00        13
#      other_ip       1.00      1.00      1.00      1354
#     other_tcp       1.00      1.00      1.00     16277
#     other_udp       1.00      1.00      1.00     12187
# remote_access       1.00      1.00      1.00        83
#          snmp       1.00      1.00      1.00        29
#   web_traffic       1.00      0.99      0.99       241
#
#      accuracy                           1.00     42905
#     macro avg       1.00      0.99      1.00     42905
#  weighted avg       1.00      1.00      1.00     42905
#
#
# Top 10 Most Important Features:
#         feature  importance
# 7        is_tcp    0.152725
# 1        has_ip    0.101746
# 3        ip_ttl    0.080404
# 6      ip_proto    0.075668
# 13   tcp_window    0.074978
# 12    tcp_flags    0.072696
# 16  tcp_dataofs    0.069056
# 2     ip_length    0.066414
# 14      tcp_seq    0.063193
# 10     src_port    0.058224
# Model trained successfully!
# You can now use the classifier for predictions:
# predicted_class, confidence = classifier.predict_packet_class(packet)

# %%
# Train with a small subset to test quickly
pcap_folder = r"E:\pcap"

try:
    # Use just 3 files to test quickly
    features, labels = classifier.load_and_process_folder(pcap_folder, file_limit=3)
    
    if features is not None:
        print(f"Training with {len(features)} packets...")
        
        # Train the model
        X_test, y_test, y_pred = classifier.train_model(features, labels)
        
        if X_test is not None:
            print("Training completed successfully!")
            
            # Test with a simple prediction
            from scapy.all import IP, TCP
            test_packet = IP(dst="192.168.1.1")/TCP(dport=80)
            pred_class, confidence = classifier.predict_packet_class(test_packet)
            print(f"Test prediction - HTTP packet: {pred_class} (confidence: {confidence:.3f})")
            
        else:
            print("Training failed")
    else:
        print("Failed to load data")
        
except Exception as e:
    print(f"Error during training: {e}")
# Out:
# Scanning folder: E:\pcap
# Found 231 pcap files:
#   - 6to4.pcap
#   - aaa.pcap
#   - abis-accept-network.pcap
#   - abis-reject-network.pcap
#   - airtunes-1.pcap
#   - alp-sample1.pcap
#   - alp-sample2.pcap
#   - anony-tcp-std.pcap
#   - ansi_map_ota.pcap
#   - ansi_map_win.pcap
#   - ansi_tcap_over_itu_sccp_over_mtp3_over_mtp2.pcap
#   - Apple_IP-over-IEEE_1394_Packet.pcap
#   - arp-storm.pcap
#   - Asterisk_ZFONE_XLITE.pcap
#   - bfd-raw-auth-md5.pcap
#   - bfd-raw-auth-sha1.pcap
#   - bgpsec.pcap
#   - bgp_shutdown_communication.pcap
#   - bicc.pcap
#   - BITTORRENT.pcap
#   - bmp.pcap
#   - c1222_over_ipv6.pcap
#   - c1222_std_example8.pcap
#   - camel.pcap
#   - camel2.pcap
#   - can-2003-0003.pcap
#   - cdp.pcap
#   - cdp_v2.pcap
#   - ch11-25-slt.pcap
#   - chargen-tcp.pcap
#   - chargen-udp.pcap
#   - cmp_IR_sequence_-OpenSSL-EJBCA.pcap
#   - cmp_IR_sequence_OpenSSL-Cryptlib.pcap
#   - coap-cbor.pcap
#   - couchbase-lww.pcap
#   - couchbase_subdoc_multi.pcap
#   - dcerpc-winreg-with-rpc-sec-verification-trailer.pcap
#   - dhcp-nanosecond.pcap
#   - dhcp.pcap
#   - dhcpv6_1.pcap
#   - DICOM_C-ECHO-echoscu.pcap
#   - dlep.pcap
#   - dnp3_read.pcap
#   - dnp3_select_operate.pcap
#   - dnp3_write.pcap
#   - dns-remoteshell.pcap
#   - dns_port.pcap
#   - DTMFsipinfo.pcap
#   - dvb-ci_1.pcap
#   - dvb-ci_2.pcap
#   - dvb-ci_UV1_0000.pcap
#   - eapol-mka.pcap
#   - ecpri.pcap
#   - eia709.1-over-eia852.pcap
#   - eigrp-for-ipv6-auth.pcap
#   - eigrp-for-ipv6-stub.pcap
#   - eigrp-for-ipv6-updates.pcap
#   - eigrp-ipx.pcap
#   - epmd.pcap
#   - exablaze_trailer.pcap
#   - exec-sample.pcap
#   - FAX-Call-t38-CA-TDM-SIP-FB-1.pcap
#   - fix-ssl.pcap
#   - fix.pcap
#   - fuzz-2008-09-30-17714.pcap
#   - gopher.pcap
#   - greb_filterlist.pcap
#   - gsm-r.uus1.pcap
#   - gsm_map_with_ussd_string.pcap
#   - h263-over-rtp.pcap
#   - hart_ip.pcap
#   - hcrt.pcap
#   - hdcp_authentication_sample.pcap
#   - homeplug_network_statistics_basic.pcap
#   - homeplug_request_channel_estimation.pcap
#   - homeplug_request_parameters_and_statistics.pcap
#   - hsrp.pcap
#   - http-chunked-gzip.pcap
#   - iec104.pcap
#   - IGMP-dataset.pcap
#   - infiniband.pcap
#   - iperf-mptcp-0-0.pcap
#   - ipmb.multi.packets.pcap
#   - ipmi.SDR.FRU.SEL.pcap
#   - ipmi.sensor.event.RR.pcap
#   - ipp.pcap
#   - ipv4frags.pcap
#   - ipv4_cipso_option.pcap
#   - isup_load_generator.pcap
#   - jaeger-compact.pcap
#   - japan_tcap_over_m2pa.pcap
#   - jxta-mcast-sample.pcap
#   - jxta-sample.pcap
#   - kismet-client-server-dump-1.pcap
#   - ldap-and-search.pcap
#   - ldap-attribute-value-list.pcap
#   - ldap-extensible-match-with-dn.pcap
#   - ldap-extensible-match.pcap
#   - ldap-substring.pcap
#   - lldp.detailed.pcap
#   - lldp.minimal.pcap
#   - lldpmed_civicloc.pcap
#   - llt-sample.pcap
#   - macsec_cisco_trunk.pcap
#   - mdb_bill_validator.pcap
#   - mdb_cashless_1.pcap
#   - mesh.pcap
#   - metamako_trailer.pcap
#   - metasploit-sip-invite-spoof.pcap
#   - MGCP.pcap
#   - mndp.pcap
#   - Mobile-Originating-Call(AMR).pcap
#   - Mobile-Terminating-Call(AMR).pcap
#   - mouse_replug2.pcap
#   - mp4-ftyp-styp-sidx.pcap
#   - mpeg2_mp2t_with_cc_drop01.pcap
#   - msgpack-generated.pcap
#   - msnms.pcap
#   - mysql_complete.pcap
#   - nano.pcap
#   - nano_tcp.pcap
#   - nb6-hotspot.pcap
#   - nb6-http.pcap
#   - nb6-startup.pcap
#   - nb6-telephone.pcap
#   - netlink-conntrack.pcap
#   - netlink-ipset.pcap
#   - netlink-nflog.pcap
#   - netlink.pcap
#   - Network_Join_Nokia_Mobile.pcap
#   - new_rfp.pcap
#   - new_rfp_on_wire.pcap
#   - nflog.pcap
#   - nlmon-big.pcap
#   - nntp.pcap
#   - notifyLTE.pcap
#   - nspi.pcap
#   - NTLM-wenchao.pcap
#   - NTP_sync.pcap
#   - opensafety_epl_trace.pcap
#   - opensafety_sercosiii_trace.pcap
#   - opensafety_udp_trace.pcap
#   - OptoMMP.pcap
#   - p772-transfer-success.pcap
#   - policy-authorizeNV.pcap
#   - ppp_lcp_ipcp.pcap
#   - ptpv2.pcap
#   - pvfs2-sample.pcap
#   - rsasnakeoil2.pcap
#   - rtp-norm-transfer.pcap
#   - rtp-opus-only.pcap
#   - s101glow.pcap
#   - S5066-Expedited.pcap
#   - S5066-HFChat-1.pcap
#   - S5066-HFChat-Rejected.pcap
#   - s7comm_downloading_block_db1.pcap
#   - s7comm_program_blocklist_onlineview.pcap
#   - s7comm_reading_plc_status.pcap
#   - s7comm_reading_setting_plc_time.pcap
#   - s7comm_varservice_libnodavedemo.pcap
#   - s7comm_varservice_libnodavedemo_bench.pcap
#   - sbus.pcap
#   - scsi-osd-example-001.pcap
#   - segmented_fpm.pcap
#   - SIMULCRYPT.pcap
#   - sip-rtp-dvi4.pcap
#   - sip-rtp-g711.pcap
#   - sip-rtp-g722.pcap
#   - sip-rtp-g726.pcap
#   - sip-rtp-g729a.pcap
#   - sip-rtp-gsm.pcap
#   - sip-rtp-ilbc.pcap
#   - sip-rtp-l16.pcap
#   - sip-rtp-lpc.pcap
#   - sip-rtp-opus-hybrid.pcap
#   - sip-rtp-opus.pcap
#   - sip-rtp-speex.pcap
#   - siso_std_002_annex_b_example.pcap
#   - siso_std_002_transmitter.pcap
#   - smb3-aes-128-ccm.pcap
#   - smb311-aes-128-ccm-filt.pcap
#   - smtp.pcap
#   - snakeoil-dtls.pcap
#   - snmp_usm.pcap
#   - sr-header.pcap
#   - stanag-5602-simple-example.pcap
#   - Stanag5066-RAW-ENCAP-Bftp-Exchange-tx.pcap
#   - steam-ihs-discovery.pcap
#   - stp.pcap
#   - tcp-ecn-sample.pcap
#   - TeamSpeak2.pcap
#   - telecomitalia-pppoe.pcap
#   - telnet-cooked.pcap
#   - telnet-raw.pcap
#   - Teredo.pcap
#   - tftp_rrq.pcap
#   - tftp_wrq.pcap
#   - tipc-publication-payload-withdrawal.pcap
#   - TNS_Oracle1.pcap
#   - TNS_Oracle2.pcap
#   - TNS_Oracle3.pcap
#   - TNS_Oracle4.pcap
#   - TNS_Oracle5.pcap
#   - tpncp_tcp.pcap
#   - tpncp_udp.pcap
#   - TTE_mix_small.pcap
#   - tunnel.pcap
#   - ua3g_freeseating_ipv4.pcap
#   - ua3g_freeseating_ipv6.pcap
#   - uaudp_ipv6.pcap
#   - udp-nm_anon.pcap
#   - udp_lite_checksum_0.pcap
#   - udp_lite_full_coverage_0.pcap
#   - udp_lite_illegal_1-7.pcap
#   - udp_lite_illegal_large-coverage.pcap
#   - udp_lite_normal_coverage_8-20.pcap
#   - UMTS_FP_MAC_RLC_RRC_NBAP.pcap
#   - unistim-call.pcap
#   - usb_memory_stick.pcap
#   - usb_memory_stick_create_file.pcap
#   - usb_memory_stick_delete_file.pcap
#   - UserLog.pcap
#   - v6.pcap
#   - VariousUSBDevices.pcap
#   - vnc-sample.pcap
#   - wap_google.pcap
#   - win_s4u2self.pcap
#   - wpa-Induction.pcap
#   - x400-ping-refuse.pcap
#   - x400-ping-success.pcap
#   - yami.pcap
# Processing first 3 files due to limit
#
# [1/3] Processing 6to4.pcap
# Loading packets from E:\pcap\6to4.pcap...
# Loaded 5 packets from 6to4.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 5 packets from 6to4.pcap
#
# [2/3] Processing aaa.pcap
# Loading packets from E:\pcap\aaa.pcap...
# Loaded 691 packets from aaa.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 691 packets from aaa.pcap
#
# [3/3] Processing abis-accept-network.pcap
# Loading packets from E:\pcap\abis-accept-network.pcap...
# WARNING: PcapReader: unknown LL type [177]/[0xb1]. Using Raw packets
# Loaded 85 packets from abis-accept-network.pcap
# Extracting features...
#   Processed 0 packets...
# Extracted features for 85 packets from abis-accept-network.pcap
#
# Combining data from 3 files...
# Total packets processed: 781
#
# Overall label distribution:
# label
# dns              357
# other_udp        231
# non_ip           129
# file_transfer     46
# other_tcp         11
# web_traffic        5
# dhcp               2
# Name: count, dtype: int64
# Training with 781 packets...
#
# Training model...
# Cleaning data...
# Cleaned dataset: 781/781 packets retained
#
# Model Accuracy: 0.994
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           dns       1.00      1.00      1.00        72
# file_transfer       1.00      0.89      0.94         9
#        non_ip       1.00      1.00      1.00        26
#     other_tcp       0.67      1.00      0.80         2
#     other_udp       1.00      1.00      1.00        47
#   web_traffic       1.00      1.00      1.00         1
#
#      accuracy                           0.99       157
#     macro avg       0.94      0.98      0.96       157
#  weighted avg       1.00      0.99      0.99       157
#
#
# Top 10 Most Important Features:
#           feature  importance
# 11       dst_port    0.175729
# 10       src_port    0.149454
# 17     udp_length    0.128565
# 2       ip_length    0.120400
# 0   packet_length    0.091070
# 3          ip_ttl    0.086838
# 6        ip_proto    0.047653
# 8          is_udp    0.040890
# 1          has_ip    0.033995
# 4        ip_flags    0.025835
# Training completed successfully!
# Test prediction - HTTP packet: other_tcp (confidence: 0.360)

# %%
# Test with your specific sample file
results = classify_new_pcap_file(classifier, r"E:\for soln\sample.pcap")

if results:
    print(f"Sample file analysis: {len(results)} packets classified")
    
    # Show detailed results for first 20 packets
    #print("\nFirst 20 packet predictions:")
    #for i, result in enumerate(results[:20]):
       # print(f"Packet {result['packet_id']}: {result['predicted_class']} "
         #     f"(confidence: {result['confidence']:.3f})")
    
    # Summary
    class_counts = Counter([r['predicted_class'] for r in results])
    print(f"\nOverall classification:")
    for packet_type, count in class_counts.items():
        print(f"  {packet_type}: {count} packets")
else:
    print("Could not process sample.pcap file")
# Out:
# Classifying packets in: E:\for soln\sample.pcap
# Packet 0: non_ip (confidence: 0.990)
# Packet 1: non_ip (confidence: 1.000)
# Packet 2: dns (confidence: 0.770)
# Packet 3: dns (confidence: 0.770)
# Packet 4: dns (confidence: 0.520)
# Packet 5: dns (confidence: 0.480)
# Packet 6: other_tcp (confidence: 0.870)
# Packet 7: other_tcp (confidence: 0.480)
# Packet 8: file_transfer (confidence: 0.420)
# Packet 9: file_transfer (confidence: 0.360)
# Sample file analysis: 8166 packets classified
#
# Overall classification:
#   non_ip: 6481 packets
#   dns: 240 packets
#   other_tcp: 666 packets
#   file_transfer: 356 packets
#   other_udp: 8 packets
#   web_traffic: 415 packets
